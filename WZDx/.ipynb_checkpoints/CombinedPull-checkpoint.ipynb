# %%
#import packages
import requests
import json
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
#pull API using API key
response_API = requests.get('https://developer.nps.gov/api/v1/roadevents?api_key=3AidKP0PiqgfP8sbwZC0RZ9JM6QDnvYaZx3RRjrH')
#print(response_API.status_code)
data = response_API.text
df = json.loads(data)

# %%
#summarize the data by park
park_list = []
for x in df["features"]:
    for y in df["road_event_feed_info"]['data_sources']:
        if y['data_source_id']==x['properties']['core_details']['data_source_id']:
            park_list.append(y['organization_name'])

park_df = Counter(park_list)
park_df = pd.DataFrame.from_dict(park_df, orient="index").reset_index().rename(
    columns={'index': 'park',
            0:'number of alerts'}).sort_values(by=['number of alerts'])

# %%
# Get today's date as a string
today = datetime.date.today()
today_string = today.strftime('%Y-%m-%d')

park_df['date'] = today_string

# %%
len(park_df), sum(park_df['number of alerts']), max(park_df['number of alerts'])
# Out:
# (18, 98, 40)

# %%
# Loop through the API entries
counter=0

park_list = []
alert_name_list = []
description_list = []
event_type_list = []
road_name_list = []
vehicle_impact_list = []
start_date_list = []
end_date_list = []
today_date_list = []
id_list = []


for x in df["features"]:
    for y in df["road_event_feed_info"]['data_sources']:
        if y['data_source_id']==x['properties']['core_details']['data_source_id']:
            print("Park:", y['organization_name'])
            park_list.append(y['organization_name'])
    print("Alert name: ", x['properties']['core_details']['name'])
    print("Description: ", x['properties']['core_details']['description'])
    print("Event type: ", x['properties']['core_details']['event_type'])
    print("Road name: ", x['properties']['core_details']['road_names'])
    print("Vehicle impact: ", x['properties']['vehicle_impact'])
    print("Alert ID: ", x['properties']['core_details']['data_source_id'])
  #  print("Dates: ", x['properties']['start_date'], "to ", x['properties']['end_date'])
    print("")
    alert_name_list.append(x['properties']['core_details']['name'])
    description_list.append(x['properties']['core_details']['description'])
    event_type_list.append(x['properties']['core_details']['event_type'])
    road_name_list.append(x['properties']['core_details']['road_names'])
    vehicle_impact_list.append(x['properties']['vehicle_impact'])
    start_date_list.append(x['properties']['start_date'])
    id_list.append(x['properties']['core_details']['data_source_id'])
   # end_date_list.append(x['properties']['end_date'])
    today_date_list.append(today_string)
    counter+=1
# Out:
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Seasonal Road Closure
# Description:  North Entrance Road, West Rim Drive, and East Rim Drive are CLOSED for the season.
# Event type:  incident
# Road name:  ['North Entrance Road', 'East Rim Drive', 'Pinnacles Road', 'Grayback Road', 'West Rim Drive']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Red Gate Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Red Gate Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Red Gate Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Red Gate Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Tanners Ridge Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Tanners Ridge Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Tanners Ridge Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Tanners Ridge Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Yosemite National Park
# Alert name:  Tioga and Glacier Point Winter Closures
# Description:  Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They will both reopen later than usual this summer. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# Event type:  incident
# Road name:  ['Tioga Road', 'Glacier Piont Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16e33ae7-e71f-45ce-2e37-08d4c7ad36e2
#
# Park: Yosemite National Park
# Alert name:  Tioga and Glacier Point Winter Closures
# Description:  Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They will both reopen later than usual this summer. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# Event type:  incident
# Road name:  ['Tioga Road', 'Glacier Piont Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16e33ae7-e71f-45ce-2e37-08d4c7ad36e2
#
# Park: Yosemite National Park
# Alert name:  Tioga and Glacier Point Winter Closures
# Description:  Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They will both reopen later than usual this summer. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# Event type:  incident
# Road name:  ['Tioga Road', 'Glacier Piont Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16e33ae7-e71f-45ce-2e37-08d4c7ad36e2
#
# Park: Yosemite National Park
# Alert name:  Tioga and Glacier Point Winter Closures
# Description:  Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They will both reopen later than usual this summer. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# Event type:  incident
# Road name:  ['Tioga Road', 'Glacier Piont Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16e33ae7-e71f-45ce-2e37-08d4c7ad36e2
#
# Park: Yosemite National Park
# Alert name:  Tioga and Glacier Point Winter Closures
# Description:  Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They will both reopen later than usual this summer. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# Event type:  incident
# Road name:  ['Tioga Road', 'Glacier Piont Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16e33ae7-e71f-45ce-2e37-08d4c7ad36e2
#
# Park: Yosemite National Park
# Alert name:  Tioga and Glacier Point Winter Closures
# Description:  Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They will both reopen later than usual this summer. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# Event type:  incident
# Road name:  ['Tioga Road', 'Glacier Piont Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16e33ae7-e71f-45ce-2e37-08d4c7ad36e2
#
# Park: Point Reyes National Seashore
# Alert name:  Drakes Beach Road only open from 10 am to 4 pm due to elephant seal pups
# Description:  To better protect elephant seal pups that are present adjacent to the parking lot at Drakes Beach, Drakes Beach Road is closed daily from 4 pm to 10 am, but will be open daily from 10 am to 4 pm when park staff and winter wildlife docents are present.
# Event type:  incident
# Road name:  ['Drakes Beach Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  2132aef6-2cc3-4acf-2da3-08d4c7ad36e2
#
# Park: Point Reyes National Seashore
# Alert name:  Drakes Beach Road only open from 10 am to 4 pm due to elephant seal pups
# Description:  To better protect elephant seal pups that are present adjacent to the parking lot at Drakes Beach, Drakes Beach Road is closed daily from 4 pm to 10 am, but will be open daily from 10 am to 4 pm when park staff and winter wildlife docents are present.
# Event type:  incident
# Road name:  ['Drakes Beach Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  2132aef6-2cc3-4acf-2da3-08d4c7ad36e2
#
# Park: Bryce Canyon National Park
# Alert name:  Fairyland Point Road Closure
# Description:  The road leading to Fairyland Point (1 mile) closes to vehicles the first Monday after Thanksgiving and remains closed through the winter season. The unplowed road remains open for hikers, snowshoers, and x-country skiers.
# Event type:  incident
# Road name:  ['Fairyland Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  2f6576a4-e71b-4130-2c11-08d4c7ad36e2
#
# Park: Bryce Canyon National Park
# Alert name:  Fairyland Point Road Closure
# Description:  The road leading to Fairyland Point (1 mile) closes to vehicles the first Monday after Thanksgiving and remains closed through the winter season. The unplowed road remains open for hikers, snowshoers, and x-country skiers.
# Event type:  incident
# Road name:  ['Fairyland Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  2f6576a4-e71b-4130-2c11-08d4c7ad36e2
#
# Park: Bryce Canyon National Park
# Alert name:  Fairyland Point Road Closure
# Description:  The road leading to Fairyland Point (1 mile) closes to vehicles the first Monday after Thanksgiving and remains closed through the winter season. The unplowed road remains open for hikers, snowshoers, and x-country skiers.
# Event type:  incident
# Road name:  ['Fairyland Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  2f6576a4-e71b-4130-2c11-08d4c7ad36e2
#
# Park: Bryce Canyon National Park
# Alert name:  Fairyland Point Road Closure
# Description:  The road leading to Fairyland Point (1 mile) closes to vehicles the first Monday after Thanksgiving and remains closed through the winter season. The unplowed road remains open for hikers, snowshoers, and x-country skiers.
# Event type:  incident
# Road name:  ['Fairyland Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  2f6576a4-e71b-4130-2c11-08d4c7ad36e2
#
# Park: Death Valley National Park
# Alert name:  Flood Damage Closure
# Description:  Closed due to flooding from heavy rain.
# Event type:  incident
# Road name:  ['All roads']
# Vehicle impact:  all-lanes-closed
# Alert ID:  3a2b40f1-3bd4-46e8-2c60-08d4c7ad36e2
#
# Park: Death Valley National Park
# Alert name:  Flood Damage Closure
# Description:  Closed due to flooding from heavy rain.
# Event type:  incident
# Road name:  ['All roads']
# Vehicle impact:  all-lanes-closed
# Alert ID:  3a2b40f1-3bd4-46e8-2c60-08d4c7ad36e2
#
# Park: Death Valley National Park
# Alert name:  Flood Damage Closure
# Description:  Closed due to flooding from heavy rain.
# Event type:  incident
# Road name:  ['All roads']
# Vehicle impact:  all-lanes-closed
# Alert ID:  3a2b40f1-3bd4-46e8-2c60-08d4c7ad36e2
#
# Park: Death Valley National Park
# Alert name:  Flood Damage Closure
# Description:  Closed due to flooding from heavy rain.
# Event type:  incident
# Road name:  ['All roads']
# Vehicle impact:  all-lanes-closed
# Alert ID:  3a2b40f1-3bd4-46e8-2c60-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Cima Road Closed to ALL VEHICLES due to Construction
# Description:  Cima Road is undergoing a major renovation for visitor and wildlife safety upgrades. Please do not drive around barricades or cross this active construction zone.
# Event type:  work-zone
# Road name:  ['Cima Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Cima Road Closed to ALL VEHICLES due to Construction
# Description:  Cima Road is undergoing a major renovation for visitor and wildlife safety upgrades. Please do not drive around barricades or cross this active construction zone.
# Event type:  work-zone
# Road name:  ['Cima Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Kelso Railroad Crossing Delays 1 hour or more
# Description:  Railroad crossing at Kelbaker Road in Kelso may be blocked by train operations for one or our more, while trains use area for siding operations or passing each other. Contact Union Pacific for updates.
# Event type:  incident
# Road name:  ['Kelbaker Road']
# Vehicle impact:  flagging
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Kelso Railroad Crossing Delays 1 hour or more
# Description:  Railroad crossing at Kelbaker Road in Kelso may be blocked by train operations for one or our more, while trains use area for siding operations or passing each other. Contact Union Pacific for updates.
# Event type:  incident
# Road name:  ['Kelbaker Road']
# Vehicle impact:  flagging
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Soda Lake Crossing CLOSED again for Mojave Road
# Description:  Soda Lake Crossing CLOSED again for Mojave Road
# Event type:  incident
# Road name:  ['Mojave Road', 'Old Government Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Soda Lake Crossing CLOSED again for Mojave Road
# Description:  Soda Lake Crossing CLOSED again for Mojave Road
# Event type:  incident
# Road name:  ['Mojave Road', 'Old Government Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Buffalo National River
# Alert name:  South Woolum Road Closure
# Description:  Road conditions have deteriorated to hazardous conditions. Road closed until further notice.
# Event type:  incident
# Road name:  ['South Woolum Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  5ed0ce93-fb16-4f86-2c14-08d4c7ad36e2
#
# Park: Buffalo National River
# Alert name:  South Woolum Road Closure
# Description:  Road conditions have deteriorated to hazardous conditions. Road closed until further notice.
# Event type:  incident
# Road name:  ['South Woolum Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  5ed0ce93-fb16-4f86-2c14-08d4c7ad36e2
#
# Park: Organ Pipe Cactus National Monument
# Alert name:  Gachado to Dos Lomitas Closure
# Description:  The road from Gachado Line Camp to Dos Lomitas is closed.
# Event type:  incident
# Road name:  ['Gachado Line Camp', 'Dos Lomitas']
# Vehicle impact:  all-lanes-closed
# Alert ID:  737af835-2236-4642-2d83-08d4c7ad36e2
#
# Park: Organ Pipe Cactus National Monument
# Alert name:  Gachado to Dos Lomitas Closure
# Description:  The road from Gachado Line Camp to Dos Lomitas is closed.
# Event type:  incident
# Road name:  ['Gachado Line Camp', 'Dos Lomitas']
# Vehicle impact:  all-lanes-closed
# Alert ID:  737af835-2236-4642-2d83-08d4c7ad36e2
#
# Park: Ozark National Scenic Riverways
# Alert name:  Akers Ferry Closure
# Description:  The Akers Ferry on State Highway K will be out of service until further notice.
# Event type:  work-zone
# Road name:  ['State Highway K']
# Vehicle impact:  all-lanes-closed
# Alert ID:  8138990c-9d3f-4856-2d87-08d4c7ad36e2
#
# Park: Ozark National Scenic Riverways
# Alert name:  Akers Ferry Closure
# Description:  The Akers Ferry on State Highway K will be out of service until further notice.
# Event type:  work-zone
# Road name:  ['State Highway K']
# Vehicle impact:  all-lanes-closed
# Alert ID:  8138990c-9d3f-4856-2d87-08d4c7ad36e2
#
# Park: Dinosaur National Monument
# Alert name:  Harpers Corner Road Winter Closure
# Description:  Harpers Corner Road is not plowed beyond Plug Hat Butte during the winter and is normally closed from January 1 into April.
# Event type:  incident
# Road name:  ['Harpers Corner Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  82d0450b-aba8-46e4-2c62-08d4c7ad36e2
#
# Park: Dinosaur National Monument
# Alert name:  Harpers Corner Road Winter Closure
# Description:  Harpers Corner Road is not plowed beyond Plug Hat Butte during the winter and is normally closed from January 1 into April.
# Event type:  incident
# Road name:  ['Harpers Corner Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  82d0450b-aba8-46e4-2c62-08d4c7ad36e2
#
# Park: Guadalupe Mountains National Park
# Alert name:  Williams Ranch Road Closure
# Description:  Road closed due to severe flood damage.
# Event type:  incident
# Road name:  ['Williams Ranch Rd.']
# Vehicle impact:  all-lanes-closed
# Alert ID:  a44eadde-41ec-4499-2cc7-08d4c7ad36e2
#
# Park: Guadalupe Mountains National Park
# Alert name:  Williams Ranch Road Closure
# Description:  Road closed due to severe flood damage.
# Event type:  incident
# Road name:  ['Williams Ranch Rd.']
# Vehicle impact:  all-lanes-closed
# Alert ID:  a44eadde-41ec-4499-2cc7-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Roads closed for the season
# Description:  Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# Event type:  incident
# Road name:  ['Clingmans Dome Road', 'Heintooga to Round Bottom Road', 'Heintooga Ridge Road', 'Forge Creek Road', 'Little Greenbrier Road', 'Parson Brand Road', 'Rich Mountain Road', 'Roaring Fork Motor Nature Trail', 'Straight Fork Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Several park roads closed due to downed trees and high winds
# Description:  Gatlinburg Bypass, Laurel Creek Road, Cherokee Orchard Road, Greenbrier Road, Tremont Road, and some of the Foothills Parkway are closed due to downed trees.
# Event type:  incident
# Road name:  ['US 441 Newfound Gap Road between Gatlinburg and Cherokee', 'Gatlinburg Bypass', 'Laurel Creek Road', 'Little River Road', 'Cherokee Orchard Road', 'Greenbrier Road', 'Tremont Road', 'Wears Gap Road', 'Foothills Parkway (new section & between Look Rock and US 129)']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Piscataway Park
# Alert name:  Marshall Hall Access Road
# Description:  The Marshall Hall Access Road is closed due to construction. This road connects the Marshall Hall ruins to Marshall Hall Rd. The main road remains open.
# Event type:  work-zone
# Road name:  ['Marshall Hall Access Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ae4481d3-3d4a-477b-2d9b-08d4c7ad36e2
#
# Park: Piscataway Park
# Alert name:  Marshall Hall Access Road
# Description:  The Marshall Hall Access Road is closed due to construction. This road connects the Marshall Hall ruins to Marshall Hall Rd. The main road remains open.
# Event type:  work-zone
# Road name:  ['Marshall Hall Access Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ae4481d3-3d4a-477b-2d9b-08d4c7ad36e2
#
# Park: Zion National Park
# Alert name:  Kolob Terrace Road Closure - Maloney Hill
# Description:  Kolob Terrace road closed to non-tracked vehicles at Maloney Hill due to snow and ice.
# Event type:  incident
# Road name:  ['Maloney Hills']
# Vehicle impact:  all-lanes-closed
# Alert ID:  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2
#
# Park: Zion National Park
# Alert name:  Kolob Terrace Road Closure - Maloney Hill
# Description:  Kolob Terrace road closed to non-tracked vehicles at Maloney Hill due to snow and ice.
# Event type:  incident
# Road name:  ['Maloney Hills']
# Vehicle impact:  all-lanes-closed
# Alert ID:  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2
#
# Park: Zion National Park
# Alert name:  Road to Lava Point and West Rim Trailhead closed
# Description:  This is a regular seasonal closure, and we will remove this alert when snow melts. Lava Point Overlook is closed.
# Event type:  incident
# Road name:  ['West Rim Trailhead Road (Lava Point)', 'Lava Point Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2
#
# Park: Zion National Park
# Alert name:  Road to Lava Point and West Rim Trailhead closed
# Description:  This is a regular seasonal closure, and we will remove this alert when snow melts. Lava Point Overlook is closed.
# Event type:  incident
# Road name:  ['West Rim Trailhead Road (Lava Point)', 'Lava Point Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2
#
# Park: Natchez Trace Parkway
# Alert name:  Single-Lane Road Closure for Road Work at Milepost 117.4
# Description:  There is an emergency repair of a pipeline crossing the Parkway at mp 117.4. The project will start Monday 3/25/24.  It will involve the temporary closure of the southbound lane from 9am-4pm daily for at least 2-3 days.
# Event type:  work-zone
# Road name:  ['Natchez Trace Parkway Milepost 117.4']
# Vehicle impact:  flagging
# Alert ID:  c96651fe-ac5b-4213-2d51-08d4c7ad36e2
#
# Park: Black Canyon of the Gunnison National Park
# Alert name:  South Rim Road Construction
# Description:  From late March into November 2024, expect delays up to 30 minutes, alternating one-way traffic, and parking lot closures from the park entrance on Hwy 347 to the Visitor Center. Construction will continue on the rest of the road in 2025.
# Event type:  work-zone
# Road name:  ['South Rim Road']
# Vehicle impact:  alternating-one-way
# Alert ID:  d45494ce-5b26-426d-2c07-08d4c7ad36e2
#
# Park: Black Canyon of the Gunnison National Park
# Alert name:  South Rim Road Construction
# Description:  From late March into November 2024, expect delays up to 30 minutes, alternating one-way traffic, and parking lot closures from the park entrance on Hwy 347 to the Visitor Center. Construction will continue on the rest of the road in 2025.
# Event type:  work-zone
# Road name:  ['South Rim Road']
# Vehicle impact:  alternating-one-way
# Alert ID:  d45494ce-5b26-426d-2c07-08d4c7ad36e2
#
# Park: Olympic National Park
# Alert name:  Hurricane Ridge Road Status
# Description:  Hurricane Ridge Road is scheduled to be open Friday-Sunday, and holiday Mondays through March 31.
# Event type:  incident
# Road name:  ['Hurricane Ridge Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  de2fee5c-d31a-4bee-2d7f-08d4c7ad36e2

# %%
df_update = pd.DataFrame({
    "date":today_date_list,
    "park":park_list,
    "alert name": alert_name_list,
    "description": description_list,
    "event type": event_type_list,
    "road name": road_name_list,
    "vehicle impact": vehicle_impact_list,
    "event start date": start_date_list,
    "alert_id": id_list
#    "event end date": end_date_list
})
df_update.head
# Out:
# <bound method NDFrame.head of           date                                        park  \
# 0   2024-03-27                   Crater Lake National Park
# 1   2024-03-27                   Crater Lake National Park
# 2   2024-03-27                   Crater Lake National Park
# 3   2024-03-27                   Crater Lake National Park
# 4   2024-03-27                   Crater Lake National Park
# ..         ...                                         ...
# 93  2024-03-27                          Zion National Park
# 94  2024-03-27                       Natchez Trace Parkway
# 95  2024-03-27  Black Canyon of the Gunnison National Park
# 96  2024-03-27  Black Canyon of the Gunnison National Park
# 97  2024-03-27                       Olympic National Park
#
#                                            alert name  \
# 0                               Seasonal Road Closure
# 1                               Seasonal Road Closure
# 2                               Seasonal Road Closure
# 3                               Seasonal Road Closure
# 4                               Seasonal Road Closure
# ..                                                ...
# 93   Road to Lava Point and West Rim Trailhead closed
# 94  Single-Lane Road Closure for Road Work at Mile...
# 95                        South Rim Road Construction
# 96                        South Rim Road Construction
# 97                        Hurricane Ridge Road Status
#
#                                           description event type  \
# 0   North Entrance Road, West Rim Drive, and East ...   incident
# 1   North Entrance Road, West Rim Drive, and East ...   incident
# 2   North Entrance Road, West Rim Drive, and East ...   incident
# 3   North Entrance Road, West Rim Drive, and East ...   incident
# 4   North Entrance Road, West Rim Drive, and East ...   incident
# ..                                                ...        ...
# 93  This is a regular seasonal closure, and we wil...   incident
# 94  There is an emergency repair of a pipeline cro...  work-zone
# 95  From late March into November 2024, expect del...  work-zone
# 96  From late March into November 2024, expect del...  work-zone
# 97  Hurricane Ridge Road is scheduled to be open F...   incident
#
#                                             road name       vehicle impact  \
# 0   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 1   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 2   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 3   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 4   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# ..                                                ...                  ...
# 93  [West Rim Trailhead Road (Lava Point), Lava Po...     all-lanes-closed
# 94             [Natchez Trace Parkway Milepost 117.4]             flagging
# 95                                   [South Rim Road]  alternating-one-way
# 96                                   [South Rim Road]  alternating-one-way
# 97                             [Hurricane Ridge Road]     all-lanes-closed
#
#         event start date                              alert_id
# 0   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 1   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 2   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 3   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 4   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# ..                   ...                                   ...
# 93  2023-11-01T20:09:00Z  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2
# 94  2024-03-25T14:00:00Z  c96651fe-ac5b-4213-2d51-08d4c7ad36e2
# 95  2024-03-25T13:49:00Z  d45494ce-5b26-426d-2c07-08d4c7ad36e2
# 96  2024-03-25T13:49:00Z  d45494ce-5b26-426d-2c07-08d4c7ad36e2
# 97  2023-10-03T18:02:00Z  de2fee5c-d31a-4bee-2d7f-08d4c7ad36e2
#
# [98 rows x 9 columns]>

# %%
path = "Park Unit Scraping Information.csv"
regionlookup = pd.read_csv(path, encoding='latin-1')
regionlookup.head()
# Out:
#                     Park Name  \
# 0  Abraham Lincoln Birthplace
# 1                      Acadia
# 2                       Adams
# 3       African Burial Ground
# 4           Agate Fossil Beds
#
#                                       Park Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#                Type of Unit State  Reg Alpha  Unit
# 0  National Historical Park    KY  SER  ABLI   1.0
# 1             National Park    ME  NER  ACAD   1.0
# 2  National Historical Park    MA  NER  ADAM   1.0
# 3         National Monument    NY  NER  AFBG   1.0
# 4         National Monument    NE  MWR  AGFO   1.0

# %%
regionlookup.rename(columns={'Park Full Name':"park", "Reg":"region","Alpha":"alpha"}, inplace = True)
region_subset = regionlookup[['park', 'region', 'alpha', "State"]]
region_subset.head
# Out:
# <bound method NDFrame.head of                                                   park region alpha     State
# 0    Abraham Lincoln Birthplace National Historical...    SER  ABLI        KY
# 1                                 Acadia National Park    NER  ACAD        ME
# 2                       Adams National Historical Park    NER  ADAM        MA
# 3              African Burial Ground National Monument    NER  AFBG        NY
# 4                  Agate Fossil Beds National Monument    MWR  AGFO        NE
# ..                                                 ...    ...   ...       ...
# 416                          Yellowstone National Park    IMR  YELL  ID,MT,WY
# 417                             Yosemite National Park    PWR  YOSE        CA
# 418             Yukon-Charley Rivers National Preserve    AKR  YUCH        AK
# 419                                        Yucca House    IMR  YUHO        CO
# 420                                 Zion National Park    IMR  ZION        UT
#
# [421 rows x 4 columns]>

# %%
merged_df = pd.merge(df_update, region_subset, on="park", how="inner")
merged_df.head
# Out:
# <bound method NDFrame.head of           date                                        park  \
# 0   2024-03-27                   Crater Lake National Park
# 1   2024-03-27                   Crater Lake National Park
# 2   2024-03-27                   Crater Lake National Park
# 3   2024-03-27                   Crater Lake National Park
# 4   2024-03-27                   Crater Lake National Park
# ..         ...                                         ...
# 93  2024-03-27                          Zion National Park
# 94  2024-03-27                       Natchez Trace Parkway
# 95  2024-03-27  Black Canyon of the Gunnison National Park
# 96  2024-03-27  Black Canyon of the Gunnison National Park
# 97  2024-03-27                       Olympic National Park
#
#                                            alert name  \
# 0                               Seasonal Road Closure
# 1                               Seasonal Road Closure
# 2                               Seasonal Road Closure
# 3                               Seasonal Road Closure
# 4                               Seasonal Road Closure
# ..                                                ...
# 93   Road to Lava Point and West Rim Trailhead closed
# 94  Single-Lane Road Closure for Road Work at Mile...
# 95                        South Rim Road Construction
# 96                        South Rim Road Construction
# 97                        Hurricane Ridge Road Status
#
#                                           description event type  \
# 0   North Entrance Road, West Rim Drive, and East ...   incident
# 1   North Entrance Road, West Rim Drive, and East ...   incident
# 2   North Entrance Road, West Rim Drive, and East ...   incident
# 3   North Entrance Road, West Rim Drive, and East ...   incident
# 4   North Entrance Road, West Rim Drive, and East ...   incident
# ..                                                ...        ...
# 93  This is a regular seasonal closure, and we wil...   incident
# 94  There is an emergency repair of a pipeline cro...  work-zone
# 95  From late March into November 2024, expect del...  work-zone
# 96  From late March into November 2024, expect del...  work-zone
# 97  Hurricane Ridge Road is scheduled to be open F...   incident
#
#                                             road name       vehicle impact  \
# 0   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 1   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 2   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 3   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 4   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# ..                                                ...                  ...
# 93  [West Rim Trailhead Road (Lava Point), Lava Po...     all-lanes-closed
# 94             [Natchez Trace Parkway Milepost 117.4]             flagging
# 95                                   [South Rim Road]  alternating-one-way
# 96                                   [South Rim Road]  alternating-one-way
# 97                             [Hurricane Ridge Road]     all-lanes-closed
#
#         event start date                              alert_id region alpha  \
# 0   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 1   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 2   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 3   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 4   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# ..                   ...                                   ...    ...   ...
# 93  2023-11-01T20:09:00Z  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2    IMR  ZION
# 94  2024-03-25T14:00:00Z  c96651fe-ac5b-4213-2d51-08d4c7ad36e2    SER  NATR
# 95  2024-03-25T13:49:00Z  d45494ce-5b26-426d-2c07-08d4c7ad36e2    IMR  BLCA
# 96  2024-03-25T13:49:00Z  d45494ce-5b26-426d-2c07-08d4c7ad36e2    IMR  BLCA
# 97  2023-10-03T18:02:00Z  de2fee5c-d31a-4bee-2d7f-08d4c7ad36e2    PWR  OLYM
#
#        State
# 0         OR
# 1         OR
# 2         OR
# 3         OR
# 4         OR
# ..       ...
# 93        UT
# 94  AL,MS,TN
# 95        CO
# 96        CO
# 97        WA
#
# [98 rows x 12 columns]>

# %%
df_old_update = pd.read_csv("./TDx_tracker.csv")

# %%
df_update = pd.concat([merged_df, df_old_update])
df_update.head
# Out:
# <bound method NDFrame.head of           date                                        park  \
# 0   2024-03-27                   Crater Lake National Park
# 1   2024-03-27                   Crater Lake National Park
# 2   2024-03-27                   Crater Lake National Park
# 3   2024-03-27                   Crater Lake National Park
# 4   2024-03-27                   Crater Lake National Park
# ..         ...                                         ...
# 81  2024-03-21                          Zion National Park
# 82  2024-03-21                          Zion National Park
# 83  2024-03-21  Black Canyon of the Gunnison National Park
# 84  2024-03-21  Black Canyon of the Gunnison National Park
# 85  2024-03-21                       Olympic National Park
#
#                                           alert name  \
# 0                              Seasonal Road Closure
# 1                              Seasonal Road Closure
# 2                              Seasonal Road Closure
# 3                              Seasonal Road Closure
# 4                              Seasonal Road Closure
# ..                                               ...
# 81  Road to Lava Point and West Rim Trailhead closed
# 82  Road to Lava Point and West Rim Trailhead closed
# 83                       South Rim Road Construction
# 84                       South Rim Road Construction
# 85                       Hurricane Ridge Road Status
#
#                                           description event type  \
# 0   North Entrance Road, West Rim Drive, and East ...   incident
# 1   North Entrance Road, West Rim Drive, and East ...   incident
# 2   North Entrance Road, West Rim Drive, and East ...   incident
# 3   North Entrance Road, West Rim Drive, and East ...   incident
# 4   North Entrance Road, West Rim Drive, and East ...   incident
# ..                                                ...        ...
# 81  This is a regular seasonal closure, and we wil...   incident
# 82  This is a regular seasonal closure, and we wil...   incident
# 83  From late March into November 2024, expect del...  work-zone
# 84  From late March into November 2024, expect del...  work-zone
# 85  Hurricane Ridge Road is scheduled to be open F...   incident
#
#                                             road name       vehicle impact  \
# 0   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 1   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 2   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 3   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# 4   [North Entrance Road, East Rim Drive, Pinnacle...     all-lanes-closed
# ..                                                ...                  ...
# 81  ['West Rim Trailhead Road (Lava Point)', 'Lava...     all-lanes-closed
# 82  ['West Rim Trailhead Road (Lava Point)', 'Lava...     all-lanes-closed
# 83                                 ['South Rim Road']  alternating-one-way
# 84                                 ['South Rim Road']  alternating-one-way
# 85                           ['Hurricane Ridge Road']     all-lanes-closed
#
#         event start date                              alert_id region alpha  \
# 0   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 1   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 2   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 3   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 4   2023-11-02T02:19:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# ..                   ...                                   ...    ...   ...
# 81  2023-11-01T20:09:00Z  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2    IMR  ZION
# 82  2023-11-01T20:09:00Z  c5536a61-d5d7-49ce-2e3b-08d4c7ad36e2    IMR  ZION
# 83  2024-03-25T13:49:00Z  d45494ce-5b26-426d-2c07-08d4c7ad36e2    IMR  BLCA
# 84  2024-03-25T13:49:00Z  d45494ce-5b26-426d-2c07-08d4c7ad36e2    IMR  BLCA
# 85  2023-10-03T18:02:00Z  de2fee5c-d31a-4bee-2d7f-08d4c7ad36e2    PWR  OLYM
#
#    State
# 0     OR
# 1     OR
# 2     OR
# 3     OR
# 4     OR
# ..   ...
# 81    UT
# 82    UT
# 83    CO
# 84    CO
# 85    WA
#
# [184 rows x 12 columns]>

# %%
null_region_count = merged_df['region'].isnull().sum()
null_region_count
# Out:
# 0

# %%
if null_region_count == 0:
    merged_df.to_csv("./TDx_tracker.csv", index=False)
else:
    null_region_rows = joined[joined['region'].isnull()]
    print("Rows with a null Region column:")
    print(null_region_rows)

# %%
path = "Park Unit Scraping Information.csv"
parks = pd.read_csv(path, encoding='latin-1')
parks.head()
# Out:
#                     Park Name  \
# 0  Abraham Lincoln Birthplace
# 1                      Acadia
# 2                       Adams
# 3       African Burial Ground
# 4           Agate Fossil Beds
#
#                                       Park Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#                Type of Unit State  Reg Alpha  Unit
# 0  National Historical Park    KY  SER  ABLI   1.0
# 1             National Park    ME  NER  ACAD   1.0
# 2  National Historical Park    MA  NER  ADAM   1.0
# 3         National Monument    NY  NER  AFBG   1.0
# 4         National Monument    NE  MWR  AGFO   1.0

# %%
#pull API using API key
response_API = requests.get('https://developer.nps.gov/api/v1/alerts?limit=1000&api_key=3AidKP0PiqgfP8sbwZC0RZ9JM6QDnvYaZx3RRjrH')
#print(response_API.status_code)
data = response_API.text
df = json.loads(data)

# %%
id_list = []
url_list = []
title_list = []
parkCode_list = []
description_list = []
category_list = []
relatedRoadEvents_list = []
lastIndexedDate_list = []

for x in df['data']:
    #print(x)
    id_list.append(x['id'])
    url_list.append(x['url']) 
    title_list.append(x['title']) 
    parkCode_list.append(x['parkCode'].upper()) 
    description_list.append(x['description'])
    category_list.append(x['category']) 
    relatedRoadEvents_list.append(x['relatedRoadEvents'])
    lastIndexedDate_list.append(x['lastIndexedDate'])

# %%
alerts_df = pd.DataFrame({
    'id': id_list, 
    'url': url_list, 
    'title': title_list,
    'park alpha': parkCode_list,
    'description': description_list,
    'category': category_list,
    'relatedRoadEvents':relatedRoadEvents_list,
    'LastIndexedDate':lastIndexedDate_list
})

# %%
alerts_df2 = alerts_df.merge(parks,left_on='park alpha', right_on="Alpha", how = "left")
alerts_df2.head()
# Out:
#                                      id  \
# 0  4504F277-D8B8-41B8-B7EA-AAAA5DD1BC79
# 1  91FF2A4C-7075-4B8C-8385-31CDCEA943F3
# 2  B9F8CEF4-8DA9-4ABF-9FBE-073579B4AB1C
# 3  D343DB17-FB31-4953-AC43-957033416C4B
# 4  75487057-E4F6-4A96-9E5F-71A40F272B2F
#
#                                                  url  \
# 0                   https://www.facebook.com/HOFRNHS
# 1                   https://www.facebook.com/VAMANHS
# 2  https://www.nps.gov/coro/planyourvisit/calenda...
# 3  https://www.nps.gov/grca/planyourvisit/grand-c...
# 4  https://www.nps.gov/grca/planyourvisit/weather...
#
#                                                title park alpha  \
# 0              Monday, April 8, 2024 (Solar Eclipse)       HOFR
# 1              Monday, April 8, 2024 (Solar Eclipse)       VAMA
# 2  Hiker Shuttle will not operate March 29, April...       CORO
# 3  What's Closed and What's Open? (Park Operation...       GRCA
# 4  Wednesday, March 27 - Mostly Sunny Today - Win...       GRCA
#
#                                          description      category  \
# 0  The last tour of the Home of Franklin D. Roose...   Information
# 1  The last tour of the Mansion will be 2:00 PM F...   Information
# 2  Due to staffing issues and special events, the...  Park Closure
# 3  The Visitor Center is OPEN from 10 am to 4 pm....  Park Closure
# 4  All South Rim roads are OPEN. The North Rim an...  Park Closure
#
#   relatedRoadEvents        LastIndexedDate                     Park Name  \
# 0                []  2024-03-27 11:53:07.0  Home Of Franklin D Roosevelt
# 1                []  2024-03-27 11:43:59.0            Vanderbilt Mansion
# 2                []  2024-03-27 11:42:49.0                      Coronado
# 3                []  2024-03-27 11:29:30.0                  Grand Canyon
# 4                []  2024-03-27 11:26:17.0                  Grand Canyon
#
#                                       Park Full Name            Type of Unit  \
# 0  Home of Franklin D. Roosevelt National Histori...  National Historic Site
# 1          Vanderbilt Mansion National Historic Site  National Historic Site
# 2                         Coronado National Memorial       National Memorial
# 3                         Grand Canyon National Park           National Park
# 4                         Grand Canyon National Park           National Park
#
#   State  Reg Alpha  Unit
# 0    NY  NER  HOFR   1.0
# 1    NY  NER  VAMA   1.0
# 2    AZ  IMR  CORO   1.0
# 3    AZ  IMR  GRCA   1.0
# 4    AZ  IMR  GRCA   1.0

# %%
alerts_df2.to_csv("alerts_api.csv", index=False)
