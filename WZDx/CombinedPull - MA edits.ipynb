# %%
#import packages
import requests
import json
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
path = "Park Unit Scraping Information.csv"
regionlookup = pd.read_csv(path, encoding='latin-1')
regionlookup.head()
# Out:
#             Park Name                            Park Full Name  \
# 0             Alagnak                        Alagnak Wild River
# 1           Aniakchak  Aniakchak National Monument and Preserve
# 2  Bering Land Bridge      Bering Land Bridge National Preserve
# 3    Cape Krusenstern        Cape Krusenstern National Monument
# 4              Denali         Denali National Park and Preserve
#
#                    Type of Unit State  Reg Alpha  Unit
# 0                    Wild River    AK  AKR  ALAG     1
# 1  National Monument & Preserve    AK  AKR  ANIA     2
# 2             National Preserve    AK  AKR  BELA     1
# 3             National Monument    AK  AKR  CAKR     1
# 4      National Park & Preserve    AK  AKR  DENA     2

# %%
regionlookup[regionlookup['Alpha'] == 'DEVA']
# Out:
#         Park Name              Park Full Name   Type of Unit   State  Reg  \
# 429  Death Valley  Death Valley National Park  National Park  CA, NV  PWR
#
#     Alpha  Unit
# 429  DEVA     1

# %%
regionlookup.columns
# Out:
# Index(['Park Name', 'Park Full Name', 'Type of Unit', 'State', 'Reg', 'Alpha',
#        'Unit'],
#       dtype='object')

# %%
#pull API using API key
response_API = requests.get('https://developer.nps.gov/api/v1/roadevents?api_key=3AidKP0PiqgfP8sbwZC0RZ9JM6QDnvYaZx3RRjrH')
#print(response_API.status_code)
data = response_API.text
df = json.loads(data)

# %%
#summarize the data by park
park_list = []
for x in df["features"]:
    for y in df["road_event_feed_info"]['data_sources']:
        if y['data_source_id']==x['properties']['core_details']['data_source_id']:
            park_list.append(y['organization_name'])

park_df = Counter(park_list)
park_df = pd.DataFrame.from_dict(park_df, orient="index").reset_index().rename(
    columns={'index': 'park',
            0:'number of alerts'}).sort_values(by=['number of alerts'])

# %%
# Get today's date as a string
today = datetime.date.today()
today_string = today.strftime('%Y-%m-%d')

park_df['date'] = today_string

# %%
len(park_df), sum(park_df['number of alerts']), max(park_df['number of alerts'])
# Out:
# (13, 58, 20)

# %%
# Loop through the API entries
counter=0

park_list = []
alert_name_list = []
description_list = []
event_type_list = []
road_name_list = []
vehicle_impact_list = []
start_date_list = []
end_date_list = []
today_date_list = []
id_list = []


for x in df["features"]:
    for y in df["road_event_feed_info"]['data_sources']:
        if y['data_source_id']==x['properties']['core_details']['data_source_id']:
            print("Park:", y['organization_name'])
            park_list.append(y['organization_name'])
    print("Alert name: ", x['properties']['core_details']['name'])
    print("Description: ", x['properties']['core_details']['description'])
    print("Event type: ", x['properties']['core_details']['event_type'])
    print("Road name: ", x['properties']['core_details']['road_names'])
    print("Vehicle impact: ", x['properties']['vehicle_impact'])
    print("Alert ID: ", x['properties']['core_details']['data_source_id'])
  #  print("Dates: ", x['properties']['start_date'], "to ", x['properties']['end_date'])
    print("")
    alert_name_list.append(x['properties']['core_details']['name'])
    description_list.append(x['properties']['core_details']['description'])
    event_type_list.append(x['properties']['core_details']['event_type'])
    road_name_list.append(x['properties']['core_details']['road_names'])
    vehicle_impact_list.append(x['properties']['vehicle_impact'])
    start_date_list.append(x['properties']['start_date'])
    id_list.append(x['properties']['core_details']['data_source_id'])
   # end_date_list.append(x['properties']['end_date'])
    today_date_list.append(today_string)
    counter+=1
# Out:
# Park: Crater Lake National Park
# Alert name:  Ease Rim Drive Rehabilitation
# Description:  East Rim Drive is closed from Skell Head to Phantom Ship Overlook for Year 2 of a major rehabilitation project.  Cloudcap Road is also closed.
# Event type:  work-zone
# Road name:  ['East Rim Drive from Skell Head to Phantom Ship Overlook']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Ease Rim Drive Rehabilitation
# Description:  East Rim Drive is closed from Skell Head to Phantom Ship Overlook for Year 2 of a major rehabilitation project.  Cloudcap Road is also closed.
# Event type:  work-zone
# Road name:  ['East Rim Drive from Skell Head to Phantom Ship Overlook']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Ease Rim Drive Rehabilitation
# Description:  East Rim Drive is closed from Skell Head to Phantom Ship Overlook for Year 2 of a major rehabilitation project.  Cloudcap Road is also closed.
# Event type:  work-zone
# Road name:  ['East Rim Drive from Skell Head to Phantom Ship Overlook']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  Ease Rim Drive Rehabilitation
# Description:  East Rim Drive is closed from Skell Head to Phantom Ship Overlook for Year 2 of a major rehabilitation project.  Cloudcap Road is also closed.
# Event type:  work-zone
# Road name:  ['East Rim Drive from Skell Head to Phantom Ship Overlook']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  North Entrance Road Temporary Closure
# Description:  North Entrance Road is temporarily closed while firefighters do important line preparations in that area for the Middle Fork Fire burning in the northwest corner of the park.
# Event type:  incident
# Road name:  ['North Entrance Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Crater Lake National Park
# Alert name:  North Entrance Road Temporary Closure
# Description:  North Entrance Road is temporarily closed while firefighters do important line preparations in that area for the Middle Fork Fire burning in the northwest corner of the park.
# Event type:  incident
# Road name:  ['North Entrance Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Red Gate Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Red Gate Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Red Gate Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Red Gate Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Tanners Ridge Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Tanners Ridge Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Shenandoah National Park
# Alert name:  Tanners Ridge Fire Road
# Description:  Closed to vehicular traffic.
# Event type:  work-zone
# Road name:  ['Tanners Ridge Fire Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  0c9a542c-a992-42be-2ddc-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 221.8 - MP 229.5 Bridge Construction
# Description:  Road closed to all activity for replacement of 3 bridges. Detour in place via NC 18 to the North Carolina/Virginia line near milepost 217.3. Access to Doughton Park, including the campground and Bluffs Restaurant, is available via NC 18.
# Event type:  work-zone
# Road name:  ['MP 221.8 - MP 229.5']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 221.8 - MP 229.5 Bridge Construction
# Description:  Road closed to all activity for replacement of 3 bridges. Detour in place via NC 18 to the North Carolina/Virginia line near milepost 217.3. Access to Doughton Park, including the campground and Bluffs Restaurant, is available via NC 18.
# Event type:  work-zone
# Road name:  ['MP 221.8 - MP 229.5']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 229.5 - MP 238.5 Road Construction
# Description:  Road closed to all activity for repaving and infrastructure repair. Detour in place via NC 18 to the NC/VA line near milepost 217.3. Access to Doughton Park, including the campground and Bluffs Restaurant, is available via NC 18.
# Event type:  work-zone
# Road name:  ['MP 229.5 - MP 238.5']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 229.5 - MP 238.5 Road Construction
# Description:  Road closed to all activity for repaving and infrastructure repair. Detour in place via NC 18 to the NC/VA line near milepost 217.3. Access to Doughton Park, including the campground and Bluffs Restaurant, is available via NC 18.
# Event type:  work-zone
# Road name:  ['MP 229.5 - MP 238.5']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 238.5 - MP 248 Road Construction
# Description:  Single lane closures possible for road paving and infrastructure repairs. Access to Doughton Park, including the campground and Bluffs restaurant is available via NC 18.
# Event type:  work-zone
# Road name:  ['MP 238.5 - MP 248']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 238.5 - MP 248 Road Construction
# Description:  Single lane closures possible for road paving and infrastructure repairs. Access to Doughton Park, including the campground and Bluffs restaurant is available via NC 18.
# Event type:  work-zone
# Road name:  ['MP 238.5 - MP 248']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 248 - MP 249 Bridge Construction
# Description:  Road closed to all activity for Laurel Fork Bridge Replacement. Detour in place from MP 248 (NC 18) to MP 258.7 (Northwest Trading Post).
# Event type:  work-zone
# Road name:  ['MP 248 - MP 249']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 248 - MP 249 Bridge Construction
# Description:  Road closed to all activity for Laurel Fork Bridge Replacement. Detour in place from MP 248 (NC 18) to MP 258.7 (Northwest Trading Post).
# Event type:  work-zone
# Road name:  ['MP 248 - MP 249']
# Vehicle impact:  all-lanes-closed
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 261 - MP 276.5 Road Construction
# Description:  Single lane closure possible for road paving and infrastructure repairs.
# Event type:  work-zone
# Road name:  ['MP 261 - MP 276.5']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 261 - MP 276.5 Road Construction
# Description:  Single lane closure possible for road paving and infrastructure repairs.
# Event type:  work-zone
# Road name:  ['MP 261 - MP 276.5']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 27.3 - MP 37.6 Pavement Preservation
# Description:  Single lane closure possible with reduced speed for paving work. Bicyclists and motorcyclists are advised to find alternative routes while pavement is curing due to hazardous conditions from loose gravel.
# Event type:  work-zone
# Road name:  ['MP 27.3 to MP 37.6']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 27.3 - MP 37.6 Pavement Preservation
# Description:  Single lane closure possible with reduced speed for paving work. Bicyclists and motorcyclists are advised to find alternative routes while pavement is curing due to hazardous conditions from loose gravel.
# Event type:  work-zone
# Road name:  ['MP 27.3 to MP 37.6']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 276.5 - MP 282 Road Construction
# Description:  Single lane closure possible for road paving and infrastructure repairs.
# Event type:  work-zone
# Road name:  ['MP 276.5 - MP 282']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 276.5 - MP 282 Road Construction
# Description:  Single lane closure possible for road paving and infrastructure repairs.
# Event type:  work-zone
# Road name:  ['MP 276.5 - MP 282']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 292 - MP 305 Road Construction
# Description:  Single lane closure possible for road paving and infrastructure repairs.
# Event type:  work-zone
# Road name:  ['MP 292 - MP 305']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 292 - MP 305 Road Construction
# Description:  Single lane closure possible for road paving and infrastructure repairs.
# Event type:  work-zone
# Road name:  ['MP 292 - MP 305']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 64.6 - MP 86.2 Pavement Preservation
# Description:  Single lane closure possible with reduced speed for paving work. Bicyclists and motorcyclists are advised to find alternative routes while pavement is curing due to hazardous conditions from loose gravel.
# Event type:  work-zone
# Road name:  ['MP 64.6 - MP 86.2']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 64.6 - MP 86.2 Pavement Preservation
# Description:  Single lane closure possible with reduced speed for paving work. Bicyclists and motorcyclists are advised to find alternative routes while pavement is curing due to hazardous conditions from loose gravel.
# Event type:  work-zone
# Road name:  ['MP 64.6 - MP 86.2']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 97 - MP 121 Road Construction
# Description:  Single lane closure possible for survey and pre-construction planning work.
# Event type:  work-zone
# Road name:  ['MP 97 - MP 121']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Blue Ridge Parkway
# Alert name:  MP 97 - MP 121 Road Construction
# Description:  Single lane closure possible for survey and pre-construction planning work.
# Event type:  work-zone
# Road name:  ['MP 97 - MP 121']
# Vehicle impact:  flagging
# Alert ID:  16b85a09-3e09-4a62-2c08-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Hart Mine Road
# Description:  Hart Mine Road Historic Culverts Collapsed
# Event type:  incident
# Road name:  ['Hart Mine Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Hart Mine Road
# Description:  Hart Mine Road Historic Culverts Collapsed
# Event type:  incident
# Road name:  ['Hart Mine Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Kelso Railroad Crossing Delays 1 hour or more
# Description:  Railroad crossing at Kelbaker Road in Kelso may be blocked by train operations for one or our more, while trains use area for siding operations or passing each other. Contact Union Pacific for updates.
# Event type:  incident
# Road name:  ['Kelbaker Road']
# Vehicle impact:  flagging
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Mojave National Preserve
# Alert name:  Kelso Railroad Crossing Delays 1 hour or more
# Description:  Railroad crossing at Kelbaker Road in Kelso may be blocked by train operations for one or our more, while trains use area for siding operations or passing each other. Contact Union Pacific for updates.
# Event type:  incident
# Road name:  ['Kelbaker Road']
# Vehicle impact:  flagging
# Alert ID:  40ce97b0-d798-4e6c-2d42-08d4c7ad36e2
#
# Park: Sequoia & Kings Canyon National Parks
# Alert name:  Closure Due to Coffeepot Fire
# Description:  The South Fork Road within Sequoia National Park is closed due to the proximity of the Coffeepot Fire.
# Event type:  incident
# Road name:  ['South Fork Rad']
# Vehicle impact:  all-lanes-closed
# Alert ID:  44ada19c-0e53-4e96-2dd7-08d4c7ad36e2
#
# Park: Sequoia & Kings Canyon National Parks
# Alert name:  Closure Due to Coffeepot Fire
# Description:  The South Fork Road within Sequoia National Park is closed due to the proximity of the Coffeepot Fire.
# Event type:  incident
# Road name:  ['South Fork Rad']
# Vehicle impact:  all-lanes-closed
# Alert ID:  44ada19c-0e53-4e96-2dd7-08d4c7ad36e2
#
# Park: Buffalo National River
# Alert name:  South Woolum Road Closure
# Description:  Road conditions have deteriorated to hazardous conditions. Road closed until further notice.
# Event type:  incident
# Road name:  ['South Woolum Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  5ed0ce93-fb16-4f86-2c14-08d4c7ad36e2
#
# Park: Buffalo National River
# Alert name:  South Woolum Road Closure
# Description:  Road conditions have deteriorated to hazardous conditions. Road closed until further notice.
# Event type:  incident
# Road name:  ['South Woolum Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  5ed0ce93-fb16-4f86-2c14-08d4c7ad36e2
#
# Park: Buffalo National River
# Alert name:  Steel Creek Road - Intermittent Closure
# Description:  To aid with installing new water lines under Steel Creek Road, the road will be intermittently closed Mon-Thurs from 8am-4:30pm. The road will be accessible outside of closure hours.
# Event type:  work-zone
# Road name:  ['Steel Creek Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  5ed0ce93-fb16-4f86-2c14-08d4c7ad36e2
#
# Park: Buffalo National River
# Alert name:  Steel Creek Road - Intermittent Closure
# Description:  To aid with installing new water lines under Steel Creek Road, the road will be intermittently closed Mon-Thurs from 8am-4:30pm. The road will be accessible outside of closure hours.
# Event type:  work-zone
# Road name:  ['Steel Creek Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  5ed0ce93-fb16-4f86-2c14-08d4c7ad36e2
#
# Park: Organ Pipe Cactus National Monument
# Alert name:  Gachado to Dos Lomitas Closure
# Description:  The road from Gachado Line Camp to Dos Lomitas is closed.
# Event type:  incident
# Road name:  ['Gachado Line Camp', 'Dos Lomitas']
# Vehicle impact:  all-lanes-closed
# Alert ID:  737af835-2236-4642-2d83-08d4c7ad36e2
#
# Park: Organ Pipe Cactus National Monument
# Alert name:  Gachado to Dos Lomitas Closure
# Description:  The road from Gachado Line Camp to Dos Lomitas is closed.
# Event type:  incident
# Road name:  ['Gachado Line Camp', 'Dos Lomitas']
# Vehicle impact:  all-lanes-closed
# Alert ID:  737af835-2236-4642-2d83-08d4c7ad36e2
#
# Park: Ozark National Scenic Riverways
# Alert name:  Akers Ferry Closure
# Description:  The Akers Ferry on State Highway K will be out of service until further notice.
# Event type:  work-zone
# Road name:  ['State Highway K']
# Vehicle impact:  all-lanes-closed
# Alert ID:  8138990c-9d3f-4856-2d87-08d4c7ad36e2
#
# Park: Ozark National Scenic Riverways
# Alert name:  Akers Ferry Closure
# Description:  The Akers Ferry on State Highway K will be out of service until further notice.
# Event type:  work-zone
# Road name:  ['State Highway K']
# Vehicle impact:  all-lanes-closed
# Alert ID:  8138990c-9d3f-4856-2d87-08d4c7ad36e2
#
# Park: Guadalupe Mountains National Park
# Alert name:  Williams Ranch Road Closure
# Description:  Road closed due to severe flood damage.
# Event type:  incident
# Road name:  ['Williams Ranch Rd.']
# Vehicle impact:  all-lanes-closed
# Alert ID:  a44eadde-41ec-4499-2cc7-08d4c7ad36e2
#
# Park: Guadalupe Mountains National Park
# Alert name:  Williams Ranch Road Closure
# Description:  Road closed due to severe flood damage.
# Event type:  incident
# Road name:  ['Williams Ranch Rd.']
# Vehicle impact:  all-lanes-closed
# Alert ID:  a44eadde-41ec-4499-2cc7-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Gatlinburg Bypass
# Description:  Bypass closed between Gatlinburg Scenic Overlook and Newfound Gap Road for bridge construction from Wednesday, August 21 at 8 p.m. until Sunday, August 25 at 8 p.m. The overlook and Campbell Lead Road will remain open.
# Event type:  work-zone
# Road name:  ['Gatlinburg Bypass at Newfound Gap Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Gatlinburg Bypass
# Description:  Bypass closed between Gatlinburg Scenic Overlook and Newfound Gap Road for bridge construction from Wednesday, August 21 at 8 p.m. until Sunday, August 25 at 8 p.m. The overlook and Campbell Lead Road will remain open.
# Event type:  work-zone
# Road name:  ['Gatlinburg Bypass at Newfound Gap Road']
# Vehicle impact:  all-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Single-lane closures on Newfound Gap Road
# Description:  Construction on Newfound Gap Road between Gatlinburg and Park HQ. Expect delays during lane-closures and drive safely in work zones.
# Event type:  work-zone
# Road name:  ['Newfound Gap Road']
# Vehicle impact:  some-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Great Smoky Mountains National Park
# Alert name:  Single-lane closures on Newfound Gap Road
# Description:  Construction on Newfound Gap Road between Gatlinburg and Park HQ. Expect delays during lane-closures and drive safely in work zones.
# Event type:  work-zone
# Road name:  ['Newfound Gap Road']
# Vehicle impact:  some-lanes-closed
# Alert ID:  aa43d898-6fea-4d90-2cc1-08d4c7ad36e2
#
# Park: Capitol Reef National Park
# Alert name:  Scenic Drive Road Closure
# Description:  The scenic drive from just south of the campground loop C and amphitheater parking to Capitol Gorge is closed. Construction is expected to finish during Fall 2024.
# Event type:  work-zone
# Road name:  ['Scenic Drive ']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ae08c83e-319e-464a-2c23-08d4c7ad36e2
#
# Park: Capitol Reef National Park
# Alert name:  Scenic Drive Road Closure
# Description:  The scenic drive from just south of the campground loop C and amphitheater parking to Capitol Gorge is closed. Construction is expected to finish during Fall 2024.
# Event type:  work-zone
# Road name:  ['Scenic Drive ']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ae08c83e-319e-464a-2c23-08d4c7ad36e2
#
# Park: Capitol Reef National Park
# Alert name:  Scenic Drive Road Closure
# Description:  The scenic drive from just south of the campground loop C and amphitheater parking to Capitol Gorge is closed. Construction is expected to finish during Fall 2024.
# Event type:  work-zone
# Road name:  ['Scenic Drive ']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ae08c83e-319e-464a-2c23-08d4c7ad36e2
#
# Park: Capitol Reef National Park
# Alert name:  Scenic Drive Road Closure
# Description:  The scenic drive from just south of the campground loop C and amphitheater parking to Capitol Gorge is closed. Construction is expected to finish during Fall 2024.
# Event type:  work-zone
# Road name:  ['Scenic Drive ']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ae08c83e-319e-464a-2c23-08d4c7ad36e2
#
# Park: Black Canyon of the Gunnison National Park
# Alert name:  South Rim Road Construction
# Description:  From late March into November 2024, expect delays up to 30 minutes, alternating one-way traffic, and parking lot closures from the park entrance on Hwy 347 to the Visitor Center. Construction will continue on the rest of the road in 2025.
# Event type:  work-zone
# Road name:  ['South Rim Road']
# Vehicle impact:  alternating-one-way
# Alert ID:  d45494ce-5b26-426d-2c07-08d4c7ad36e2
#
# Park: Black Canyon of the Gunnison National Park
# Alert name:  South Rim Road Construction
# Description:  From late March into November 2024, expect delays up to 30 minutes, alternating one-way traffic, and parking lot closures from the park entrance on Hwy 347 to the Visitor Center. Construction will continue on the rest of the road in 2025.
# Event type:  work-zone
# Road name:  ['South Rim Road']
# Vehicle impact:  alternating-one-way
# Alert ID:  d45494ce-5b26-426d-2c07-08d4c7ad36e2
#
# Park: De Soto National Memorial
# Alert name:  Parking Lot Construction
# Description:  Parking lot is closed to all visitor access due to construction from July 8 through August 28. All access to the park will be through Riverview Point Preserve located adjacent to the park.
# Event type:  work-zone
# Road name:  ['Desoto Memorial Hwy', '75th St NW']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ddcb77a3-c905-4331-2c5e-08d4c7ad36e2
#
# Park: De Soto National Memorial
# Alert name:  Parking Lot Construction
# Description:  Parking lot is closed to all visitor access due to construction from July 8 through August 28. All access to the park will be through Riverview Point Preserve located adjacent to the park.
# Event type:  work-zone
# Road name:  ['Desoto Memorial Hwy', '75th St NW']
# Vehicle impact:  all-lanes-closed
# Alert ID:  ddcb77a3-c905-4331-2c5e-08d4c7ad36e2

# %%
df_update = pd.DataFrame({
    "date":today_date_list,
    "park":park_list,
    "alert name": alert_name_list,
    "description": description_list,
    "event type": event_type_list,
    "road name": road_name_list,
    "vehicle impact": vehicle_impact_list,
    "event start date": start_date_list,
    "alert_id": id_list
#    "event end date": end_date_list
})
df_update.head()
# Out:
#          date                       park  \
# 0  2024-08-22  Crater Lake National Park
# 1  2024-08-22  Crater Lake National Park
# 2  2024-08-22  Crater Lake National Park
# 3  2024-08-22  Crater Lake National Park
# 4  2024-08-22  Crater Lake National Park
#
#                               alert name  \
# 0          Ease Rim Drive Rehabilitation
# 1          Ease Rim Drive Rehabilitation
# 2          Ease Rim Drive Rehabilitation
# 3          Ease Rim Drive Rehabilitation
# 4  North Entrance Road Temporary Closure
#
#                                          description event type  \
# 0  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 1  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 2  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 3  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 4  North Entrance Road is temporarily closed whil...   incident
#
#                                            road name    vehicle impact  \
# 0  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 1  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 2  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 3  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 4                              [North Entrance Road]  all-lanes-closed
#
#        event start date                              alert_id
# 0  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 1  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 2  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 3  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2
# 4  2024-08-13T12:30:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2

# %%
regionlookup.rename(columns={'Park Full Name':"park", "Reg":"region","Alpha":"alpha"}, inplace = True)
region_subset = regionlookup[['park', 'region', 'alpha', "State"]]
region_subset.head()
# Out:
#                                        park region alpha State
# 0                        Alagnak Wild River    AKR  ALAG    AK
# 1  Aniakchak National Monument and Preserve    AKR  ANIA    AK
# 2      Bering Land Bridge National Preserve    AKR  BELA    AK
# 3        Cape Krusenstern National Monument    AKR  CAKR    AK
# 4         Denali National Park and Preserve    AKR  DENA    AK

# %%
merged_df = pd.merge(df_update, region_subset, on="park", how="inner")
merged_df.head()
# Out:
#          date                       park  \
# 0  2024-08-22  Crater Lake National Park
# 1  2024-08-22  Crater Lake National Park
# 2  2024-08-22  Crater Lake National Park
# 3  2024-08-22  Crater Lake National Park
# 4  2024-08-22  Crater Lake National Park
#
#                               alert name  \
# 0          Ease Rim Drive Rehabilitation
# 1          Ease Rim Drive Rehabilitation
# 2          Ease Rim Drive Rehabilitation
# 3          Ease Rim Drive Rehabilitation
# 4  North Entrance Road Temporary Closure
#
#                                          description event type  \
# 0  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 1  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 2  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 3  East Rim Drive is closed from Skell Head to Ph...  work-zone
# 4  North Entrance Road is temporarily closed whil...   incident
#
#                                            road name    vehicle impact  \
# 0  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 1  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 2  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 3  [East Rim Drive from Skell Head to Phantom Shi...  all-lanes-closed
# 4                              [North Entrance Road]  all-lanes-closed
#
#        event start date                              alert_id region alpha  \
# 0  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 1  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 2  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 3  2024-07-02T03:58:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
# 4  2024-08-13T12:30:00Z  02e0312b-cbd4-40bb-2c4e-08d4c7ad36e2    PWR  CRLA
#
#   State
# 0    OR
# 1    OR
# 2    OR
# 3    OR
# 4    OR

# %%
df_old_update = pd.read_csv("./TDx_tracker.csv")

# %%
df_update = pd.concat([merged_df, df_old_update])
df_update['date'] = pd.to_datetime(df_update.date)

# %%
null_region_count = merged_df['region'].isnull().sum()
null_region_count
# Out:
# 0

# %%
if null_region_count == 0:
    df_update.to_csv("./TDx_tracker.csv", index=False)
else:
    null_region_rows = joined[joined['region'].isnull()]
    print("Rows with a null Region column:")
    print(null_region_rows)

# %%
path = "Park Unit Scraping Information.csv"
parks = pd.read_csv(path, encoding='latin-1')
parks.head()
# Out:
#             Park Name                            Park Full Name  \
# 0             Alagnak                        Alagnak Wild River
# 1           Aniakchak  Aniakchak National Monument and Preserve
# 2  Bering Land Bridge      Bering Land Bridge National Preserve
# 3    Cape Krusenstern        Cape Krusenstern National Monument
# 4              Denali         Denali National Park and Preserve
#
#                    Type of Unit State  Reg Alpha  Unit
# 0                    Wild River    AK  AKR  ALAG     1
# 1  National Monument & Preserve    AK  AKR  ANIA     2
# 2             National Preserve    AK  AKR  BELA     1
# 3             National Monument    AK  AKR  CAKR     1
# 4      National Park & Preserve    AK  AKR  DENA     2

# %%
df_update.park.value_counts()
# Out:
# park
# Blue Ridge Parkway                            392
# Crater Lake National Park                     390
# Mojave National Preserve                      223
# Great Smoky Mountains National Park           220
# Shenandoah National Park                      166
# Yosemite National Park                        150
# Capitol Reef National Park                     92
# Buffalo National River                         90
# Curecanti National Recreation Area             84
# Organ Pipe Cactus National Monument            78
# Death Valley National Park                     78
# Guadalupe Mountains National Park              78
# Ozark National Scenic Riverways                74
# Black Canyon of the Gunnison National Park     74
# Sleeping Bear Dunes National Lakeshore         59
# Zion National Park                             44
# De Soto National Memorial                      40
# Redwood National Park                          29
# Natchez Trace Parkway                          24
# Dinosaur National Monument                     20
# Bryce Canyon National Park                     12
# Olympic National Park                          11
# Point Reyes National Seashore                  10
# Padre Island National Seashore                 10
# Acadia National Park                            7
# Golden Gate National Recreation Area            6
# Fort Point National Historic Site               5
# Piscataway Park                                 4
# Pinnacles National Park                         2
# Big Bend National Park                          2
# Valley Forge National Historical Park           2
# Muir Woods National Monument                    1
# Name: count, dtype: int64

# %%
len(df_update.park.unique())
# Out:
# 32

# %%
running_park_list = []
date_list = []
park_count_list = []

df_update = df_update.sort_values(by=['date'])

for x in df_update.date.unique():
    df_date = df_update.loc[df_update['date']==x]
    print(x, ": ", len(df_date))
    for y in df_date['park']:
        if y not in running_park_list:
            print(y)
            running_park_list.append(y)
    date_list.append(x)
    park_count_list.append(len(running_park_list))
# Out:
# 2023-10-17 00:00:00 :  11
# Yosemite National Park
# Mojave National Preserve
# Acadia National Park
# Dinosaur National Monument
# Natchez Trace Parkway
# Olympic National Park
# Golden Gate National Recreation Area
# 2023-10-23 00:00:00 :  11
# 2023-11-27 00:00:00 :  4
# Padre Island National Seashore
# 2023-12-18 00:00:00 :  4
# Muir Woods National Monument
# Fort Point National Historic Site
# 2023-12-28 00:00:00 :  3
# 2024-01-04 00:00:00 :  3
# 2024-01-11 00:00:00 :  5
# Shenandoah National Park
# 2024-01-18 00:00:00 :  4
# 2024-01-25 00:00:00 :  3
# 2024-02-01 00:00:00 :  8
# 2024-02-05 00:00:00 :  61
# Organ Pipe Cactus National Monument
# Death Valley National Park
# Bryce Canyon National Park
# Valley Forge National Historical Park
# Guadalupe Mountains National Park
# Zion National Park
# Redwood National Park
# Point Reyes National Seashore
# Crater Lake National Park
# 2024-03-04 00:00:00 :  83
# Buffalo National River
# Great Smoky Mountains National Park
# Piscataway Park
# 2024-04-02 00:00:00 :  62
# Ozark National Scenic Riverways
# Black Canyon of the Gunnison National Park
# 2024-04-19 00:00:00 :  364
# Sleeping Bear Dunes National Lakeshore
# 2024-04-26 00:00:00 :  120
# 2024-04-29 00:00:00 :  172
# 2024-05-02 00:00:00 :  52
# 2024-05-08 00:00:00 :  56
# Curecanti National Recreation Area
# Pinnacles National Park
# 2024-05-22 00:00:00 :  91
# Blue Ridge Parkway
# Capitol Reef National Park
# 2024-06-06 00:00:00 :  58
# 2024-06-17 00:00:00 :  71
# 2024-06-28 00:00:00 :  138
# De Soto National Memorial
# 2024-07-02 00:00:00 :  63
# 2024-07-03 00:00:00 :  366
# 2024-07-10 00:00:00 :  71
# 2024-07-16 00:00:00 :  71
# 2024-07-23 00:00:00 :  65
# 2024-07-24 00:00:00 :  63
# 2024-07-30 00:00:00 :  60
# 2024-07-31 00:00:00 :  60
# 2024-08-07 00:00:00 :  54
# Big Bend National Park
# 2024-08-13 00:00:00 :  54
# 2024-08-14 00:00:00 :  54
# 2024-08-16 00:00:00 :  56
# 2024-08-22 00:00:00 :  56

# %%
df_count = pd.DataFrame({
    'date': date_list,
    "count of parks": park_count_list
})
df_count['date'] = pd.to_datetime(df_count['date'])

# %%
date_list
# Out:
# [Timestamp('2023-10-17 00:00:00'),
#  Timestamp('2023-10-23 00:00:00'),
#  Timestamp('2023-11-27 00:00:00'),
#  Timestamp('2023-12-18 00:00:00'),
#  Timestamp('2023-12-28 00:00:00'),
#  Timestamp('2024-01-04 00:00:00'),
#  Timestamp('2024-01-11 00:00:00'),
#  Timestamp('2024-01-18 00:00:00'),
#  Timestamp('2024-01-25 00:00:00'),
#  Timestamp('2024-02-01 00:00:00'),
#  Timestamp('2024-02-05 00:00:00'),
#  Timestamp('2024-03-04 00:00:00'),
#  Timestamp('2024-04-02 00:00:00'),
#  Timestamp('2024-04-19 00:00:00'),
#  Timestamp('2024-04-26 00:00:00'),
#  Timestamp('2024-04-29 00:00:00'),
#  Timestamp('2024-05-02 00:00:00'),
#  Timestamp('2024-05-08 00:00:00'),
#  Timestamp('2024-05-22 00:00:00'),
#  Timestamp('2024-06-06 00:00:00'),
#  Timestamp('2024-06-17 00:00:00'),
#  Timestamp('2024-06-28 00:00:00'),
#  Timestamp('2024-07-02 00:00:00'),
#  Timestamp('2024-07-03 00:00:00'),
#  Timestamp('2024-07-10 00:00:00'),
#  Timestamp('2024-07-16 00:00:00'),
#  Timestamp('2024-07-23 00:00:00'),
#  Timestamp('2024-07-24 00:00:00'),
#  Timestamp('2024-07-30 00:00:00'),
#  Timestamp('2024-07-31 00:00:00'),
#  Timestamp('2024-08-07 00:00:00'),
#  Timestamp('2024-08-13 00:00:00'),
#  Timestamp('2024-08-14 00:00:00'),
#  Timestamp('2024-08-16 00:00:00'),
#  Timestamp('2024-08-22 00:00:00')]

# %%
# Adjusting the figure size
fig, ax = plt.subplots(1,1,figsize=(20,10))

# Creating a plot
plt.plot(df_count.date, df_count['count of parks'], linewidth = 3)

# Adding a plot title and customizing its font size
plt.title('Running Count of Parks that have Created TDx Alerts (248 Parks with Roads)', fontsize=20)

bar_max = df_count['count of parks']*1.1
plt.text(365, bar_max,
           'Asheville,NC\nMP 370-400', fontsize=15)
plt.vlines([100, 130, 280, 300, 370,400], ymin=0, ymax = bar_max/1.05,
            linestyles = "dotted", linewidth = 2)


# Adding axis labels and customizing their font size
plt.xlabel('Date', fontsize=15)
plt.ylabel('Count of Parks', fontsize=15)

# Rotaing axis ticks and customizing their font size
plt.xticks(rotation=30, fontsize=15)
plt.ylim([0,max(df_count['count of parks'])*1.25])

# Changing the plot resolution - zooming in the period from 15.12.2022 till 15.01.2023
#plt.xlim(pd.Timestamp('2023-09-1'), pd.Timestamp('2024-02-15'))
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 13
#      10 bar_max = df_count['count of parks']*1.1
#      11 plt.text(365, bar_max,
#      12            'Asheville,NC\nMP 370-400', fontsize=15)
# ---> 13 plt.vlines([100, 130, 280, 300, 370,400], ymin=0, ymax = bar_max/1.05,
#      14             linestyles = "dotted", linewidth = 2)
#      17 # Adding axis labels and customizing their font size
#      18 plt.xlabel('Date', fontsize=15)
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\pyplot.py:4083, in vlines(x, ymin, ymax, colors, linestyles, label, data, **kwargs)
#    4071 @_copy_docstring_and_deprecators(Axes.vlines)
#    4072 def vlines(
#    4073     x: float | ArrayLike,
#    (...)
#    4081     **kwargs,
#    4082 ) -> LineCollection:
# -> 4083     return gca().vlines(
#    4084         x,
#    4085         ymin,
#    4086         ymax,
#    4087         colors=colors,
#    4088         linestyles=linestyles,
#    4089         label=label,
#    4090         **({"data": data} if data is not None else {}),
#    4091         **kwargs,
#    4092     )
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\axes\_axes.py:1198, in Axes.vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1196 masked_verts[:, 0, 1] = ymin
#    1197 masked_verts[:, 1, 0] = x
# -> 1198 masked_verts[:, 1, 1] = ymax
#    1200 lines = mcoll.LineCollection(masked_verts, colors=colors,
#    1201                              linestyles=linestyles, label=label)
#    1202 self.add_collection(lines, autolim=False)
#
# File ~\Anaconda3\envs\work_env\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\numpy\ma\core.py:3387, in MaskedArray.__setitem__(self, indx, value)
#    3384     mval = tuple([False] * len(_dtype.names))
#    3385 if _mask is nomask:
#    3386     # Set the data, then the mask
# -> 3387     _data[indx] = dval
#    3388     if mval is not nomask:
#    3389         _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (35,) into shape (6,)
# Error in callback <function _draw_all_if_interactive at 0x0000016F065FD8B0> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\text.py:754, in Text.draw(self, renderer)
#     751 # don't use self.get_position here, which refers to text
#     752 # position in Text:
#     753 posx = float(self.convert_xunits(self._x))
# --> 754 posy = float(self.convert_yunits(self._y))
#     755 posx, posy = trans.transform((posx, posy))
#     756 if not np.isfinite(posx) or not np.isfinite(posy):
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Anaconda3\envs\work_env\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\matplotlib\text.py:754, in Text.draw(self, renderer)
#     751 # don't use self.get_position here, which refers to text
#     752 # position in Text:
#     753 posx = float(self.convert_xunits(self._x))
# --> 754 posy = float(self.convert_yunits(self._y))
#     755 posx, posy = trans.transform((posx, posy))
#     756 if not np.isfinite(posx) or not np.isfinite(posy):
#
# File ~\Anaconda3\envs\work_env\lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
df_count
# Out:
#          date  count of parks
# 0  2023-10-17               7
# 1  2023-10-23               7
# 2  2023-11-27               8
# 3  2023-12-18              10
# 4  2023-12-28              10
# 5  2024-01-04              10
# 6  2024-01-11              11
# 7  2024-01-18              11
# 8  2024-01-25              11
# 9  2024-02-01              11
# 10 2024-02-05              20
# 11 2024-03-04              23
# 12 2024-04-02              25
# 13 2024-04-19              26
# 14 2024-04-26              26
# 15 2024-04-29              26
# 16 2024-05-02              26
# 17 2024-05-08              28
# 18 2024-05-22              30
# 19 2024-06-06              30
# 20 2024-06-17              30
# 21 2024-06-28              31
# 22 2024-07-02              31
# 23 2024-07-03              31
# 24 2024-07-10              31
# 25 2024-07-16              31
# 26 2024-07-23              31
# 27 2024-07-24              31
# 28 2024-07-30              31
# 29 2024-07-31              31
# 30 2024-08-07              32
# 31 2024-08-13              32
# 32 2024-08-14              32
# 33 2024-08-16              32
# 34 2024-08-22              32

# %% [markdown]
# ## Alerts

# %%
#pull API using API key
response_API = requests.get('https://developer.nps.gov/api/v1/alerts?limit=1000&api_key=3AidKP0PiqgfP8sbwZC0RZ9JM6QDnvYaZx3RRjrH')
#print(response_API.status_code)
data = response_API.text
df = json.loads(data)

# %%
id_list = []
url_list = []
title_list = []
parkCode_list = []
description_list = []
category_list = []
relatedRoadEvents_list = []
lastIndexedDate_list = []

for x in df['data']:
    #print(x)
    id_list.append(x['id'])
    url_list.append(x['url']) 
    title_list.append(x['title']) 
    parkCode_list.append(x['parkCode'].upper()) 
    description_list.append(x['description'])
    category_list.append(x['category']) 
    relatedRoadEvents_list.append(x['relatedRoadEvents'])
    lastIndexedDate_list.append(x['lastIndexedDate'])

# %%
alerts_df = pd.DataFrame({
    'id': id_list, 
    'url': url_list, 
    'title': title_list,
    'park alpha': parkCode_list,
    'description': description_list,
    'category': category_list,
    'relatedRoadEvents':relatedRoadEvents_list,
    'LastIndexedDate':lastIndexedDate_list
})

# %%
alerts_df2 = alerts_df.merge(parks,left_on='park alpha', right_on="Alpha", how = "left")

# %%
road_closed_flag_list = []
road_words_list = ["road", "route", "interstate", "highway", "vehic"]

for x in range(len(alerts_df2)): 
    road_closed_flag = "No"
    
    for y in road_words_list:
        if y in str(alerts_df2["description"][x].lower()):
            road_closed_flag = "Yes"
            break
            
    road_closed_flag_list.append(road_closed_flag)

alerts_df2["Road Closed Flag"] = road_closed_flag_list

# %%
# add to alerts tracker table
alerts_df2['date'] = today_string
alerts_df2_old = pd.read_csv("./alerts_api_tracker.csv")
alerts_df2_combined = pd.concat([alerts_df2, alerts_df2_old])
alerts_df2_combined.to_csv("alerts_api_tracker.csv", index=False)

# %% [markdown]
# ##### Create a tracking table
#
# NPS wants to know how many total road closures there are, and how many of these are included in the TDx feed. For this, we can subset our alerts table for road closure alerts then compare our 2 tables.

# %%
# filter our alerts table to only include road closures
alerts_df3 = alerts_df2.loc[alerts_df2['Road Closed Flag']=="Yes"]

# group by our park-related fields and create sub-lists for our alert info
alerts_df3_grouped = alerts_df3.groupby(['park alpha','Park Name', 'Park Full Name',
       'Type of Unit', 'State','Reg'])[['title', 'description', 'category',
       'relatedRoadEvents']].agg(lambda x: list(x)).reset_index()

# %%
# create list of the unique park alphas in our two tables
has_alerts = set(alerts_df3['park alpha'])
has_tdx = set(merged_df['alpha'])

# create sublists of overlapping alphas, only in alerts table, only in TDx table
has_both = has_alerts.intersection(has_tdx)
only_alerts = has_alerts - has_tdx
only_tdx = has_tdx - has_alerts

#create empty data frame then populate the rows
status = pd.DataFrame(columns=['Park Alpha', 'Status'])
status['Park Alpha'] = list(has_both) + list(only_alerts) + list(only_tdx)
status['Status'] = (['Using TDx feed and alerts'] * len(has_both)) + (['Only using alerts'] * len(only_alerts)) + (['Only using TDx feed'] * len(only_tdx))

# %%
# join our status table with our alerts table
status_merged = status.merge(alerts_df3_grouped,left_on='Park Alpha', right_on="park alpha", how = "left")

# %%
status_merged['Status'].value_counts()
# Out:
# Status
# Only using alerts            97
# Using TDx feed and alerts    12
# Name: count, dtype: int64

# %%
status_merged.to_csv("combined_status.csv", index=False)

# %% [markdown]
# #### Create a tracker spreadsheet with the combined updates

# %%
df_update_combined = status_merged
df_update_combined['date'] = today_string

# %%
df_old_update = pd.read_csv("./combined_status_tracker.csv")

# %%
df_update_combined = pd.concat([df_update_combined, df_old_update])

# %%
df_update_combined.to_csv("combined_status_tracker.csv", index=False)

# %% [markdown]
# #### Calculate visitors going to a park with TDx out of all visitors going to a park with a road closure, using hardcoded 2014-2023 data

# %%
#Recreation visitor data for 2014-2023, inclusive, downloaded from NPS IRMA Public Use Statistics QueryBuilder, saved in the parent folder.
#If this file is changed (e.g. new download with future years' data), delete rows 1 and 2 in the file. The first row should be the column headings.
df_10year_visits = pd.read_excel("./2014_2023_Visitation_All_Parks.xlsx")

df_10year_visits.columns = df_10year_visits.columns.str.strip()
df_10year_visits.sort_values(by=['Unit Code'], ascending=True)

df_10year_visits['TenAvg'] = df_10year_visits.groupby(by='Unit Code')['Recreation Visits'].transform('mean')

#Subset of all parks: visits at parks using TDx or TDx and alerts or Alerts only (i.e. all road closures)
df_10year_visits_at_allroadclosure_parks = df_10year_visits[df_10year_visits['Unit Code'].isin(has_both|only_tdx|only_alerts)]

#Number of visits at parks with road closures
AllRoadClosureTotal = df_10year_visits_at_allroadclosure_parks['Recreation Visits'].sum()
print("10 year average visits to parks with a current road closure:", format(AllRoadClosureTotal,','))

#Subset of all parks: visits at parks using TDx or TDx and alerts
df_10year_visits_at_TDx_parks = df_10year_visits[df_10year_visits['Unit Code'].isin(has_both|only_tdx)]

#Number of visits at parks with TDx
ParksUsingTDxTotal = df_10year_visits_at_TDx_parks['Recreation Visits'].sum()
print("10 year visits to parks using TDx for an active road closure:", format(ParksUsingTDxTotal,','))
print("This is",(round((ParksUsingTDxTotal/AllRoadClosureTotal)*100)),"% of 10 year average visits.")
# Out:
# 10 year average visits to parks with a current road closure: 1,286,183,933
# 10 year visits to parks using TDx for an active road closure: 348,707,645
# This is 27 % of 10 year average visits.

# %%
#### Basic Keyword search

# %%
#### To do: Create list of keywords
sample_alerts_df = alerts_df3.description.str.split(expand=True).stack().value_counts()
print(sample_alerts_df.head(45))
# Out:
# the             281
# to              222
# and             167
# is              110
# of               89
# in               79
# for              76
# on               62
# at               61
# will             57
# Road             55
# are              52
# The              50
# a                50
# road             50
# closed           48
# park             47
# be               47
# from             46
# or               40
# your             39
# parking          38
# may              31
# all              31
# not              29
# due              26
# vehicle          26
# with             23
# vehicles         23
# construction     22
# Trail            21
# open             21
# Please           20
# can              20
# access           18
# along            18
# roads            18
# Visitor          16
# closure          16
# Due              16
# &                14
# that             14
# traffic          14
# entrance         14
# you              14
# Name: count, dtype: int64
