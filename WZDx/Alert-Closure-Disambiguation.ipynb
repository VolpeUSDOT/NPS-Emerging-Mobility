# %%
import requests
import pandas as pd
import json

# %%
password = pd.read_csv("passwords.csv")
password_nps = password["password"][0]

# %%
#pull API using API key
alerts_url = "https://developer.nps.gov/api/v1/alerts?limit=1000&api_key=" + password_nps

response_API = requests.get(alerts_url)
#print(response_API.status_code)
data = response_API.text
alerts_json = json.loads(data)

# %%
alerts_json
# Out:
# {'total': '726',
#  'limit': '1000',
#  'start': '0',
#  'data': [{'id': '17B42D3F-84E4-4B78-900F-670C9D625658',
#    'url': '',
#    'title': 'Sept. 29-Oct. 3 approved Uncrewed Aircraft System (drone) use',
#    'parkCode': 'slbe',
#    'description': 'Research under approved permit entitled "Mapping dune erosion and sand transport at Sleeping Bear Dunes National Lakeshore" will be conducted via Uncrewed Aircraft System (drone) that will be flown at the following locations: Dune Climb, Pierce Stocking Scenic Drive Overlook #9, Pyramid Point, Empire Bluff trail (boardwalk and bluff edge area).',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '872E3239-CDB2-4E89-8F57-1C87EC3FC3FE',
#    'url': 'https://www.nps.gov/grca/northrimstatus.htm',
#    'title': 'North Rim Status and Inner Canyon Closures —Monday, September 29, 2025',
#    'parkCode': 'grca',
#    'description': 'Follow the link for North Rim status and current closures. ADDITIONAL CLOSURES: South Kaibab Trail below the Tipoff, Phantom Ranch and North Kaibab Trail.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [{'title': 'North Rim Roads Are Closed by the Dragon Bravo Wildfire',
#      'id': '872E3239-CDB2-4E89-8F57-1C87EC3FC3FE',
#      'type': 'roadevent',
#      'url': 'https://www.nps.gov/grca/planyourvisit/conditions.htm'}],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '3396D6D3-5F44-4532-B48B-42A629991493',
#    'url': 'https://www.nps.gov/grca/planyourvisit/grand-canyon-national-park-public-health-update.htm',
#    'title': "What's Closed and What's Open on South Rim —Monday, September 29, 2025",
#    'parkCode': 'grca',
#    'description': 'Visit this link for a list of the available visitor services in Grand Canyon Village and at Desert View. —South Rim High 66°F (19°C) Low 44°F (7°C). Mostly sunny.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '2CF15EBC-0800-4DF3-8179-B1579B6D4F57',
#    'url': 'https://www.nps.gov/grca/planyourvisit/key-messages.htm',
#    'title': 'Monday, September 29, 2025 — Critical Backcountry Updates/Closures',
#    'parkCode': 'grca',
#    'description': "Visit the link for the inner canyon weather forecast, today's heat risk and drinking water availability. Inner Canyon High 88°F (31°C)",
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': 'F43C6435-4C08-4DF8-B1DD-C92B68C9E805',
#    'url': '',
#    'title': 'Jenny Lake Lakeshore Trail Reroute',
#    'parkCode': 'grte',
#    'description': 'The Jenny Lake Boat Dock Bridge is under construction, and the trail has been temporarily rerouted. Temporary reroutes will be in place until October 23rd. Maps and directional signage will be posted in the area of the reroute to guide you along the trail during construction. Jenny Lake Boating is closed for the season.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '3E4B8C08-23A0-4F40-B290-53BB4959E6CD',
#    'url': 'https://www.nps.gov/shen/planyourvisit/alert-system.htm',
#    'title': 'Get Skyline Drive Status Updates',
#    'parkCode': 'shen',
#    'description': 'Sign up for Shenandoah Alerts by texting SHENALERTS to 888777. Any time there are closures, re-openings, or other important safety-related alerts, subscribers will receive a notification via text. You may unsubscribe at any time.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '6EC20CC5-4731-4E02-BDE1-AC5330C09182',
#    'url': '',
#    'title': 'Oct 3-5: Temporary Lane Closure on Rock Creek and Potomac Parkway',
#    'parkCode': 'rocr',
#    'description': 'From Friday, Oct. 3 at 8 pm until Sunday, Oct. 5 at 8 pm, the right southbound lane of Rock Creek and Potomac Parkway will be closed between P Street NW and Pennsylvania Avenue NW to allow DC Water to conduct repair work.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '3032989A-A3CF-4ED8-B80F-FB84A828D76B',
#    'url': '',
#    'title': 'Oct 3-5: Temporary Closure of Multi-Use Trail, P St to Pennsylvania Ave.',
#    'parkCode': 'rocr',
#    'description': 'From Friday, Oct. 3 at 8 pm until Sunday, Oct. 5 at 8 pm, the multi-use trail between P Street NW and Pennsylvania Avenue NW will be closed for DC Water to conduct repair work. During the closure, please follow the signs which indicate a detour route.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': 'B500783E-4014-4447-A7A0-5EED9674D710',
#    'url': 'https://www.nps.gov/bith/planyourvisit/safety.htm',
#    'title': 'Hunting Season Underway: Sep 27 to Feb 28',
#    'parkCode': 'bith',
#    'description': 'Hunting is allowed in the following units: Big Sandy Creek, Beech Creek, Lance Rosier, Beaumont, Neches Bottom & Jack Gore Baygall. People entering those units should wear orange. Most hiking trails are NOT in hunting zones (exception: Big Sandy Trail).',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '36736D3B-B300-4DD0-B546-67C6374A7E1B',
#    'url': '',
#    'title': 'Beach safety closure in place in northern Rodanthe',
#    'parkCode': 'caha',
#    'description': 'Due to the presence of threatened oceanfront structures, the beach in the village of Rodanthe, from East Point Drive south for approximately 0.15 miles to Surfside Drive, is closed.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '51204133-7729-4B51-B78F-7870E3FFB757',
#    'url': '',
#    'title': 'High Wind and Rip Current Risk from Offshore Storms',
#    'parkCode': 'cuis',
#    'description': 'The National Park Service is closely monitoring the tropics for the development of weather systems with potential to impact the surrounding area. Visitor Services are operating under normal conditions at this time. Please check updates before visiting. We are expecting the severe risk of rip currents now until further notice. Please avoid swimming during this time. For up-to-date alerts and hazards, follow the link to the National Weather Service. https://www.weather.gov/jax',
#    'category': 'Danger',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '0E31ECDE-AF77-4BA3-9005-C064906DCBB6',
#    'url': 'https://www.nps.gov/romo/planyourvisit/hiking.htm',
#    'title': 'Temporary Trail Closure Impacting Access to Dream Lake & Emerald Lake',
#    'parkCode': 'romo',
#    'description': 'Beginning today, September 29 through Thursday, October 2, and again Monday, October 6 through Thursday, October 9, trail access to Dream Lake and Emerald Lake will be closed to all uses for a bridge replacement project. Dream Lake & Emerald Lake will not be accessible during this closure. This popular trail section will reopen Friday through Sunday (Oct 3 through Oct 5) and close again on Monday, Oct 6. All other trails in the Bear Lake area will remain open, including access to Lake Haiyaha.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-29 00:00:00.0'},
#   {'id': '806AD68E-F1E5-4D28-9A5E-910193F04473',
#    'url': '',
#    'title': 'All Fort Sumter Ferries CANCELED Monday Sept 29 and Tuesday Sept 30',
#    'parkCode': 'fosu',
#    'description': 'All Fort Sumter ferries are CANCELED on Monday September 29 and Tuesday September 30, 2025. For more information about tickets, please contact Fort Sumter Tours at (843) 883-3123 or www.fortsumtertours.com All other Charleston National park sites will remain open including Fort Moultrie and the Fort Sumter Visitor Center at Liberty Square. For updated closure information, please monitor this website or visit our Facebook page.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'D143C837-28F0-4759-B604-8DB084276532',
#    'url': 'https://www.nps.gov/elma/planyourvisit/driving-to-big-tubes.htm',
#    'title': 'NPS 300 Road Conditions',
#    'parkCode': 'elma',
#    'description': 'NPS 300 to Big Tubes has not been evaluated since the most recent rainstorms. A high clearance, four-wheel drive vehicle is recommended.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'AA99D6DB-C985-49E1-9A88-1C9A4AA97137',
#    'url': 'https://www.nps.gov/elma/learn/management/superintendent-s-compendium.htm',
#    'title': 'Stage II Fire Restrictions in effect',
#    'parkCode': 'elma',
#    'description': 'Stage II Fire Restrictions are in effect until further notice. The following activities are prohibited: building, maintaining, attending or using a fire, campfire, charcoal, coal, or wood stove and smoking, except within an enclosed vehicle.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'C380E82F-798C-43B7-8B19-510BB2BEDB6D',
#    'url': '',
#    'title': 'Debris on Roadways',
#    'parkCode': 'moja',
#    'description': 'Use caution when driving through Mojave National Preserve. All roadways have debris on them due to storms over the weekend and may be flooded.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': '3D639DA0-55DB-4458-864A-991455DE5320',
#    'url': '',
#    'title': 'Restroom Closure',
#    'parkCode': 'flni',
#    'description': 'Flight 93 National Memorial permanent restroom facilities are currently out of order. Temporary restroom facilities are available outside of the Visitor Center and waterless restroom facilities are available at the Memorial Plaza.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'BC1BD87D-7655-41BA-8A8E-80B3470E053E',
#    'url': '',
#    'title': 'Accessible Lift Temporarily Out Of Order',
#    'parkCode': 'mava',
#    'description': 'Due to unforeseen circumstances, the accessible lift to Lindenwald is temporarily out of order. We apologize for any inconvenience.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'E124DAA0-C101-4260-A0A4-BF9A02E596A4',
#    'url': 'https://www.nps.gov/gero/planyourvisit/hours.htm',
#    'title': 'George Rogers Clark NHP in the Eastern Time Zone',
#    'parkCode': 'gero',
#    'description': 'George Rogers Clark National Historical Park is located in the Eastern Time Zone. The memorial closes 15 minutes before the visitor center.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': '34716E37-18AB-400B-96D0-2DA7E0F28B40',
#    'url': '',
#    'title': 'Road Closures',
#    'parkCode': 'bibe',
#    'description': 'River Road East is open from the eastern end to the Glenn Spring Road junction. Glenn Spring Road is open. The paved road between Castolon and Santa Elena Canyon (Park Route 16) is open. River Road is closed west of the Glenn Springs Road junction. Old Ore Road, Hot Springs Road, and Black Gap Road are all closed. Unpaved roads require 4-wheel drive. Your safety is your responsibility, be prepared to self-rescue.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'BF331E2F-E6DB-407A-B873-443B8BA6B2DD',
#    'url': '',
#    'title': 'Trolleys Out of Service',
#    'parkCode': 'lowe',
#    'description': 'The Lowell National Historical Park Trolleys are currently not operating for public runs or on any scheduled tours due to unplanned complications with the power lines',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': '3AD423CE-5CD9-4A38-85E6-142AC41B7CC9',
#    'url': '',
#    'title': 'High winds expected as impact of offshore storms',
#    'parkCode': 'fofr',
#    'description': 'The National Park Service is closely monitoring the tropics. High winds are expected through the week. Be aware of surroundings as trees can be vulnerable to high wind. Visitor Services are operating under normal conditions at this time. Please check updates before visiting.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'B28BDD5D-BBC4-454C-A34B-BE47D64A1C3A',
#    'url': '',
#    'title': 'Oasis of Mara Trail Closed',
#    'parkCode': 'jotr',
#    'description': 'Due to a heavy flooding event, the Oasis of Mara Trail is closed until further notice.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': '6BF7A5BC-3966-4B77-B66D-A09141E99AF6',
#    'url': '',
#    'title': 'Use Caution Kelso Dunes Road',
#    'parkCode': 'moja',
#    'description': 'Flooding has resulted in damage to Kelso Dunes Road. Watch for numerous washouts with dirt, rocks, potholes, debris and sharp shoulder drop-offs. Use caution when driving and watch for road crews at work.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'A8445CF7-4BD1-4EA1-8D97-7A3269314892',
#    'url': 'https://www.nps.gov/perl/learn/news/advance-reservations-for-uss-arizona-memorial-will-pause-beginning-july-9-while-preservation-work-continues.htm',
#    'title': 'September 29, 2025, boats will operate in the vicinity of the memorial.',
#    'parkCode': 'valr',
#    'description': 'Tomorrow, September 29, we will be operating boats on the harbor in the vicinity of the USS Arizona Memorial from 8 am to 3:30 pm. Please expect extended delays between boats. Preservation work may impact direct access to the memorial.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-28 00:00:00.0'},
#   {'id': 'DE5C4C84-FCB5-497A-8F27-117A76E9CF6D',
#    'url': '',
#    'title': 'Temple Bar Road Down to One Lane at Several Wash Crossings',
#    'parkCode': 'lake',
#    'description': 'Due to a storm on 9/26/25 the road was flooded at several wash crossings. The road has reopened but is down to one lane in several places. Use caution where rocks are still in the road and areas that work crews are present.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-27 00:00:00.0'},
#   {'id': '33D1E725-7BC2-4F92-A760-13414335B41D',
#    'url': 'https://www.nps.gov/lake/planyourvisit/hemenway-harbor-boat-launch-extension-project-summer-2025.htm',
#    'title': 'Hemenway Harbor Boat Ramp Extension - Reduced Lane Capacity - Expect Delays',
#    'parkCode': 'lake',
#    'description': 'Boaters who want to launch at Hemenway Harbor this summer and early fall may experience delays at the ramp on busy days. The nearby PWC launch is open to boats during the project. Callville Bay, Echo Bay, Temple Bar, and South Cove launches are open on Lake Mead.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-27 00:00:00.0'},
#   {'id': '722FB041-2F1D-4763-83C5-5FFF92887485',
#    'url': '',
#    'title': 'New Fire Regulations',
#    'parkCode': 'deto',
#    'description': "See the Superintendent's Compendium for more information.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-27 00:00:00.0'},
#   {'id': '1C39489F-72C4-47D3-A77F-36F2DAB63CE7',
#    'url': '',
#    'title': 'Gatlinburg Bypass closed',
#    'parkCode': 'grsm',
#    'description': 'The Gatlinburg Bypass is closed due to a landslide blocking the roadway. Park officials are currently assessing the situation.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [{'title': 'Gatlinburg Bypass closed',
#      'id': '1C39489F-72C4-47D3-A77F-36F2DAB63CE7',
#      'type': 'roadevent',
#      'url': 'https://www.nps.gov/grsm/planyourvisit/conditions.htm'}],
#    'lastIndexedDate': '2025-09-27 00:00:00.0'},
#   {'id': 'D7753095-F79A-4223-9014-D0FC478E4D96',
#    'url': '',
#    'title': 'Bonita Canyon Campground Restroom Construction',
#    'parkCode': 'chir',
#    'description': 'The restrooms at the campground will be closed for construction from 8/1/25 to 10/20/25. Portable toilets and a handwashing station will be available in the campground. Restrooms with running water are available at the Visitor Center and Faraway Ranch.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-27 00:00:00.0'},
#   {'id': '509BA687-3354-4CBF-B1C9-1DAE23F4B1EC',
#    'url': '',
#    'title': 'Campfires Allowed in Front-Country Campgrounds Starting September 27',
#    'parkCode': 'olym',
#    'description': 'Due favorable weather conditions, Olympic National Park and Olympic National Forest are returning to Stage 1 campfire restrictions. Campfires are allowed in front-country campgrounds in established fire rings.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-27 00:00:00.0'},
#   {'id': '48D3D569-48E9-4387-A2D1-7572A7DA8CC5',
#    'url': '',
#    'title': 'Dyer Road Closed Due to Road Construction',
#    'parkCode': 'chch',
#    'description': 'Road closures/construction will continue on the east section of Dyer Road, between Glenn-Kelly and LaFayette Roads, and will extend onto the west portion of Dyer Road, between Glenn-Kelly and Chickamauga-Vittetoe Roads. During the closures, all public traffic, including motorists, equestrians, pedestrians and bicyclists, is prohibited from using the closed sections.',
#    'category': 'Information',
#    'relatedRoadEvents': [{'title': 'Dyer Road Closure',
#      'id': '48D3D569-48E9-4387-A2D1-7572A7DA8CC5',
#      'type': 'roadevent',
#      'url': 'https://www.nps.gov/chch/planyourvisit/conditions.htm'}],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '2EFF9BC8-6E01-4172-8D1E-6F62E325C6C4',
#    'url': '',
#    'title': 'Kaymoor Trail closure at Wolf Creek',
#    'parkCode': 'neri',
#    'description': 'The Kaymoor Trail will be temporarily closed from Wolf Creek parking area on Fayette Station Road approximately 1/4 mile up the hill to the bend below Long Point from Monday September 29 through Friday October 3. Contractors will be performing geotechnical drilling to identify potential safety hazards related to underground water.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': 'C3963F67-E61D-4540-A526-9F764480BEDD',
#    'url': '',
#    'title': 'Tour Schedule Change',
#    'parkCode': 'mava',
#    'description': 'Due to a private group tour, there will be no publicly available 3 pm house tour on Thursday October 2, 2025. We apologize for any inconvenience.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': 'ADB74044-4F38-4E26-AD6F-88F4BCCA1F20',
#    'url': 'https://www.nps.gov/grba/planyourvisit/current-projects.htm',
#    'title': 'Lehman Caves Closure - October 20, 2025 to Spring 2026',
#    'parkCode': 'grba',
#    'description': 'Lehman Caves and the Lehman Caves Visitor Center will close to\xa0the public on October 20, as work begins on a six-month, $5.8 million project to replace the cave’s 48-year-old, failing electric lights. Project completion is planned for late spring 2026. The Great Basin Visitor Center and the rest of Great Basin National Park remains open.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '447289B4-619A-4A95-BEB4-0FD817FE190C',
#    'url': '',
#    'title': 'Park Phone Lines Out of Service- To Book Education Programs',
#    'parkCode': 'lowe',
#    'description': 'The Park education program line (978-970-5080) is currently out of service. To learn more about education programs through the Tsongas Industrial History or to book your school field trip today, please call 978-934-4265, email tihc@uml.edu. You can visit www.uml.edu/tsongas for more information.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '1650C0FE-016C-4D80-BD03-D73715A4E1D8',
#    'url': '',
#    'title': 'Tour Schedule Change',
#    'parkCode': 'mava',
#    'description': 'Due to a private group tour, there will be no publicly available 11 am house tour on Thursday October 17, 2025. We apologize for any inconvenience.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '04A84A1A-EF20-4341-B6A7-F6FDEAC8D5AE',
#    'url': '',
#    'title': 'Tour Schedule Change',
#    'parkCode': 'mava',
#    'description': 'Due to a private group tour, there will be no publicly available 11 am house tour on Thursday October 10, 2025. We apologize for any inconvenience.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': 'D9A9DD10-3B81-4982-A6B4-584A050C5E37',
#    'url': 'https://www.nps.gov/blri/planyourvisit/road-construction-projects.htm',
#    'title': 'Ongoing Road Projects and Helene Recovery',
#    'parkCode': 'blri',
#    'description': 'Parkway areas closed for ongoing road maintenance, construction, and Helene recovery projects.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [{'title': 'Ongoing Road Projects and Helene Recovery',
#      'id': 'D9A9DD10-3B81-4982-A6B4-584A050C5E37',
#      'type': 'roadevent',
#      'url': 'https://www.nps.gov/blri/planyourvisit/conditions.htm'}],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '9106B54E-9E68-4058-B3DE-B95AC3F22B1F',
#    'url': 'https://www.nps.gov/cany/planyourvisit/grand_view_point_construction.htm',
#    'title': 'Grand View Point Closed for Construction Weekdays July 28 through September',
#    'parkCode': 'cany',
#    'description': 'Grand View Point Overlook, Grand View Point Trail, and 0.3 mi (0.5 km) of park road is closed Monday to Thursday. The closure applies to all uses, including vehicles, tour buses, motorcycles, bikes, & hikers. Parking is open but limited Friday to Sunday.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': 'C43FA812-4F31-4597-AD48-B102D340F997',
#    'url': 'https://www.nps.gov/mora/planyourvisit/trails-and-backcountry-camp-conditions.htm',
#    'title': 'Naches Peak Trail Closed',
#    'parkCode': 'mora',
#    'description': 'Access is prohibited to Naches Peak Trail to protect public health and safety due to the vicinity of the Wildcat Fire burning outside of the park to the east. Shriner Peak Trail & trailheads on SR 123 between Cayuse Pass and Stevens Canyon Road have reopened as of 9/19/25.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '9444532C-FB52-42F2-956C-E475C5CF73FB',
#    'url': '',
#    'title': 'Delays on Wawona Road (continuation of Highway 41)',
#    'parkCode': 'yose',
#    'description': 'Expect delays on Wawona Road between Yosemite Valley and Wawona from Sundays at 11 pm through Fridays at 4:30 pm until approximately mid-November.',
#    'category': 'Information',
#    'relatedRoadEvents': [{'title': 'Wawona Road Delays',
#      'id': '9444532C-FB52-42F2-956C-E475C5CF73FB',
#      'type': 'roadevent',
#      'url': 'https://www.nps.gov/yose/planyourvisit/conditions.htm'}],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '58E30F52-2D8A-44AE-902D-651FA61A04F4',
#    'url': '',
#    'title': 'Parking Closure of Fort Mason Bay Street Lot Starting September 29, 2025',
#    'parkCode': 'goga',
#    'description': "Bay Street Parking Lot at upper Fort Mason will close to vehicles on September 29. Lot will be closed Fall 2025 through Fall 2026. Lot will be fenced and used as a staging area for utilities project occurring at Fort Mason. Do not park in lot after midnight on September 28, 2025. Vehicles will be towed at owner's expense.",
#    'category': 'Park Closure',
#    'relatedRoadEvents': [{'title': 'Parking Closure of Fort Mason Bay Street Lot Starting September 29, 2025',
#      'id': '58E30F52-2D8A-44AE-902D-651FA61A04F4',
#      'type': 'roadevent',
#      'url': 'https://www.nps.gov/goga/planyourvisit/conditions.htm'}],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '5E8A4127-26B7-445F-849A-0488677FD890',
#    'url': '',
#    'title': 'EV Chargers at Fort Mason Bay Street Lot Offline Week of September 29, 2025',
#    'parkCode': 'goga',
#    'description': 'EV Chargers at Fort Mason Bay Street Lot will be offline during the week of September 29. Chargers are being relocated due to Bay Street Parking Lot closure.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': '789E8DFE-D73E-486E-925F-8CD82634C78C',
#    'url': 'https://www.nps.gov/kefj/learn/news/two-hikers-injured-by-bear-in-kenai-fjords-national-park.htm',
#    'title': 'Exit Glacier Trails and Road Re-Open at 8:00 AM 9/27/2025',
#    'parkCode': 'kefj',
#    'description': 'The trails at Exit Glacier and Kenai Fjords National Park gate on Herman Leirer Road will be closed until re-opening at 8:00 AM 9/27/2025.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-26 00:00:00.0'},
#   {'id': 'FB10585E-5FC6-4944-8C2E-2118DECF5D7C',
#    'url': 'https://www.nps.gov/mabi/planyourvisit/accessibility.htm',
#    'title': 'Alternative and Limited Access During Construction at Park Entrance and Mansion',
#    'parkCode': 'mabi',
#    'description': 'Visitors and vehicles may be temporarily rerouted and wheelchair access into the mansion may be unavailable during construction. Please call the visitor center for additional information if you use a mobility device or need accessible parking.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '199425EB-2593-4F31-8C69-474DED4F5FC6',
#    'url': '',
#    'title': 'Potential delays during stone wall rehabilitation project',
#    'parkCode': 'shen',
#    'description': 'The stone wall that lines Skyline Drive is being rehabilitated between miles 72.8 and 75.7. There will be a single lane closure for the duration of this work, with an established work zone that will be managed by flaggers. Visitors should expect delays.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '9C0563B6-2B0F-496B-82BC-BE394B64BEE3',
#    'url': '',
#    'title': 'Necessary Upgrades Underway at Dickey Ridge Visitor Center in September',
#    'parkCode': 'shen',
#    'description': 'For visitor safety, please avoid the construction area and follow all signage and fencing. Visitor center operations will not be impacted.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': 'EB9C9565-125F-4EFB-B20E-DC9AD1A8E842',
#    'url': 'https://www.nps.gov/calo/learn/news/storm-watch.htm',
#    'title': 'Weather Advisory',
#    'parkCode': 'calo',
#    'description': "Cape Lookout National Seashore is closely monitoring the Atlantic storms. If you're planning to visit the park this weekend or next week, stay alert to changing weather conditions.",
#    'category': 'Danger',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '98CB65BD-C200-47D3-A9FD-B3B452B9DC5D',
#    'url': 'https://www.nps.gov/grsa/planyourvisit/medano-pass-road.htm',
#    'title': 'Medano Pass Primitive Road Impassible to Most Vehicles at Crossing Two',
#    'parkCode': 'grsa',
#    'description': 'Erosion and deep mud near the second creek crossing are making the road impassible to most vehicles. Park road crews are repairing this section. Please check the park website here for updates before your trip.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': 'D0CD7A77-A451-4C33-9870-03D0CF4FAB51',
#    'url': 'https://www.nps.gov/rocr/planyourvisit/scenic-driving-days.htm',
#    'title': 'Beach Drive open for Driving Day on October 11, 2025',
#    'parkCode': 'rocr',
#    'description': 'On October 11, from 11 am to 4 pm, the entire length of Beach Drive in Rock Creek Park will be open for a scenic driving day for visitors who prefer to enjoy the park from their cars. Those who frequently bike or hike in these areas should plan accordingly.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': 'F93E9C9B-1838-4CBF-A85A-A9C466AEDFC4',
#    'url': '',
#    'title': 'Water Availability',
#    'parkCode': 'gicl',
#    'description': "There is NO water at the scorpion campgrounds and the trailhead for the cliff dwellings. Water is available at the Visitor Center, Woody's corral and TJ's corral.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '4F0850D6-ACCE-472F-B601-7C928A02C699',
#    'url': '',
#    'title': 'Burn Scar Flash Flood Risk on NM15 and NM35 to the Dwellings',
#    'parkCode': 'gicl',
#    'description': "Due to the Trout Wildland Fire there is a risk of flash flooding during rain events. there are many low crossings on NM35 be cautious. Turn around don't drown. This risk will likely go on for multiple years.",
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': 'D14CD43E-A8BB-4B37-8193-062ACD132809',
#    'url': '',
#    'title': 'Phone Service Disruption - Charlestown Navy Yard Visitor Center',
#    'parkCode': 'bost',
#    'description': 'We are working on resolving an issue with our phone lines at the Charlestown Navy Yard Visitor Center. To reach the NPS Visitor Center at Faneuil Hall, dial 617-429-6760.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '6938D9EC-204E-4BCB-95D9-E4A7B998179F',
#    'url': '',
#    'title': 'LSR Preserve Construction',
#    'parkCode': 'grte',
#    'description': 'The Laurance S. Rockefeller Preserve parking lot and areas around the Preserve Center will be closed for construction beginning September 23. Use Death Canyon Trailhead to access Phelps Lake.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '8B97962A-CD01-45F9-BBD9-F165A4E0E50E',
#    'url': '',
#    'title': 'William Johnson House Closed Monday',
#    'parkCode': 'natc',
#    'description': 'The William Johnson House will be closed to the public on Monday, September 29, 2025. Electricians will be connecting a new emergency generator at the site and will need to disconnect electricity during installation. We apologize for any inconvenience.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': 'F5520C75-42FC-4498-9551-12146E13A80D',
#    'url': 'https://www.nps.gov/frri/learn/management/superintendents-compendium.htm',
#    'title': "Update to the Superintendent's Compendium",
#    'parkCode': 'frri',
#    'description': 'Freedom Riders National Monument recently updated the Superintendent’s Compendium for 2025. The Compendium is a set of designations, closures, permit requirements, and other restrictions created by the Superintendent to manage the national monument. There were several changes from the previous version especially concerning Filming and Still Photography (Section 1.5), and the designation a Demonstration and First Amendment Site (Section 2.51).',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': 'CA010190-E35C-44DB-8D7F-C5DBDA61D765',
#    'url': 'https://www.nps.gov/bicr/learn/management/superintendents-compendium.htm',
#    'title': "Update to the Superintendent's Compendium",
#    'parkCode': 'bicr',
#    'description': 'Birmingham Civil Rights National Monument recently updated the Superintendent’s Compendium for 2025. The Compendium is a set of designations, closures, permit requirements, and other restrictions created by the Superintendent to manage the national monument. There were several changes from the previous version especially concerning Filming and Still Photography (Section 1.5), and the designation a Demonstration and First Amendment Site (Section 2.51).',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '0C295297-2DE0-4ECC-AD36-9E7E0F1C3920',
#    'url': '',
#    'title': 'Intermitent Road Work',
#    'parkCode': 'foun',
#    'description': 'Visitors should be aware that there is road work occurring in the park starting August 12th and potentially continuing through November. There may be some minor delays and alternative parking arrangements.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '56BFD278-C4DD-47E2-B538-D5B655C316D4',
#    'url': '',
#    'title': 'Visitor Center hours changing on October 1st',
#    'parkCode': 'sagu',
#    'description': 'Starting October 1st, both visitor centers (Red Hills and Rincon Mountain) will revert to Winter Hours, opening at 9am and closing at 5pm. Trails remain open 24 hours a day, and the loop roads are open from dawn to dusk.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-25 00:00:00.0'},
#   {'id': '404981B1-0C90-4DCF-A926-5E7A0AF0CAB5',
#    'url': 'https://www.nps.gov/blri/planyourvisit/roadclosures.htm',
#    'title': 'Possible Hazards in Open Sections',
#    'parkCode': 'blri',
#    'description': 'Parkway areas open after Hurricane Helene may have limited services. Visitors should exercise caution when hiking in or near open areas of the park. Hazards on trails such as landslides, tree debris, and washed-out sections or bridges are possible.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': 'D20834BB-2882-48D9-82E2-296DD0BBDF03',
#    'url': '',
#    'title': 'LiveMap Not Updated',
#    'parkCode': 'blri',
#    'description': 'Due to system issues, the LiveMap is not accurate and does not reflect opening from Milepost 355.3 at the Ridge Junction Overlook near NC 128 to Milepost 382 in Asheville, NC.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '0ECC4397-6B6E-4F11-A62D-D6F30D6025AA',
#    'url': 'https://www.nps.gov/blca/learn/news/south-rim-of-black-canyon-to-open-south-rim-road.htm',
#    'title': 'Park Closures Due to Wildfires',
#    'parkCode': 'blca',
#    'description': 'As of 9/24/2025: South Rim Road and visitor center have reopened. East Portal Road is open. North Rim is open. South Rim Campground, East Portal Campground, and some trails remain closed. Do not enter closed or burned areas until further notice.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '297FA72A-CC77-4803-B8F1-ABB824C9C59A',
#    'url': '',
#    'title': 'Restrooms CLOSED at Visitor Center. Use Restrooms at Dunes Parking.',
#    'parkCode': 'grsa',
#    'description': 'All Restrooms are CLOSED at the visitor center due to construction. Please use the restroom facilities located at the Main Dunes Parking Lot until further notice.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '097494CF-48B5-493A-BFE2-6CE7952EB972',
#    'url': 'https://www.nps.gov/tuin/planyourvisit/george-washington-carver-museum.htm',
#    'title': 'Visitor Pass Needed to Visit George Washington Carver Museum',
#    'parkCode': 'tuin',
#    'description': "All visitors to Tuskegee University, including those visiting the George Washington Carver Museum located on campus, are required to obtain a visitor pass before entering. This policy is part of the university's safety and security procedures. Visitor passes are issued by Tuskegee University Public Safety. Stop by the Campus Public Safety building upon arrival to receive your pass at 1103 West Montgomery Road, Tuskegee, AL 36088.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': 'B37BE0E1-1ECA-40C7-9425-AF5A5BE991FD',
#    'url': '',
#    'title': 'Temporary Museum Closure',
#    'parkCode': 'nisi',
#    'description': 'The park museum in the visitor center will temporarily close on September 28 for the installation of new exhibits. All other areas within the visitor center such as the welcome desk, theater, and bookstore will remain open during the project. The museum will reopen in November with the official ribbon cutting event being announced at a later date.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': 'DD70ECD9-3888-4DCC-9CC5-6C5D7BE668DD',
#    'url': '',
#    'title': 'Trail update 9/24/2025',
#    'parkCode': 'nisi',
#    'description': 'Most trails are open and ready for the public. Those that remain closed are the Charleston Road/ Goudey Trail past the Cherokee Path and the portion of Cherokee Path between the stockade fort and the Charleston Road.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': 'A2D756E8-11E0-42AE-86F8-44817692E680',
#    'url': '',
#    'title': 'Equestrian Trail Update 9/24/2025',
#    'parkCode': 'nisi',
#    'description': 'An equestrian bridge on the north side of the park is closed. All other equestrian trails are open.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '93EA9483-5276-401C-A1AB-EDF6EC700CD0',
#    'url': '',
#    'title': 'Construction work in the Taggart area',
#    'parkCode': 'grte',
#    'description': 'Construction work is underway near Taggart Lake Trailhead to bury power lines. Pathway users should expect short delays, detours, and construction equipment in the area. The Taggart Trail bridge is under repair. Through mid-October, use the bypass along the corral road. Sept. 22–29, all hikers will be rerouted to the south segment of the Taggart Lake Loop Trail while crews remove boulders.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': 'D1F9402C-4017-480D-8969-B4F661CB2753',
#    'url': 'https://www.nps.gov/piro/learn/news/09-24-2025-sand-point-rd-closure.htm',
#    'title': 'Sand Point Road Closed Oct. 2 - 8',
#    'parkCode': 'piro',
#    'description': 'Sand Point Road will be temporarily closed to all vehicle and pedestrian traffic east of the Pictured Rocks National Lakeshore boundary from approximately\xa0Oct. 2 through Oct. 8, 2025, for a culvert replacement project. The closure may extend through Oct. 10 if additional time is needed to complete the work.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': 'C17E64D1-5BB5-44D8-8CCD-A888F3EC278C',
#    'url': '',
#    'title': 'East Portal Road Reopened: Use Caution',
#    'parkCode': 'cure',
#    'description': 'During periods of rain or other precipitation, visitors are encouraged to leave East Portal promptly due to an increased risk of landslides in burned areas along East Portal Road. Please stay alert to changing weather conditions and use caution when traveling in the area.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '53C1D112-AA2F-4463-9EB3-EF16C3DFE433',
#    'url': '',
#    'title': 'East Portal Road Reopened: Use Caution',
#    'parkCode': 'blca',
#    'description': 'During periods of rain or other precipitation, visitors are encouraged to leave East Portal promptly due to an increased risk of landslides in burned areas along East Portal Road. Please stay alert to changing weather conditions and use caution when traveling in the area.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '682E96E0-BEEB-4878-B7F0-BE1B1D348723',
#    'url': '',
#    'title': 'Seasonal Summer Closures and Fire Restrictions',
#    'parkCode': 'jotr',
#    'description': 'As part of its seasonal operations, the park is implementing the routine summer closure of select campgrounds. Parkwide fire restrictions are in effect from June 15 until October 1. No open fires.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '7291B9AA-F7FA-4C5D-AD9A-A263C4381EEB',
#    'url': '',
#    'title': '49 Palms Closed Due to Storm Damage',
#    'parkCode': 'jotr',
#    'description': 'The trail will remain closed until November 7 while trail and road crews remove debris and ensure the trail is safe for visitor use',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-24 00:00:00.0'},
#   {'id': '12C2F359-A9EC-4279-83FF-A8BB13F71643',
#    'url': '',
#    'title': '9/11/2025 North Gorge Reopened',
#    'parkCode': 'laro',
#    'description': 'Effective immediately, North Gorge campground and boat launch are open to the public.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-23 00:00:00.0'},
#   {'id': 'BE7256F7-5FE4-4022-A99E-06E6BF6D6E52',
#    'url': '',
#    'title': 'Faneuil Hall Great Hall - Elevator Out of Service',
#    'parkCode': 'bost',
#    'description': 'The elevator in Faneuil Hall is temporarily out of service. We hope to have it fixed as soon as possible. If you have any questions, or if you need access to bathrooms, please inform one of the on-site Rangers or call 617-429-6760.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-23 00:00:00.0'},
#   {'id': 'AC7FF262-B2C5-41FD-A982-CD8FA491B106',
#    'url': 'https://www.nps.gov/fosc/learn/photosmultimedia/360tours.htm',
#    'title': 'Some Park Buildings are Temporarily Closed for Maintenance',
#    'parkCode': 'fosc',
#    'description': "Some park buildings are temporarily closed to clean up after the Fire Suppression System replacement. Closed are Officer's Quarters #2 and some of the Dragoon Barracks, A virtual tour link below.",
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-23 00:00:00.0'},
#   {'id': 'F9411EAE-4E94-433B-882D-D9DDC4514583',
#    'url': 'https://www.maine.gov/dacf/mfs/wildfire_danger_report/index.html',
#    'title': 'High Fire Danger',
#    'parkCode': 'kaww',
#    'description': 'The monument is currently under a high fire danger warning issued by the Maine Forest Service. Please exercise caution when lighting a fire, and make sure the fire is completely out before leaving. Fires are allowed in designated areas only.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': 'EEFA5B2C-2B4D-462B-BDFA-72ACA962AAF6',
#    'url': 'https://www.nps.gov/choh/planyourvisit/byron-bridge.htm',
#    'title': 'Bridge access to Maryland Heights Trail CLOSED',
#    'parkCode': 'hafe',
#    'description': 'The NPS will rehabilitate the stairway connecting the Goodloe Byron Memorial Footbridge to the C&O Canal NHP towpath. The stairway is CLOSED for approximately two weeks beginning September 22 while crews build a temporary stairwell. During that time, a shuttle will run between C&O Canal Lock 34 and Harpers Ferry National Historical Park Visitor Center. This will impact access to Maryland Heights, the Appalachian NST, and the Potomac Heritage NST.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '7C22A293-B110-455B-B5A6-9F5B67068487',
#    'url': 'https://www.nps.gov/tuin/learn/management/superintendent-s-compendium.htm',
#    'title': 'New Policy on Fires and Lighting',
#    'parkCode': 'tuin',
#    'description': "Please be advised that a new policy is now in effect regarding the lighting and maintaining of fires within the park. To read the full details, including specific regulations and guidelines, please refer to the Superintendent's Compendium.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '6C003D5A-53F4-4FA0-86FE-C01942D34418',
#    'url': '',
#    'title': 'Limited Restroom Availability',
#    'parkCode': 'inde',
#    'description': 'Restrooms are available at the Independence Visitor Center at 6th & Market Streets, the corner of 5th and Chestnut Streets, and the Benjamin Franklin Museum (museum entrance requires a fee) in Franklin Court.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '4717AF74-9DEE-45BE-B77C-DA28493B451A',
#    'url': 'https://www.nps.gov/tuai/learn/management/superintendent-s-compendium.htm',
#    'title': 'New Policy on Fires and Lighting',
#    'parkCode': 'tuai',
#    'description': "Please be advised that a new policy is now in effect regarding the lighting and maintaining of fires within the park. To read the full details, including specific regulations and guidelines, please refer to the Superintendent's Compendium.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '800234DB-9C92-434E-B583-3CC8DEF65B5A',
#    'url': 'https://www.nps.gov/deva/planyourvisit/conditions.htm',
#    'title': 'Many Roads Closed due to Flooding',
#    'parkCode': 'deva',
#    'description': 'Badwater Road, North Highway, and some other roads are still closed due to damage by flash floods on 9/19/2025. Click "More" for a full list of closures.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '4F723F8A-E097-4924-AB69-E2900B19EBAC',
#    'url': '',
#    'title': 'Phones are Inoperable',
#    'parkCode': 'cave',
#    'description': 'We are currently unable to return phone calls at Carlsbad Caverns National Park because our phone system is down. We apologize for the inconvenience and ask you to reach out to us at our email CAVE_Park_information@nps.gov with any questions you may have',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '24C18EF8-175C-4102-8F5E-8C6AF2EC0363',
#    'url': '',
#    'title': 'Elk Creek Visitor Center temporary closure',
#    'parkCode': 'cure',
#    'description': 'The Elk Creek Visitor Center will be closed from September 21 to October 1 for installation of new exhibits. During winter hours, staff will be present in the visitor center parking lot while installation is in progress.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': 'FF358624-59A9-4291-8ACD-59559EA6FBF3',
#    'url': '',
#    'title': 'Tree Thinning Project Will Cause Short Delays Starting September 28, 2025',
#    'parkCode': 'wica',
#    'description': 'Expect one-way traffic with short delays along Highways 87 and 385 while contractors remove pine saplings to improve visibility and safety along roadways. A pilot car will lead vehicles through the project area. The project begins on Sunday, September 28, and continues until complete.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '404D3582-2744-48DD-9859-E7F8D47AE7A6',
#    'url': 'https://www.nps.gov/goga/planyourvisit/maps.htm',
#    'title': 'Temporary Closure of Fort Mason Restrooms Until October 17, 2025',
#    'parkCode': 'goga',
#    'description': 'Great Meadow restrooms will be closed for renovation. Portable restrooms are available on site. Additional restrooms are available near East Beach and Presidio Tunnel Tops. See map link below to see restroom locations.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2025-09-22 00:00:00.0'},
#   {'id': '62EA44A1-7210-4B0E-B5D1-CC1E37531265',
#    'url': '',
#    'title': 'Reduced cold-water flow at the Serpentine Hot Springs bathhouse',
#    'parkCode': 'bela',
# ...
#    'url': 'https://www.nps.gov/badl/planyourvisit/directions.htm',
#    'title': 'Navigation',
#    'parkCode': 'badl',
#    'description': 'Do not rely on GPS digital navigation systems to find your way to Badlands National Park. Please note that the Visitor Center at 25216 Ben Reifel Road, Interior SD 57750 is located just off I-90.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-12-16 09:25:24.0'},
#   {'id': '7E88CFCF-AB2C-4551-9727-A91514543BC0',
#    'url': 'https://iceagetrail.maps.arcgis.com/apps/opsdashboard/index.html#/5cb8ca63f0e447dea9dc29afb5ed12e6',
#    'title': 'Trail Conditions',
#    'parkCode': 'iatr',
#    'description': 'Trail conditions can vary throughout the state. Before heading out, check the trail conditions, potential re-routes and closures on the Ice Age Trail Alliance website.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-10-23 14:28:03.0'},
#   {'id': '1F91438F-5FE5-4E40-BBB3-7A9B265AA7EE',
#    'url': 'https://www.nps.gov/juba/learn/news/anza-exhibit-at-martinez-adobe-closed-for-structural-repairs.htm',
#    'title': 'Closure of Anza Expedition Exhibit at Martinez Adobe in Martinez, CA',
#    'parkCode': 'juba',
#    'description': 'For safety reasons, access to the Martinez Adobe, which houses the Anza exhibit, is blocked off from the public and remains closed for all use until the structure is stabilized. Currently, there is no timeline for the repairs to be complete...',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-09-28 17:29:18.0'},
#   {'id': '2B0C77D1-2B6D-4BFF-B712-80098F9257FC',
#    'url': '',
#    'title': 'What To Know Before You Visit',
#    'parkCode': 'popo',
#    'description': "Park grounds and visitor center are open, but you're encouraged to call the visitor center at 318-926-5492 for the latest information and COVID-19 precautions before you visit.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-07-20 13:22:54.0'},
#   {'id': '9B4FEB70-4E5A-4C7B-A3AB-F5C6A923870C',
#    'url': '',
#    'title': 'Motorized Recreational Scooters Not Permitted in Park',
#    'parkCode': 'fomc',
#    'description': 'For the safety and protection of visitors and park resources, motorized scooters are not permitted within the park. Any vehicles (scooters, bicycles, etc.) that are part of a ride-share program may not be left behind for pick up inside the park',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-06-08 08:37:13.0'},
#   {'id': 'BA77C3A9-15D9-4139-9DB0-B2E75ADFBB4D',
#    'url': '',
#    'title': 'Be Prepared for your Visit',
#    'parkCode': 'mocr',
#    'description': 'Before hiking at Moores Creek, make sure to bring all your necessary medications, sunscreen, bottled water for hikes, loose fitting clothes for hiking, and any other items you may need.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-05-27 09:43:21.0'},
#   {'id': '0CCEB613-6423-4271-B64C-BD953E8421CA',
#    'url': 'https://www.nps.gov/choh/planyourvisit/conditions.htm',
#    'title': 'Closures: Detours; Towpath; Points of Interest',
#    'parkCode': 'choh',
#    'description': 'Multiple items are closed due to hazardous conditions or maintenance. See below for more details.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2020-02-15 08:53:01.0'},
#   {'id': '12A30328-BB76-4826-9315-69220824E33B',
#    'url': '',
#    'title': 'Bicycle Use In The Monument',
#    'parkCode': 'petr',
#    'description': 'Bicycles are ONLY allowed at the following locations: 1 - On the Boca Negra Canyon paved multiuse path; bicycles must remain on the paved bike path. 2 - On the crusher fine trail that winds in and out of the park around the mesa top above Boca Negra.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2019-12-03 14:57:43.0'},
#   {'id': '9A365014-CBA7-45E4-95E6-F8F0A13D35A8',
#    'url': 'https://www.nps.gov/natr/learn/news/yockanookany-section-trail-closure.htm',
#    'title': 'Yockanookany Trail Section Closed to Equestrians',
#    'parkCode': 'natt',
#    'description': 'The Yockanookany section of the Natchez Trace National Scenic Trail is closed to equestrian use effective immediately, due to safety concerns with trail bridges and boardwalks. The trail will remain open to pedestrians.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2019-10-26 11:08:59.0'},
#   {'id': 'B171D571-FE0E-4920-B8B4-5C35D646DD4F',
#    'url': '',
#    'title': 'Notice to travelers to National Cemetery',
#    'parkCode': 'anjo',
#    'description': 'Due to the narrow roadway & tight turn, RVs, mobile homes, charter buses, delivery trucks, or vehicles with trailers are prohibited from the crest of Monument Hill. Check for information about parking at the Visitor Center upon your arrival.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2019-08-12 15:39:35.0'},
#   {'id': '87F12777-F902-4017-8783-2A28241A0458',
#    'url': '',
#    'title': 'RV and Tractor Trailer Parking at the Visitor Center',
#    'parkCode': 'whsa',
#    'description': 'There is limited space for parking for recreational vehicles and trailers in the parking lot directly in front (south) of the visitor center. RVs are asked to not park in the lot behind the visitor center. There is no parking space for tractor trailers.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2019-02-05 14:36:01.0'},
#   {'id': 'D2043EA0-DF82-46FB-B3A1-6CECDD141B8D',
#    'url': '',
#    'title': 'Federal Government Shutdown',
#    'parkCode': 'opot',
#    'description': 'During the federal government shutdown, this website will not be updated and may not reflect current conditions. The tour of the Old Post Office Tower is closed for resource protection and safety.',
#    'category': 'Park Closure',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2018-12-22 11:01:55.0'},
#   {'id': 'DD4E164C-89A7-47B0-B6D8-937134DC52C5',
#    'url': 'https://www.nps.gov/ulsg/planyourvisit/directions.htm',
#    'title': 'GPS Navigation Systems',
#    'parkCode': 'ulsg',
#    'description': "GPS navigation systems often misdirect visitors driving to Ulysses S. Grant National Historic Site. GPS systems often route visitors to our back gate, or to the entrance for Grant's Farm (not affiliated with the NPS). Please visit our directions page.",
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2018-12-05 18:00:27.0'},
#   {'id': '59BA228E-ACAE-4A57-AD4F-CC9E6AFD54E4',
#    'url': '',
#    'title': 'Footwear in the Cavern',
#    'parkCode': 'cave',
#    'description': 'For safety, closed-toe shoes with good traction are recommended. Flip flops, sandals, and some walking shoes have little or no traction and increase the possibility of slips, trips, and falls. Watch your step and use the handrails when necessary.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2018-09-19 18:25:10.0'},
#   {'id': 'EA0AC8A8-A54E-4BB8-A3E8-C118F912876B',
#    'url': 'https://www.nps.gov/laro/planyourvisit/boating.htm',
#    'title': 'Warning to All Watercraft',
#    'parkCode': 'laro',
#    'description': 'These waters may be used as a water source for firefighting aircraft. When aircraft approach at low altitudes, please clear the center of the lake.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2018-07-24 18:14:51.0'},
#   {'id': '0EA570B2-2FF0-4B33-AD3A-1313385965A0',
#    'url': 'https://www.nps.gov/zion/planyourvisit/index.htm',
#    'title': 'Please park legally and responsibly in Zion National Park and the Town of Springdale',
#    'parkCode': 'zion',
#    'description': 'Zion has limited parking space. Park only in designated stalls. Vehicles parked outside of designated stalls are subject to citation and may be towed. Once all designated parking stalls in Zion are full, visitors should park in Springdale.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2018-05-18 14:28:24.0'},
#   {'id': 'D992F239-4C85-45CE-B471-5107FEC177B2',
#    'url': 'https://www.nps.gov/chis/planyourvisit/conditions.htm',
#    'title': 'Santa Barbara Island Dock Closed; Landings Restricted to Adjacent Rocky Ledge',
#    'parkCode': 'chis',
#    'description': 'Santa Barbara Island is open to public access, but landings are restricted to the rocky ledge adjacent to the dock. The dock is closed and is not expected to be repaired in the near future due to the severe winter storm damage.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2018-01-23 14:42:10.0'},
#   {'id': '0FC3E803-182D-4F93-B872-2E3277445A72',
#    'url': '',
#    'title': 'Arrival by Boat',
#    'parkCode': 'kala',
#    'description': 'It is prohibited to come within 1/4 mile of the Kalaupapa shoreline. Access by boat within the quarter mile offshore park boundary requires a special use permit.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2017-09-21 18:06:38.0'},
#   {'id': '7D5830C9-8EED-4C56-B4EC-CA0130205AE5',
#    'url': '',
#    'title': 'Garden Key Harbor Light',
#    'parkCode': 'drto',
#    'description': 'Vessel operators - the Garden Key Harbor Light is undergoing repairs and is extinguished. At this time it is unknown when the light will again be illuminated.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2017-08-17 14:16:47.0'},
#   {'id': '07FA0182-FE82-4689-9355-B863754A45A9',
#    'url': 'https://www.nps.gov/mimi/planyourvisit/directions.htm',
#    'title': 'Warning about GPS Systems!',
#    'parkCode': 'mimi',
#    'description': 'Vehicle Navigation Systems and GPS units may provide inaccurate information—sending drivers the wrong way on one-way roads, leading them to dead ends in remote areas, or sending them on roads which are impassable. Use the Interstate exits for wayfinding.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2017-08-02 08:27:14.0'},
#   {'id': 'DEEF1D1E-E2AE-4CE7-AD53-70E7F876070B',
#    'url': '',
#    'title': 'Life Jackets Required!',
#    'parkCode': 'niob',
#    'description': 'By Nebraska State law, all children 12 years old and younger must WEAR a USCG approved life jacket to float the Niobrara NSR. Anyone over 12 years old must HAVE a life jacket. If you are renting equipment, your outfitter will provide them.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2017-03-09 15:41:43.0'},
#   {'id': '029622AA-F8C4-40E2-99C1-13479E55D4ED',
#    'url': '',
#    'title': 'Test Alert',
#    'parkCode': 'inau',
#    'description': 'Test Alert',
#    'category': 'Danger',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2017-03-08 10:04:12.0'},
#   {'id': '7D2EBFB8-4ACF-498E-B6E7-E4E50D4649A7',
#    'url': 'https://www.nps.gov/crmo/planyourvisit/directions.htm',
#    'title': 'Navigation',
#    'parkCode': 'crmo',
#    'description': 'Please do not rely upon GPS digital navigation systems to find your way to Craters of the Moon. Please note that the Visitor Center at 1266 Craters Loop Road is located just off U.S. Highway 20/26/93 and is not accessed via any unpaved roads.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2017-01-13 08:33:59.0'},
#   {'id': 'D48614E4-5A1C-470D-9410-AF1BAEF62D29',
#    'url': 'https://www.nps.gov/mimi/planyourvisit/launch-control-facility-delta-01-tours-and-tickets.htm',
#    'title': 'Delta-01 Tour Fee and Reservations',
#    'parkCode': 'mimi',
#    'description': 'All Delta-01 Launch Control Facility Tours require advanced reservations. Reservations can be made up to 90 days in advance on-line or by phone at 605-717-7629. No SAME-DAY tours available during the summer season.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-10-25 10:53:44.0'},
#   {'id': '41955910-CBC1-4A0A-B3B6-6749C6D6FF39',
#    'url': 'https://www.nps.gov/policy/PolMemos/PM_14-05.htm',
#    'title': 'The Use of Drones is Prohibited at Big South Fork National River & Recreation Area',
#    'parkCode': 'biso',
#    'description': 'Currently, the use of drones is prohibited at Big South Fork and all National Parks. Detailed information about the policy is available...',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-06-12 09:50:45.0'},
#   {'id': 'B7FA217E-29E4-4FF9-87DD-45C07E0D86B4',
#    'url': 'https://www.nps.gov/labe/planyourvisit/caving.htm',
#    'title': 'White-Nose Syndrome / Cave Permit',
#    'parkCode': 'labe',
#    'description': 'Please Do Not bring clothing or caving gear used in caves or mines outside of Lava Beds into our caves. This will help slow the spread of white-nose syndrome, a bat disease that is killing bats outside of the park.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-05-19 15:48:28.0'},
#   {'id': '6B262C5A-387C-4AAE-B3A4-31461DB05D04',
#    'url': 'https://www.nps.gov/biso/planyourvisit/firewood-quarantine.htm',
#    'title': 'Firewood ban is in effect for the park.',
#    'parkCode': 'biso',
#    'description': 'Firewood ban is in effect for the park. Only firewood from the surrounding counties of Scott, Morgan, Pickett, and Fentress, in Tennessee, and McCreary in Kentucky, can be brought into the park. Firewood is for sale or you may use dead and down wood.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-04-20 08:21:16.0'},
#   {'id': '2F92DCC9-55CD-440F-A35C-8B08AA1558B5',
#    'url': 'https://www.nps.gov/biso/learn/nature/blackbear.htm',
#    'title': 'Black Bears at Big South Fork',
#    'parkCode': 'biso',
#    'description': 'Black bears call Big South Fork NRRA home. Help keep them healthy and safe by storing all food, cooking items, feed, cosmetics and coolers properly stored when at campgrounds or in the backcountry.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-04-12 17:35:48.0'},
#   {'id': '5033D82A-CDFE-4756-B726-2EEB52552CF7',
#    'url': '',
#    'title': 'Unmanned Aircraft',
#    'parkCode': 'kala',
#    'description': 'Launching, landing, or operating an unmanned aircraft from or on lands and waters administered by the National Park Service within the boundaries of Kalaupapa National Historical Park is prohibited. This includes model airplanes, quadcopters, and drones.',
#    'category': 'Information',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-03-31 14:47:23.0'},
#   {'id': 'B4D4660E-26C1-4E36-AB27-463EF41D522D',
#    'url': '',
#    'title': 'General Mosquito Information',
#    'parkCode': 'npsa',
#    'description': 'Although there is no known current transmission of dengue, Zika, or chikungunya, American Samoa has had recent outbreaks, and reintroduction is possible. Avoid mosquito bites and report to your doctor if you get sick within two weeks of returning.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-03-30 20:34:26.0'},
#   {'id': '11465413-C4F3-441C-BFF9-BEB55AB9052D',
#    'url': '',
#    'title': 'Vehicle Break-Ins: Take precautions to secure your vehicle and valuables.',
#    'parkCode': 'petr',
#    'description': "This is an urban park. Don't hide valuables inside your car. Carry items with you on hike. Lock your vehicle and set car alarm. Recent auto break-ins at Rinconada Canyon parking lot. Report suspicious persons loitering/peeking in cars. Call 928-638-7805",
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2016-01-28 11:38:51.0'},
#   {'id': 'FA92ED3E-3FA3-41C9-A166-5064DDA98044',
#    'url': '',
#    'title': 'Be Aware of Break-ins along State Route 20',
#    'parkCode': 'noca',
#    'description': 'Prevent smashed windows and theft. Break-ins are not uncommon at trailheads along State Route 20. Remove your valuables and electronics and take associated electronic cords.',
#    'category': 'Caution',
#    'relatedRoadEvents': [],
#    'lastIndexedDate': '2015-05-21 11:19:27.0'}]}

# %%
for x in alerts_json['data']:
    print(data)

# %%
df = pd.json_normalize(alerts_json)

df
# Out:
#   total limit start                                               data
# 0   726  1000     0  [{'id': '17B42D3F-84E4-4B78-900F-670C9D625658'...

# %%
df2 = pd.json_normalize(df['data'])

df2
# Out:
#                                                  0    \
# 0  {'id': '17B42D3F-84E4-4B78-900F-670C9D625658',...
#
#                                                  1    \
# 0  {'id': '872E3239-CDB2-4E89-8F57-1C87EC3FC3FE',...
#
#                                                  2    \
# 0  {'id': '3396D6D3-5F44-4532-B48B-42A629991493',...
#
#                                                  3    \
# 0  {'id': '2CF15EBC-0800-4DF3-8179-B1579B6D4F57',...
#
#                                                  4    \
# 0  {'id': 'F43C6435-4C08-4DF8-B1DD-C92B68C9E805',...
#
#                                                  5    \
# 0  {'id': '3E4B8C08-23A0-4F40-B290-53BB4959E6CD',...
#
#                                                  6    \
# 0  {'id': '6EC20CC5-4731-4E02-BDE1-AC5330C09182',...
#
#                                                  7    \
# 0  {'id': '3032989A-A3CF-4ED8-B80F-FB84A828D76B',...
#
#                                                  8    \
# 0  {'id': 'B500783E-4014-4447-A7A0-5EED9674D710',...
#
#                                                  9    ...  \
# 0  {'id': '36736D3B-B300-4DD0-B546-67C6374A7E1B',...  ...
#
#                                                  716  \
# 0  {'id': '7D2EBFB8-4ACF-498E-B6E7-E4E50D4649A7',...
#
#                                                  717  \
# 0  {'id': 'D48614E4-5A1C-470D-9410-AF1BAEF62D29',...
#
#                                                  718  \
# 0  {'id': '41955910-CBC1-4A0A-B3B6-6749C6D6FF39',...
#
#                                                  719  \
# 0  {'id': 'B7FA217E-29E4-4FF9-87DD-45C07E0D86B4',...
#
#                                                  720  \
# 0  {'id': '6B262C5A-387C-4AAE-B3A4-31461DB05D04',...
#
#                                                  721  \
# 0  {'id': '2F92DCC9-55CD-440F-A35C-8B08AA1558B5',...
#
#                                                  722  \
# 0  {'id': '5033D82A-CDFE-4756-B726-2EEB52552CF7',...
#
#                                                  723  \
# 0  {'id': 'B4D4660E-26C1-4E36-AB27-463EF41D522D',...
#
#                                                  724  \
# 0  {'id': '11465413-C4F3-441C-BFF9-BEB55AB9052D',...
#
#                                                  725
# 0  {'id': 'FA92ED3E-3FA3-41C9-A166-5064DDA98044',...
#
# [1 rows x 726 columns]

# %%
id_list = []
url_list = []
title_list = []
parkCode_list = []
description_list = []
category_list = []
relatedRoadEvents_list = []
lastIndexedDate_list = []

for x in df['data']:
    #print(x)
    id_list.append(x['id'])
    url_list.append(x['url']) 
    title_list.append(x['title']) 
    parkCode_list.append(x['parkCode'].upper()) 
    description_list.append(x['description'])
    category_list.append(x['category']) 
    relatedRoadEvents_list.append(x['relatedRoadEvents'])
    lastIndexedDate_list.append(x['lastIndexedDate'])

alerts_df = pd.DataFrame({
    'id': id_list, 
    'url': url_list, 
    'title': title_list,
    'park alpha': parkCode_list,
    'description': description_list,
    'category': category_list,
    'relatedRoadEvents':relatedRoadEvents_list,
    'LastIndexedDate':lastIndexedDate_list
})
