# %%
#import packages
import requests
import json
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
path = "Park Unit Scraping Information.csv"
parks = pd.read_csv(path, encoding='latin-1')
parks.head()
# Out:
#                     Park Name  \
# 0  Abraham Lincoln Birthplace
# 1                      Acadia
# 2                       Adams
# 3       African Burial Ground
# 4           Agate Fossil Beds
#
#                                       Park Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#                Type of Unit State  Reg Alpha  Unit
# 0  National Historical Park    KY  SER  ABLI   1.0
# 1             National Park    ME  NER  ACAD   1.0
# 2  National Historical Park    MA  NER  ADAM   1.0
# 3         National Monument    NY  NER  AFBG   1.0
# 4         National Monument    NE  MWR  AGFO   1.0

# %%
#pull API using API key
response_API = requests.get('https://developer.nps.gov/api/v1/alerts?limit=1000&api_key=3AidKP0PiqgfP8sbwZC0RZ9JM6QDnvYaZx3RRjrH')
#print(response_API.status_code)
data = response_API.text
df = json.loads(data)

# %%
id_list = []
url_list = []
title_list = []
parkCode_list = []
description_list = []
category_list = []
relatedRoadEvents_list = []
lastIndexedDate_list = []

for x in df['data']:
    #print(x)
    id_list.append(x['id'])
    url_list.append(x['url']) 
    title_list.append(x['title']) 
    parkCode_list.append(x['parkCode'].upper()) 
    description_list.append(x['description'])
    category_list.append(x['category']) 
    relatedRoadEvents_list.append(x['relatedRoadEvents'])
    lastIndexedDate_list.append(x['lastIndexedDate'])

# %%
alerts_df = pd.DataFrame({
    'id': id_list, 
    'url': url_list, 
    'title': title_list,
    'park alpha': parkCode_list,
    'description': description_list,
    'category': category_list,
    'relatedRoadEvents':relatedRoadEvents_list,
    'LastIndexedDate':lastIndexedDate_list
})

# %%
alerts_df.head()
# Out:
#                                      id  \
# 0  1CC5DA87-2D0C-4E51-B88C-DB49B7F38957
# 1  D343DB17-FB31-4953-AC43-957033416C4B
# 2  75487057-E4F6-4A96-9E5F-71A40F272B2F
# 3  82666CCF-577D-4717-9BE5-9E42431B1490
# 4  B090C622-C867-4B23-9250-F0EBF3B5642D
#
#                                                  url  \
# 0
# 1  https://www.nps.gov/grca/planyourvisit/grand-c...
# 2  https://www.nps.gov/grca/planyourvisit/weather...
# 3
# 4
#
#                                                title park alpha  \
# 0                 April 15, 2024: Summer Hours Begin       STEA
# 1  What's Closed and What's Open? (Park Operation...       GRCA
# 2  Thursday, March 21, 2024 - Mostly Sunny Today ...       GRCA
# 3                         Prescribed Fire Operations       EVER
# 4                                       Road Closure       SHEN
#
#                                          description      category  \
# 0  Effective Monday, April 15, Steamtown NHS will...   Information
# 1  Visitor Center is OPEN from 10 am to 4 pm. Ran...  Park Closure
# 2  Bright Angel Trail, Plateau Pt. and Tonto Trai...  Park Closure
# 3  Due to recent prescribed fire operations north...       Caution
# 4  Skyline Drive is closed northbound from Thornt...  Park Closure
#
#                                    relatedRoadEvents        LastIndexedDate
# 0                                                 []  2024-03-21 08:39:02.0
# 1                                                 []  2024-03-21 00:02:31.0
# 2                                                 []  2024-03-21 00:00:41.0
# 3                                                 []  2024-03-20 20:27:48.0
# 4  [{'title': 'Thornton Gap Entrance Station to M...  2024-03-20 20:08:33.0

# %%
alerts_df.category.value_counts()
# Out:
# Information     352
# Park Closure    202
# Caution         118
# Danger           22
#                   2
# Name: category, dtype: int64

# %%
counter = 0
road_closed_list = []

for x in range(0,len(alerts_df)):
    road_closed = 0
    if "lane closure" in str(alerts_df['description'][x]).lower():
        road_closed = 1
    if "road closure" in str(alerts_df['description'][x]).lower():
        road_closed = 1
    if "road closed" in str(alerts_df['description'][x]).lower():
        road_closed = 1
    if "road is closed" in str(alerts_df['description'][x]).lower():
        road_closed = 1
    if ("road" in str(alerts_df['description'][x]).lower())&("closed" in str(alerts_df['description'][x]).lower()):
        road_closed=1
    road_closed_list.append(road_closed)

    if road_closed == 1:
        print(alerts_df['park alpha'][x])
        print(alerts_df['description'][x])
        counter +=1

alerts_df['road_closed_flag'] = road_closed_list
# Out:
# GRTE
# Spring Plowing has begun on the Teton Park Road. For safety reasons, visitors may NOT access the Teton Park Road while rotary snow removal equipment and plows are working; the roadway is closed to ALL users during this time.
# GRTE
# Portions of the Teton Park Road (Taggart Lake TH to Signal Mt.), Moose-Wilson Road (Granite Canyon TH to Death Canyon Road), and other roads are closed to vehicles. Check the Grand Teton Roads page for the latest seasonal and weather related closures.
# JOTR
# Due to recent rains, the following dirt roads are temporarily closed: Big Horn Pass Road, Queen Vally Road, Keys Ranch Road, and O'Dell Road.
# OLYM
# Hurricane Ridge Road remains closed Monday through Thursday during the winter season. The road is scheduled to reopen Friday, March 22nd, weather permitting.
# PRWI
# Scenic Drive will be closed from dawn (6:30am) until around 11:00am. Oak Ridge Campground will be completely inaccessible for vehicles entering or leaving during this time. Parking Lots A, B, C, and D will remain open. Road re-opens at 11:00am.
# YELL
# Spring plowing has begun and most roads are closed to all vehicles until mid-April. The road between the North and Northeast entrances remains open and is open year-round to regular vehicles.
# SEKI
# It is still winter in the mountains, and some roads remain under a seasonal closure. To see which roads are closed, click on the "more" link:
# SCBL
# The Scotts Bluff Summit Road will be closed during the morning of Wednesday, March 20, 2024, for an inspection of the roadway surfaces, retaining walls and drainage systems. We anticipate a noon opening on that day.
# CORO
# Grading operations will be taking place on Montezuma Canyon Rd on March 18-21, 2024. Foot, bicycle, and ATV/UTV traffic are not permitted on the closed portions of the road during this time. The park grounds, trails, and visitor center will remain open.
# GRSM
# Due to snow, ice, and other hazardous weather events, many park roads are closed in the winter season.
# JAME
# Beginning Monday, August 14, 2023, construction will close the Colonial Parkway from Ballard Street in Yorktown to Fusiliers Road, which will remain open. The Route 17 access ramps will be closed. This segment may remain closed through Winter 2024/2025.
# CACO
# Between 3/11-4/20, the Pilgrim Heights parking area and access roadways in Truro will be temporarily closed to allow for repaving and survey work. 24-hour vehicle and pedestrian closures will be in place during this time.
# LAMR
# Blue West and Fritch Fortress are closed to the visiting public due to road construction. There is no public access.
# YOSE
# Tioga Road (continuation of Highway 120 through the park) and Glacier Point Road are closed for the season due to snow. They usually open in late May or June. Call 209/372-0200 (then 1, 1) for road conditions and tire chain requirements.
# ALFL
# Cas Johnson Road, McBride Canyon, Mullinaw, and Alibates Road are all closed.
# MOJA
# Cima Road between Kelso Cima Road in Cima and Interstate 15 along the north preserve boundary is CLOSED to all vehicles. Please do not drive around barricades, or cross this active construction zone in the Cima Dome area.
# NOCA
# Cascade River Road is closed for the winter season at milepost 20 (El Dorado parking lot), three miles before the trailhead.
# CANY
# The unpaved Elephant Hill Access Road and trailhead parking lot will close temporarily for necessary road maintenance on March 21, 2024. The road and parking lot will be closed to all uses until the work is complete, which should be later that same day.
# BUFF
# In the interest of safety, the South Woolum Road has been closed. The Woolum launch and campground remain open.
# GRBA
# The Wheeler Peak Scenic Drive is closed for the season at mile three near the Upper Lehman Campground. Baker Creek Road will close intermittently with snowfall. Both the Snake Creek and Strawberry Creek Roads are closed for the season.
# PISC
# The Marshall Hall Access Road is closed due to construction. This road connects the Marshall Hall ruins to Marshall Hall Rd. The main road remains open.
# MIMA
# Battle Road Trail between Olive Stow Boardwalk to Shadyside Avenue and Lexington Road is closed until late Spring 2024. This will allow for the completion of a trail re-route. Entering closures is prohibited. Please plan accordingly.
# FODO
# Fort Heiman is located at 682 Fort Heiman Road, New Concord KY. Due to poor conditions of county roads, the County has posted the loop road closed to vehicles past the park pavilion. Pedestrian access is permitted.
# GUMO
# The Williams Ranch Road is currently impassable and closed to public access due to unsafe conditions.
# ZION
# Kolob Terrace Road closed to non-tracked vehicles past Maloney Hill (12 miles north of SR-9) due to snow and ice.
# DEPO
# Reds Meadow Road and shuttle service, which provide access to Devils Postpile National Monument, will be closed 24 hours per day for construction work from Sundays at 11 pm through Fridays at 9 am (excluding holidays) during the summer 2024 season.
# DINO
# The Harpers Corner Road in Colorado is closed at Plug Hat Picnic Area, approximately five miles from US HWY 40. Access to the Dinosaur Quarry in the Utah portion of the monument is open all winter.
# DEWA
# The winter maintenance plan is in effect for the season beginning January 2, 2024. Certain roads and areas may be closed or may not receive winter maintenance. Visit the Current Conditions page for more information.
# ROMO
# Trail Ridge Road, which is Hwy 34 through RMNP, is closed to through travel for the winter. The road is closed at Many Parks Curve on the east side of the park and at the Colorado River Trailhead on the west side. For more information, call 970-586-1222.
# GLAC
# The alpine section of the Going-to-the-Sun Road is closed for the season. The road remains open to Lake McDonald Lodge on the west side and to St. Mary Campground on the east side.
# GRSM
# Several trails in the park are temporarily closed. Please check the "Trail and Backcountry Closures, Warnings & Cautions" section of the Current Road, Facility, Trail & Backcountry Updates page for further details.
# OLYM
# The Daley-Rankin Tunnel and pedestrian bridge on the Spruce Railroad Trail are temporarily closed due to rockfall.
# BLCA
# The North Rim Road, East Portal Road, and South Rim Road (beyond the visitor center) are closed for the season. They will reopen next spring as conditions permit. The East Portal Road is managed by the Bureau of Reclamation (not NPS).
# LAVO
# Hwy. 89 connecting the north and south park entrances is CLOSED for the season. The northwest and southwest entrances remain open to vehicle access throughout the snow season (through April). Road clearing operations begin in April.
# PIRO
# Most park roads are closed to all vehicles except snowmobiles. Sand Point Road is the only park road accessible by car. County Road H58 is a snowmobile trail from Adam's Trail to Grand Marais.
# ORPI
# The border roads remain closed (the dirt roads directly along the border and all crossover roads leading from South Puerto Blanco Drive to the border) to all public vehicle and pedestrian traffic for public safety. South Puerto Blanco Drive remains open.
# ORPI
# El Camino De Dos Republicas remains open from SR85 to Gachado Line Camp. Dos Lomitas is not accessible. The southeast border road from Lukeville Port of Entry eastward to the Santa Rosa Mountains is closed to public vehicle and pedestrian traffic.
# CRMO
# The Loop Road and Lava Flow Campground are closed to vehicles for the season. The Loop Road is only accessible by hiking and biking.
# KAWW
# As of November 3, 2023, the North Entrance Road and the Katahdin View Loop Road are closed to wheeled vehicles for the winter season. Access by foot and bicycle is permitted.
# BLRI
# From late fall through the winter, park personnel conduct winter maintenance activities in multiple sections of the Parkway. These daily closures require full, 2-lane closures to all uses during the workday.
# MORA
# Except for the Longmire/Paradise road in the southwest side of the park, all park roads are closed for the winter season, including SR410/Chinook Pass, SR123/Cayuse Pass, White River, Sunrise, Mowich Lake, Stevens Canyon, and Westside Roads.
# KEFJ
# The road to Exit Glacier is now closed to automobile access at mile 1.3 of the Herman Leirer Road for the summer season.
# DEPO
# Devils Postpile National Monument and Reds Meadow Road are closed for season; they will not reopen before June 2024.
# MACA
# The Sloan’s Crossing Pond Walk trail and picnic area is closed for rehabilitation of the wooden boardwalk that circles the pond. The Mammoth Cave Railroad Hike and Bike Trail remains open through this area.
# AMIS
# Due to soil and vegetation damage caused by off-road vehicle travel near Amistad Acres, undesignated dirt loop roads in the area are closed to vehicle traffic until further notice. The area will remain open to foot traffic.
# FONE
# Portions of the Braddock Road Trail at the Indian Run bridge are closed until a new foot bridge is constructed.
# LIRI
# Due to washout and bad road conditions Slant Rock Road has been closed to all traffic aside from hikers and bikers. To access Slant Rock, park your vehicle at the hunting inspection station off of Road 103.
# THRO
# Due to major road repair work, the former scenic loop between the Old East Entrance Station (near mile marker 22) and mile marker 28 is closed to all traffic, including pedestrian, and bicycle access.
# VOYA
# Salmi Road entrance to the Kab-Ash Trail remains temporarily closed at the trail's western most terminus. Access to the trail remains open at trailheads along Ash River Trail road, Meadwood Road, and the eastern terminus within the community of Ash River.
# VAFO
# County Line Road is closed during the week, from Monday through Friday. The closure will apply to all vehicular, pedestrian, and bicycle traffic. Please find an alternate route.
# NATT
# Heavy rain has undermined a culvert making it unsafe for passage. Due to horse trailer parking availability, the entire section is closed to equestrians. Hikers are still able to travel from the railroad tracks to the Parkway Visitor Center.
# CUIS
# South Cut Trail is closed between the main road and Killman Field trail due to washout along the trail. Detour for that section is along Killman Field trail. South Cut trail from Killman Field trail to the beach is open.

# %%
sum(alerts_df['road_closed_flag'])
# Out:
# 52

# %%
alerts_df2 = alerts_df.merge(parks,left_on='park alpha', right_on="Alpha", how = "left")

# %%
alerts_df2['relatedRoadEvents'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-afff09c12d82> in <module>
# ----> 1 alerts_df2['relatedRoadEvents'].value_counts()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\base.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#    1301         from pandas.core.algorithms import value_counts
#    1302         result = value_counts(self, sort=sort, ascending=ascending,
# -> 1303                               normalize=normalize, bins=bins, dropna=dropna)
#    1304         return result
#    1305
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     703
#     704         else:
# --> 705             keys, counts = _value_counts_arraylike(values, dropna)
#     706
#     707             if not isinstance(keys, Index):
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\algorithms.py in _value_counts_arraylike(values, dropna)
#     748         # TODO: handle uint8
#     749         f = getattr(htable, "value_count_{dtype}".format(dtype=ndtype))
# --> 750         keys, counts = f(values, dropna)
#     751
#     752         mask = isna(values)
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object()
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object()
#
# TypeError: unhashable type: 'list'

# %%
alerts_df2.head()
# Out:
#                                      id  \
# 0  1CC5DA87-2D0C-4E51-B88C-DB49B7F38957
# 1  D343DB17-FB31-4953-AC43-957033416C4B
# 2  75487057-E4F6-4A96-9E5F-71A40F272B2F
# 3  82666CCF-577D-4717-9BE5-9E42431B1490
# 4  B090C622-C867-4B23-9250-F0EBF3B5642D
#
#                                                  url  \
# 0
# 1  https://www.nps.gov/grca/planyourvisit/grand-c...
# 2  https://www.nps.gov/grca/planyourvisit/weather...
# 3
# 4
#
#                                                title park alpha  \
# 0                 April 15, 2024: Summer Hours Begin       STEA
# 1  What's Closed and What's Open? (Park Operation...       GRCA
# 2  Thursday, March 21, 2024 - Mostly Sunny Today ...       GRCA
# 3                         Prescribed Fire Operations       EVER
# 4                                       Road Closure       SHEN
#
#                                          description      category  \
# 0  Effective Monday, April 15, Steamtown NHS will...   Information
# 1  Visitor Center is OPEN from 10 am to 4 pm. Ran...  Park Closure
# 2  Bright Angel Trail, Plateau Pt. and Tonto Trai...  Park Closure
# 3  Due to recent prescribed fire operations north...       Caution
# 4  Skyline Drive is closed northbound from Thornt...  Park Closure
#
#                                    relatedRoadEvents        LastIndexedDate  \
# 0                                                 []  2024-03-21 08:39:02.0
# 1                                                 []  2024-03-21 00:02:31.0
# 2                                                 []  2024-03-21 00:00:41.0
# 3                                                 []  2024-03-20 20:27:48.0
# 4  [{'title': 'Thornton Gap Entrance Station to M...  2024-03-20 20:08:33.0
#
#    road_closed_flag     Park Name                    Park Full Name  \
# 0                 0     Steamtown  Steamtown National Historic Site
# 1                 0  Grand Canyon        Grand Canyon National Park
# 2                 0  Grand Canyon        Grand Canyon National Park
# 3                 0    Everglades          Everglades National Park
# 4                 0    Shenandoah          Shenandoah National Park
#
#              Type of Unit State  Reg Alpha  Unit
# 0  National Historic Site    PA  NER  STEA   1.0
# 1           National Park    AZ  IMR  GRCA   1.0
# 2           National Park    AZ  IMR  GRCA   1.0
# 3           National Park    FL  SER  EVER   1.0
# 4           National Park    VA  NER  SHEN   1.0

# %%
alerts_df2.loc[alerts_df2['relatedRoadEvents'].str.contains("nps.gov")==True]
# Out:
# Empty DataFrame
# Columns: [id, url, title, park alpha, description, category, relatedRoadEvents, LastIndexedDate, road_closed_flag, Park Name, Park Full Name, Type of Unit, State, Reg, Alpha, Unit]
# Index: []

# %%
alerts_df_closures = alerts_df2.loc[alerts_df2['road_closed_flag']==1]
alerts_df_closures.Reg.value_counts()
# Out:
# IMR    16
# PWR    13
# SER     7
# NER     5
# MWR     5
# NCR     2
# AKR     1
# NE      1
# Name: Reg, dtype: int64

# %%
alerts_df2.to_csv("alerts_api.csv", index=False)
