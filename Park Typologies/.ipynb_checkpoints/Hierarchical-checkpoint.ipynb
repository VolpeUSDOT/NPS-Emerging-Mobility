# %%
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
## import the dataset. Change the file path as needed
df = pd.read_excel(r"C:\Users\Daniel.Lang\Downloads\Park Typology Dataset 3.xlsx")

## change numerical columns to text values
df.rename(columns={2012: '2012', 2016:'2016', 2019:'2019', 2022:'2022'},
    inplace=True)
df.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name Park Alpha Setting     2012     2016     2019  \
# 0  Abraham Lincoln Birthplace       ABLI   rural   169515   252495   238226
# 1                      Acadia       ACAD   rural  2431052  3303393  3437286
# 2                       Adams       ADAM   urban   336031   199301   187400
# 3       African Burial Ground       AFBG   urban    77624    46526    47427
# 4           Agate Fossil Beds       AGFO   rural    11824    15555    16657
#
#       2022  Jan-19  Feb-19  ...  Total Parking Area (Acres)  \
# 0   265707    1939    6534  ...                    1.503191
# 1  3970260    8532    9154  ...                   40.037856
# 2    12848      27     179  ...                    0.000000
# 3    29743      96    1571  ...                    0.000000
# 4    16357       0      94  ...                    1.922567
#
#    Miles of Road/Acre  Acre of Parking/Acre  Transit Y/N  Transit Boardings  \
# 0            0.002441              0.004363            0                  0
# 1            0.001938              0.000816            1             414808
# 2            0.000000              0.000000            1                  0
# 3            0.000000              0.000000            0                  0
# 4            0.001270              0.000629            0                  0
#
#    Access Type  Recent Trans Data Collection Study  Hrly VUStats  FOTSC park  \
# 0          NaN                                 NaN           NaN         NaN
# 1          NaN                                 NaN           NaN         1.0
# 2          NaN                                 NaN           NaN         NaN
# 3          NaN                                 NaN           NaN         NaN
# 4          NaN                                 NaN           NaN         NaN
#
#    remove
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 48 columns]

# %%
# extract variables of interest by column number
voi = df.iloc[:, [0,1,7,33,34,35,37,41]]
voi.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace   265707         344.50                1
# 1                      Acadia  3970260       49071.40                1
# 2                       Adams    12848          23.82                0
# 3       African Burial Ground    29743           0.35                0
# 4           Agate Fossil Beds    16357        3057.87                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N
# 0                     0.841                  1            0
# 1                    95.109                  1            1
# 2                     0.000                  0            1
# 3                     0.000                  0            0
# 4                     3.882                  1            0

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
## choose columns to run the analysis on
data_columns = ['2022','Road Length in Park (Mi)', 'Size  (acres)', 'Have Roads Y/N?', "Have Parking Y/N?", "Transit Y/N"]  
data = voi[data_columns]
## scale the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
## make clusters
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data_scaled)
print(labels)
# Out:
# [5 0 0 1 5 1 5 5 5 5 5 1 5 5 5 5 5 1 5 5 5 0 1 5 3 2 2 5 5 5 5 5 5 4 1 5 1
#  0 5 6 0 1 5 5 1 5 9 5 9 0 2 1 0 5 5 0 5 1 5 5 1 5 5 5 5 5 0 1 6 5 5 5 5 5
#  5 1 1 5 5 5 5 5 5 5 5 0 2 0 1 6 2 0 3 0 5 0 0 1 1 6 0 5 5 5 0 2 1 0 6 5 5
#  1 5 5 5 5 5 5 5 0 5 5 5 5 5 5 6 1 0 5 5 5 5 5 1 1 1 5 5 3 5 7 9 1 5 5 5 7
#  5 5 3 0 0 7 5 5 0 5 0 6 5 5 7 5 5 9 0 1 2 1 5 0 6 2 5 0 5 5 5 5 5 5 5 1 5
#  0 6 5 5 1 5 5 1 5 5 9 9 5 1 3 5 0 6 5 5 9 5 3 1 0 3 2 5 2 5 5 5 5 5 1 5 9
#  6 1 0 5 1 1 0 5 1 5 1 1 9 5 1 1 5 6 5 6 9 5 2 5 5 5 5 2 5 0 6 4 5 0 1 5 5
#  1 1 9 5 1 5 1 3 5 1 9 2 5 5 0 5 5 5 5 1 5 1 6 5 5 5 5 0 5 5 1 0 1 1 1 5 5
#  6 1 5 5 5 1 6 5 0 1 1 0 5 5 5 6 5 5 5 1 5 9 5 5 5 9 1 5 5 6 0 2 2 5 5 0 5
#  0 5 5 1 5 1 1 1 6 1 5 5 1 1 5 5 5 1 5 5 5 5 5 5 9 5 5 5 1 5 5 5 5 9 1 6 1
#  5 5 5 5 6 5 5 0 1 1 1 8 9 5 2 0 3 0]

# %%
## append lapels to original dataset
voi['Cluster_Labels'] = labels
voi.head()
# Out:
# C:\Users\Daniel.Lang\AppData\Local\Temp\ipykernel_15472\2214654142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voi['Cluster_Labels'] = labels
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace   265707         344.50                1
# 1                      Acadia  3970260       49071.40                1
# 2                       Adams    12848          23.82                0
# 3       African Burial Ground    29743           0.35                0
# 4           Agate Fossil Beds    16357        3057.87                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels
# 0                     0.841                  1            0               5
# 1                    95.109                  1            1               0
# 2                     0.000                  0            1               0
# 3                     0.000                  0            0               1
# 4                     3.882                  1            0               5

# %%
from scipy.cluster.hierarchy import dendrogram , linkage
## Calculate Z (Euclidean Distance)
Z = linkage(data_scaled, method = 'ward')

## (Plot Dendrogram)
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(voi['Cluster_Labels'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(voi.loc[voi['Cluster_Labels'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")
# Out:
# 45 in cluster 0
# 73 in cluster 1
# 16 in cluster 2
# 9 in cluster 3
# 2 in cluster 4
# 199 in cluster 5
# 22 in cluster 6
# 4 in cluster 7
# 1 in cluster 8
# 17 in cluster 9

# %%
## find the largest cluster
max_cluster = voi['Cluster_Labels'].value_counts().idxmax()

# Extract rows with the max_cluster value into a new DataFrame
second_sort = voi[voi['Cluster_Labels'] == max_cluster]
second_sort.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 4                Agate Fossil Beds National Monument
# 6          Alibates Flint Quarries National Monument
# 7  Allegheny Portage Railroad National Historic Site
# 8                   Amistad National Recreation Area
#
#               Simplified Name    2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace  265707         344.50                1
# 4           Agate Fossil Beds   16357        3057.87                1
# 6     Alibates Flint Quarries    7520        1370.97                1
# 7  Allegheny Portage Railroad  176144        1284.27                1
# 8                     Amistad  912283       62945.15                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels
# 0                     0.841                  1            0               5
# 4                     3.882                  1            0               5
# 6                     4.574                  1            0               5
# 7                    12.669                  1            0               5
# 8                    28.871                  1            0               5

# %%
## choose columns to run the second analysis on
data_columns = ['2022','Road Length in Park (Mi)', 'Size  (acres)', 'Have Roads Y/N?', "Have Parking Y/N?", "Transit Y/N"]  
data = second_sort[data_columns]
## scale the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
## make clusters
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data_scaled)
print(labels)
# Out:
# [5 5 5 3 1 5 5 3 4 5 1 5 2 5 1 5 5 1 1 6 4 3 5 2 7 7 2 1 1 5 3 5 7 3 7 5 3
#  5 8 8 1 6 3 5 2 6 5 5 3 0 9 3 5 4 5 5 3 5 5 5 5 3 5 5 5 5 3 7 5 5 5 5 5 7
#  5 5 1 5 2 5 5 5 6 5 5 5 5 1 1 5 6 5 5 5 5 5 5 2 5 5 2 5 5 7 5 5 5 5 9 0 3
#  5 7 6 6 5 5 5 3 5 3 5 5 6 7 3 5 5 5 3 2 7 3 5 5 5 0 5 0 4 5 5 3 5 3 1 3 6
#  5 5 6 5 5 1 3 2 5 5 1 7 5 5 5 7 8 7 1 3 3 5 5 5 3 3 6 5 5 7 5 5 5 5 5 5 4
#  2 5 3 6 4 5 5 1 5 1 5 3 3 3]

# %%
## Calculate Z (Euclidean Distance)
Z = linkage(data_scaled, method = 'ward')

## Plot Dendrogram
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()

# %%
## add results to table
second_sort['Cluster_Labels2'] = labels
second_sort.head()
# Out:
# C:\Users\Daniel.Lang\AppData\Local\Temp\ipykernel_15472\962863721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_sort['Cluster_Labels2'] = labels
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 4                Agate Fossil Beds National Monument
# 6          Alibates Flint Quarries National Monument
# 7  Allegheny Portage Railroad National Historic Site
# 8                   Amistad National Recreation Area
#
#               Simplified Name    2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace  265707         344.50                1
# 4           Agate Fossil Beds   16357        3057.87                1
# 6     Alibates Flint Quarries    7520        1370.97                1
# 7  Allegheny Portage Railroad  176144        1284.27                1
# 8                     Amistad  912283       62945.15                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels  \
# 0                     0.841                  1            0               5
# 4                     3.882                  1            0               5
# 6                     4.574                  1            0               5
# 7                    12.669                  1            0               5
# 8                    28.871                  1            0               5
#
#    Cluster_Labels2
# 0                5
# 4                5
# 6                5
# 7                3
# 8                1

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(second_sort['Cluster_Labels2'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(second_sort.loc[second_sort['Cluster_Labels2'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")
# Out:
# 4 in cluster 0
# 17 in cluster 1
# 10 in cluster 2
# 30 in cluster 3
# 6 in cluster 4
# 101 in cluster 5
# 12 in cluster 6
# 14 in cluster 7
# 3 in cluster 8
# 2 in cluster 9

# %%
## clean and merge second level results
voi = voi.merge(second_sort[['NPS Full Name','Cluster_Labels2']], on='NPS Full Name', how='left', suffixes=('', '_second_sort'))
voi['Cluster_Labels2'] = voi['Cluster_Labels2'].fillna(999)
voi['Cluster_Labels2'] = voi['Cluster_Labels2'].astype(int)
voi.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace   265707         344.50                1
# 1                      Acadia  3970260       49071.40                1
# 2                       Adams    12848          23.82                0
# 3       African Burial Ground    29743           0.35                0
# 4           Agate Fossil Beds    16357        3057.87                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels  \
# 0                     0.841                  1            0               5
# 1                    95.109                  1            1               0
# 2                     0.000                  0            1               0
# 3                     0.000                  0            0               1
# 4                     3.882                  1            0               5
#
#    Cluster_Labels2
# 0                5
# 1              999
# 2              999
# 3              999
# 4                5

# %%
## list second level clusters
grouped = voi.groupby('Cluster_Labels2')['Simplified Name'].unique()

for cluster_label, names in grouped.items():
    print(f"Cluster {cluster_label}: {', '.join(names)}")
# Out:
# Cluster 0: Crater Lake, Kings Canyon, North Cascades, Organ Pipe Cactus
# Cluster 1: Amistad, Arches, Badlands, Big South Fork, Big Thicket, Canyon de Chelly, Capitol Reef, Chickamauga and Chattanooga, Fredericksburg and Spotsylvania County Battlefields Memorial, Great Basin, Great Sand Dunes, Petrified Forest, Redwood, Saguaro, Santa Monica Mountains, Whiskeytown-Shasta-Trinity, White Sands
# Cluster 2: Assateague Island, Boston, Canaveral, Colonial, Gateway Arch, Hot Springs, Indiana Dunes, Mount Rushmore, Rock Creek, Valley Forge
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data)
voi['Cluster_Labels_US'] = labels
voi.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace   265707         344.50                1
# 1                      Acadia  3970260       49071.40                1
# 2                       Adams    12848          23.82                0
# 3       African Burial Ground    29743           0.35                0
# 4           Agate Fossil Beds    16357        3057.87                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels  \
# 0                     0.841                  1            0               5
# 1                    95.109                  1            1               0
# 2                     0.000                  0            1               0
# 3                     0.000                  0            0               1
# 4                     3.882                  1            0               5
#
#    Cluster_Labels2  Cluster_Labels_US
# 0                5                  5
# 1              999                  1
# 2              999                  5
# 3              999                  5
# 4                5                  5

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(voi['Cluster_Labels_US'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(voi.loc[voi['Cluster_Labels_US'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")
# Out:
# 9 in cluster 0
# 13 in cluster 1
# 3 in cluster 2
# 21 in cluster 3
# 19 in cluster 4
# 269 in cluster 5
# 3 in cluster 6
# 1 in cluster 7
# 3 in cluster 8
# 47 in cluster 9

# %%
## plot dendrogram
Z = linkage(data, method = 'ward')
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()

# %%
## find the largest cluster
max_cluster = voi['Cluster_Labels_US'].value_counts().idxmax()

## Extract rows with the max_cluster value into a new DataFrame
second_sort = voi[voi['Cluster_Labels_US'] == max_cluster]
second_sort.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
# 5                                 Alagnak Wild River
#
#               Simplified Name    2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace  265707         344.50                1
# 2                       Adams   12848          23.82                0
# 3       African Burial Ground   29743           0.35                0
# 4           Agate Fossil Beds   16357        3057.87                1
# 5                Alagnak Wild     184       30664.79                0
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels  \
# 0                     0.841                  1            0               5
# 2                     0.000                  0            1               0
# 3                     0.000                  0            0               1
# 4                     3.882                  1            0               5
# 5                     0.000                  0            0               1
#
#    Cluster_Labels2  Cluster_Labels_US
# 0                5                  5
# 2              999                  5
# 3              999                  5
# 4                5                  5
# 5              999                  5

# %%
## choose columns to run the second analysis on
data_columns = ['2022','Road Length in Park (Mi)', 'Size  (acres)', 'Have Roads Y/N?', "Have Parking Y/N?", "Transit Y/N"]  
data = second_sort[data_columns]
## make clusters
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data)
print(labels)
# Out:
# [1 7 7 7 7 7 4 3 3 9 3 1 3 7 6 3 1 7 7 2 3 1 1 6 7 7 0 7 7 3 7 7 0 9 0 3 3
#  0 7 3 0 7 3 7 5 7 7 3 3 3 7 0 1 3 1 8 2 3 3 4 4 0 5 3 7 3 7 1 3 7 7 7 0 7
#  6 3 6 7 6 7 4 1 7 7 1 1 0 6 7 3 3 0 7 7 0 7 7 7 7 4 3 3 3 7 7 3 7 3 7 4 8
#  3 1 0 7 7 7 0 7 3 3 3 3 3 3 7 3 9 7 6 3 7 4 7 7 4 7 6 3 2 7 1 0 7 3 8 4 6
#  3 4 4 3 3 1 3 1 7 0 7 3 3 1 7 7 7 0 7 3 6 4 3 6 3 1 3 7 3 7 7 7 6 7 3 3 9
#  6 4 3 5 8 1 1 3 3 3 3 4 8 6 6 7 3 1 7 7 6 6 7 7 7 8 4 7 1 7 7 7 3 7 7 7 0
#  7 7 7 3 7 4 0 3 7 3 0 3 7 7 7 7 4 7 7 4 7 3 7 7 7 3 7 1 3 6 0 1 5 3 4 0 1
#  7 7 1 3 7 6 0 7 0 1]

# %%
## add results to table 
second_sort['Cluster_Labels_US2'] = labels
second_sort.head()
# Out:
# C:\Users\Daniel.Lang\AppData\Local\Temp\ipykernel_15472\1656572663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_sort['Cluster_Labels_US2'] = labels
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
# 5                                 Alagnak Wild River
#
#               Simplified Name    2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace  265707         344.50                1
# 2                       Adams   12848          23.82                0
# 3       African Burial Ground   29743           0.35                0
# 4           Agate Fossil Beds   16357        3057.87                1
# 5                Alagnak Wild     184       30664.79                0
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels  \
# 0                     0.841                  1            0               5
# 2                     0.000                  0            1               0
# 3                     0.000                  0            0               1
# 4                     3.882                  1            0               5
# 5                     0.000                  0            0               1
#
#    Cluster_Labels2  Cluster_Labels_US  Cluster_Labels_US2
# 0                5                  5                   1
# 2              999                  5                   7
# 3              999                  5                   7
# 4                5                  5                   7
# 5              999                  5                   7

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(second_sort['Cluster_Labels_US2'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(second_sort.loc[second_sort['Cluster_Labels_US2'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")
# Out:
# 23 in cluster 0
# 26 in cluster 1
# 3 in cluster 2
# 68 in cluster 3
# 19 in cluster 4
# 4 in cluster 5
# 19 in cluster 6
# 97 in cluster 7
# 6 in cluster 8
# 4 in cluster 9

# %%
## plot dendrogram 
Z = linkage(data, method = 'ward')
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()

# %%
## clean and merge second level results
voi = voi.merge(second_sort[['NPS Full Name','Cluster_Labels_US2']], on='NPS Full Name', how='left', suffixes=('', '_second_sort'))
voi['Cluster_Labels_US2'] = voi['Cluster_Labels_US2'].fillna(999)
voi['Cluster_Labels_US2'] = voi['Cluster_Labels_US2'].astype(int)
voi.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Size  (acres)  Have Roads Y/N?  \
# 0  Abraham Lincoln Birthplace   265707         344.50                1
# 1                      Acadia  3970260       49071.40                1
# 2                       Adams    12848          23.82                0
# 3       African Burial Ground    29743           0.35                0
# 4           Agate Fossil Beds    16357        3057.87                1
#
#    Road Length in Park (Mi)  Have Parking Y/N?  Transit Y/N  Cluster_Labels  \
# 0                     0.841                  1            0               5
# 1                    95.109                  1            1               0
# 2                     0.000                  0            1               0
# 3                     0.000                  0            0               1
# 4                     3.882                  1            0               5
#
#    Cluster_Labels2  Cluster_Labels_US  Cluster_Labels_US2
# 0                5                  5                   1
# 1              999                  1                 999
# 2              999                  5                   7
# 3              999                  5                   7
# 4                5                  5                   7

# %%
## display second level clusters
grouped = voi.groupby('Cluster_Labels_US2')['Simplified Name'].unique()

for cluster_label, names in grouped.items():
    print(f"Cluster {cluster_label}: {', '.join(names)}")
# Out:
# Cluster 0: Boston African American, Canyon de Chelly, Cape Lookout, Carlsbad Caverns, Catoctin Mountain, Colorado, Devils Tower, Fire Island, Fort Pulaski, Fort Sumter and Fort Moultrie, Fort Washington, Guilford Courthouse, Harpers Ferry, Klondike Gold Rush, Manassas, Mesa Verde, Salem Maritime, Shiloh, Stones River, Vicksburg, War in the Pacific, Wolf Trap, Wright Brothers
# Cluster 1: Abraham Lincoln Birthplace, Apostle Islands, Bandelier, Big Thicket, Bighorn Canyon, Congaree, Cowpens, El Malpais, Fort Frederica, Fort McHenry, Fort Necessity, Guadalupe Mountains, Kings Mountain, Lowell, LBJ Memorial Grove, Martin Luther King, Jr.,, Morristown, Palo Alto Battlefield, Paterson Great Falls, Piscataway, River Raisin, Upper Delaware, Virgin Islands, Washington Monument, White House, Wupatki
