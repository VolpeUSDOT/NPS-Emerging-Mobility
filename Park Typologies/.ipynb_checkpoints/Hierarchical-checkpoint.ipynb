# %%
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
## import the dataset. Change the file path as needed
df = pd.read_excel(r"C:\Users\Daniel.Lang\Downloads\Park Typology Dataset 3.xlsx")

## change numerical columns to text values
df.rename(columns={2012: '2012', 2016:'2016', 2019:'2019', 2022:'2022'},
    inplace=True)
df.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name Park Alpha Setting     2012     2016     2019  \
# 0  Abraham Lincoln Birthplace       ABLI   rural   169515   252495   238226
# 1                      Acadia       ACAD   rural  2431052  3303393  3437286
# 2                       Adams       ADAM   urban   336031   199301   187400
# 3       African Burial Ground       AFBG   urban    77624    46526    47427
# 4           Agate Fossil Beds       AGFO   rural    11824    15555    16657
#
#       2022  Jan-19  Feb-19  ...  Total Parking Area (Acres)  \
# 0   265707    1939    6534  ...                    1.503191
# 1  3970260    8532    9154  ...                   40.037856
# 2    12848      27     179  ...                    0.000000
# 3    29743      96    1571  ...                    0.000000
# 4    16357       0      94  ...                    1.922567
#
#    Miles of Road/Acre  Acre of Parking/Acre  Transit Y/N  Transit Boardings  \
# 0            0.002441              0.004363            0                  0
# 1            0.001938              0.000816            1             414808
# 2            0.000000              0.000000            1                  0
# 3            0.000000              0.000000            0                  0
# 4            0.001270              0.000629            0                  0
#
#    Access Type  Recent Trans Data Collection Study  Hrly VUStats  FOTSC park  \
# 0          NaN                                 NaN           NaN         NaN
# 1          NaN                                 NaN           NaN         1.0
# 2          NaN                                 NaN           NaN         NaN
# 3          NaN                                 NaN           NaN         NaN
# 4          NaN                                 NaN           NaN         NaN
#
#    remove
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 48 columns]

# %%
# extract variables of interest by column number
voi = df.iloc[:, [0,1,7, 35]]
voi.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Road Length in Park (Mi)
# 0  Abraham Lincoln Birthplace   265707                     0.841
# 1                      Acadia  3970260                    95.109
# 2                       Adams    12848                     0.000
# 3       African Burial Ground    29743                     0.000
# 4           Agate Fossil Beds    16357                     3.882

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
## choose columns to run the analysis on
data_columns = ['2022','Road Length in Park (Mi)']  
data = voi[data_columns]
## scale the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
## make clusters
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data_scaled)
print(labels)
# Out:
# [6 3 6 6 6 6 6 6 7 6 6 6 6 6 6 7 6 6 4 6 7 7 6 6 6 3 3 6 7 7 7 7 6 5 6 6 6
#  6 4 6 4 6 7 7 6 4 6 7 7 4 3 6 7 7 6 6 6 6 6 7 4 6 7 6 6 6 6 6 6 4 4 7 7 6
#  6 6 6 4 7 6 6 6 9 7 7 6 9 4 6 6 0 0 7 6 6 9 6 7 6 6 6 6 6 6 6 3 6 6 6 6 6
#  6 6 6 6 6 6 6 6 7 6 6 7 6 6 6 6 6 6 6 6 7 6 6 4 6 6 7 6 6 7 8 6 6 6 6 6 8
#  7 6 6 3 3 1 6 6 3 6 3 6 6 7 1 6 7 6 4 6 9 6 6 6 6 9 6 6 6 6 6 6 4 6 6 4 4
#  6 6 6 6 6 7 6 6 6 6 3 6 6 6 6 6 7 6 7 6 6 6 6 4 6 6 0 7 9 7 7 6 6 6 8 6 7
#  6 6 6 6 6 6 7 7 6 6 6 4 6 6 6 6 9 6 7 6 9 6 0 6 6 6 6 3 4 7 6 2 7 7 6 6 6
#  6 6 3 6 6 6 6 6 9 6 6 3 6 9 7 6 6 6 6 7 6 6 6 6 7 6 7 6 6 6 6 3 6 6 7 7 6
#  6 6 6 7 6 6 6 4 3 6 6 7 6 6 7 6 7 6 6 6 6 6 7 4 7 7 6 7 6 6 6 9 3 7 6 7 6
#  4 6 6 7 6 6 6 6 6 6 7 6 4 6 6 7 6 6 6 6 6 6 6 6 6 4 6 7 4 7 6 6 6 6 6 6 6
#  7 6 7 6 6 6 7 6 6 7 4 6 6 7 2 0 6 3]

# %%
## append lapels to original dataset
voi['Cluster_Labels'] = labels
voi.head()
# Out:
# C:\Users\Daniel.Lang\AppData\Local\Temp\ipykernel_34232\2214654142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   voi['Cluster_Labels'] = labels
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Road Length in Park (Mi)  \
# 0  Abraham Lincoln Birthplace   265707                     0.841
# 1                      Acadia  3970260                    95.109
# 2                       Adams    12848                     0.000
# 3       African Burial Ground    29743                     0.000
# 4           Agate Fossil Beds    16357                     3.882
#
#    Cluster_Labels
# 0               6
# 1               3
# 2               6
# 3               6
# 4               6

# %%
from scipy.cluster.hierarchy import dendrogram , linkage
## Calculate Z (Euclidean Distance)
Z = linkage(data_scaled, method = 'ward')

## (Plot Dendrogram)
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(voi['Cluster_Labels'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(voi.loc[voi['Cluster_Labels'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")
# Out:
# 5 in cluster 0
# 2 in cluster 1
# 2 in cluster 2
# 17 in cluster 3
# 25 in cluster 4
# 1 in cluster 5
# 252 in cluster 6
# 70 in cluster 7
# 3 in cluster 8
# 11 in cluster 9

# %%
## find the largest cluster
max_cluster = voi['Cluster_Labels'].value_counts().idxmax()

# Extract rows with the max_cluster value into a new DataFrame
second_sort = voi[voi['Cluster_Labels'] == max_cluster]
second_sort.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
# 5                                 Alagnak Wild River
#
#               Simplified Name    2022  Road Length in Park (Mi)  \
# 0  Abraham Lincoln Birthplace  265707                     0.841
# 2                       Adams   12848                     0.000
# 3       African Burial Ground   29743                     0.000
# 4           Agate Fossil Beds   16357                     3.882
# 5                Alagnak Wild     184                     0.000
#
#    Cluster_Labels
# 0               6
# 2               6
# 3               6
# 4               6
# 5               6

# %%
## choose columns to run the second analysis on
data_columns = ['2022','Road Length in Park (Mi)']  
data = second_sort[data_columns]
## scale the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
## make clusters
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data_scaled)
print(labels)
# Out:
# [8 2 2 3 2 3 7 3 2 2 7 8 2 3 1 2 2 2 2 2 4 2 2 1 2 2 2 2 2 2 5 9 6 2 9 6 2
#  7 2 1 2 2 7 9 9 2 8 5 0 2 9 8 0 1 9 2 2 3 8 2 2 2 2 1 2 4 3 1 2 1 2 4 8 3
#  2 8 0 1 0 2 9 2 1 2 2 1 3 2 2 3 2 5 9 9 5 2 3 6 3 2 9 2 4 3 1 2 2 2 6 2 9
#  5 2 3 3 3 2 2 2 2 0 5 2 8 2 2 5 3 1 2 2 6 2 0 1 3 2 2 2 0 9 8 0 9 2 8 3 8
#  2 2 5 2 8 2 2 2 2 9 7 5 1 2 0 2 2 7 2 2 2 1 2 5 9 2 1 5 3 6 8 8 7 2 2 9 0
#  0 4 2 2 8 2 2 1 2 2 2 0 2 8 2 2 2 9 2 2 3 1 2 2 2 7 2 5 9 2 9 6 7 2 2 2 2
#  8 2 2 8 2 2 2 2 2 9 2 8 7 1 0 9 5 1 8 2 2 0 2 2 0 1 2 2 1 2]

# %%
## Calculate Z (Euclidean Distance)
Z = linkage(data_scaled, method = 'ward')

## Plot Dendrogram
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()

# %%
second_sort['Cluster_Labels2'] = labels
second_sort.head()
# Out:
# C:\Users\Daniel.Lang\AppData\Local\Temp\ipykernel_34232\725244384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_sort['Cluster_Labels2'] = labels
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
# 5                                 Alagnak Wild River
#
#               Simplified Name    2022  Road Length in Park (Mi)  \
# 0  Abraham Lincoln Birthplace  265707                     0.841
# 2                       Adams   12848                     0.000
# 3       African Burial Ground   29743                     0.000
# 4           Agate Fossil Beds   16357                     3.882
# 5                Alagnak Wild     184                     0.000
#
#    Cluster_Labels  Cluster_Labels2
# 0               6                8
# 2               6                2
# 3               6                2
# 4               6                3
# 5               6                2

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(second_sort['Cluster_Labels2'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(second_sort.loc[second_sort['Cluster_Labels2'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")
# Out:
# 15 in cluster 0
# 22 in cluster 1
# 119 in cluster 2
# 20 in cluster 3
# 5 in cluster 4
# 13 in cluster 5
# 7 in cluster 6
# 10 in cluster 7
# 20 in cluster 8
# 21 in cluster 9

# %%
voi = voi.merge(second_sort[['NPS Full Name','Cluster_Labels2']], on='NPS Full Name', how='left', suffixes=('', '_second_sort'))
voi['Cluster_Labels2'] = voi['Cluster_Labels2'].fillna(999)
voi['Cluster_Labels2'] = voi['Cluster_Labels2'].astype(int)
voi.head()
# Out:
#                                        NPS Full Name  \
# 0  Abraham Lincoln Birthplace National Historical...
# 1                               Acadia National Park
# 2                     Adams National Historical Park
# 3            African Burial Ground National Monument
# 4                Agate Fossil Beds National Monument
#
#               Simplified Name     2022  Road Length in Park (Mi)  \
# 0  Abraham Lincoln Birthplace   265707                     0.841
# 1                      Acadia  3970260                    95.109
# 2                       Adams    12848                     0.000
# 3       African Burial Ground    29743                     0.000
# 4           Agate Fossil Beds    16357                     3.882
#
#    Cluster_Labels  Cluster_Labels2
# 0               6                8
# 1               3              999
# 2               6                2
# 3               6                2
# 4               6                3

# %%
grouped = voi.groupby('Cluster_Labels2')['Simplified Name'].unique()

for cluster_label, names in grouped.items():
    print(f"Cluster {cluster_label}: {', '.join(names)}")
# Out:
# Cluster 0: Cowpens, Devils Postpile, Fort Necessity, Fort Raleigh, Jean Lafitte, Kings Mountain, Lewis and Clark, Little Bighorn Battlefield, Morristown, Petersburg, Petroglyph, Richmond, Voyageurs, White House, Wilson's Creek
# Cluster 1: Arlington House, Boston African American, Channel Islands, Devils Tower, Fire Island, Ford's Theatre, Fort Caroline, Fort Pulaski, Fort Sumter and Fort Moultrie, Fort Washington, Guilford Courthouse, Kaloko-Honokohau, Klondike Gold Rush, Montezuma Castle, Nez Perce, Obed, Pu'uhonua o Honaunau, Salem Maritime, Vanderbilt Mansion, War in the Pacific, Wolf Trap, Wright Brothers
# Cluster 2: Adams, African Burial Ground, Alagnak Wild, Andrew Johnson, Aniakchak, Appomattox Court House, Aztec Ruins, Belmont-Paul Women's Equality, Bent's Old Fort, Bering Land Bridge, Big Hole, Bluestone, Booker T. Washington, Boston Harbor Islands, Brown v. Board of Education, Buck Island Reef, Camp Nelson, Cane River Creole, Cape Krusenstern, Carter G. Woodson Home, César E. Chávez, Chamizal, Charles Pinckney, Charles Young Buffalo Soldiers, Clara Barton, Cumberland Island, Edgar Allan Poe, Effigy Mounds, El Morro, Eleanor Roosevelt, Eugene O'Neill, Federal Hall, First Ladies, Fort Bowie, Fort Davis, Fort Larned, Fort Scott, Fort Stanwix, Fort Union, Fort Union Trading Post, Frederick Douglass, Frederick Law Olmsted, Gates of the Arctic, George Washington Carver, Governors Island, Grant-Kohrs Ranch, Hagerman Fossil Beds, Hamilton Grange, Hampton, Harry S Truman, Homestead, Hovenweep, Hubbell Trading Post, Isle Royale, James A. Garfield, Jimmy Carter, John Fitzgerald Kennedy, John Muir, Katahdin Woods and Waters, Katmai, Keweenaw, Kobuk Valley, Lake Chelan, Lake Clark, Longfellow House-Washington's Headquarters, Maggie L. Walker, Manhattan Project, Marsh-Billings-Rockefeller, Martin Van Buren, Mary McLeod Bethune Council House, Medgar and Myrlie Evers Home, Minidoka, Moores Creek, Natchez, American Samoa, Navajo, New Bedford Whaling, New Orleans Jazz, Nicodemus, Noatak, Pecos, Pennsylvania Avenue, Pipe Spring, Pipestone, Port Chicago Naval Magazine, President William Jefferson Clinton Birthplace Home, Pu'ukohola Heiau, Rainbow Bridge, Reconstruction Era, Rio Grande, Roger Williams, Rosie the Riveter/World War II Home Front, Russell Cave, Saubt Croix Island, Saint Paul's Church, Salinas Pueblo Missions, Salt River Bay, Sand Creek Massacre, Saugus Iron Works, Springfield Armory, Tallgrass Prairie, Thaddeus Kosciuszko, Theodore Roosevelt Birthplace, Theodore Roosevelt Inaugural, Thomas Edison, Thomas Stone, Tonto, Tule Springs Fossil Beds, Tumacacori, Tuskegee Airmen, Tuskegee Institute, Ulysses S. Grant, Washita Battlefield, Weir Farm, Whitman Mission, William Howard Taft, Women's Rights, Wrangell-St. Elias, Yukon-Charley Rivers
# Cluster 3: Agate Fossil Beds, Alibates Flint Quarries, Andersonville, Arkansas Post, Eisenhower, Florissant Fossil Beds, Fort Laramie, Fossil Butte, Friendship Hill, Gila Cliff Dwellings, Golden Spike, Greenbelt, Hopewell Culture, Hopewell Furnace, Horseshoe Bend, Kalaupapa, Knife River Indian Villages, Lyndon B. Johnson, Oregon Caves, Saint-Gaudens
# Cluster 4: Black Canyon of the Gunnison, Flight 93, Fort Donelson, Great Basin, Pinnacles
# Cluster 5: Capulin Volcano, Coronado, Gauley River, George Washington Birthplace, Home of Franklin D. Roosevelt, Jewel Cave, Johnstown Flood, Manzanar, Monocacy, Ninety Six, Ocmulgee Mounds, Scotts Bluff, Walnut Canyon
# Cluster 6: Carlsbad Caverns, Catoctin Mountain, Glacier Bay, Harpers Ferry, Kenai Fjords, Padre Island, Stones River
# Cluster 7: Allegheny Portage Railroad, Antietam, Chaco Culture, Chiricahua, Missouri, Natural Bridges, Pea Ridge, Saratoga, Sunset Crater Volcano, Valles Caldera
# Cluster 8: Abraham Lincoln Birthplace, Apostle Islands, Congaree, De Soto, El Malpais, Fort Frederica, Fort McHenry, John Day Fossil Beds, Lincoln Home, Lowell, LBJ Memorial Grove, Martin Luther King, Jr.,, Palo Alto Battlefield, Paterson Great Falls, Piscataway, River Raisin, Theodore Roosevelt Island, Timpanogos Cave, Upper Delaware, Washington Monument
# Cluster 9: Carl Sandburg Home, Casa Grande Ruins, Christiansted, City of Rocks, Dayton Aviation Heritage, Dry Tortugas, Fort Smith, General Grant, George Rogers Clark, Grand Portage, Herbert Hoover, Lincoln Boyhood, Little Rock Central High School, Minuteman Missile, Niobrara, Perry's Victory, Sagamore Hill, Sitka, Steamtown, Tuzigoot, Waco Mammoth
# Cluster 999: Acadia, Amistad, Arches, Assateague Island, Badlands, Bandelier, Big Bend, Big Cypress, Big South Fork, Big Thicket, Bighorn Canyon, Biscayne, Blue Ridge Parkway, Boston, Bryce Canyon, Buffalo, Cabrillo, Canaveral, Canyon de Chelly, Canyonlands, Cape Cod, Cape Hatteras, Cape Lookout, Capitol Reef, Castillo de San Marcos, Castle Clinton, Cedar Breaks, Chattahoochee River, Chesapeake and Ohio Canal, Chickamauga and Chattanooga, Chickasaw, Colonial, Colorado, Crater Lake, Craters of the Moon, Cumberland Gap, Curecanti, Cuyahoga Valley, Death Valley, Delaware Water Gap, Denali, Dinosaur, Eisenhower Memorial, Everglades, Fort Matanzas, Fort Point, Fort Vancouver, Franklin Delano Roosevelt , Fredericksburg and Spotsylvania County Battlefields Memorial, Gateway Arch, Gateway, George Washington Memorial Parkway, Gettysburg, Glacier, Glen Canyon, Golden Gate, Grand Canyon, Grand Teton, Great Sand Dunes, Great Smoky Mountains, Guadalupe Mountains, Gulf Islands, Haleakala, Hawai'i Volcanoes, Hot Springs, Independence, Indiana Dunes, John D. Rockefeller, Jr. Parkway, Joshua Tree, Kennesaw Mountain, Kings Canyon, Korean War Veterans, Lake Mead, Lake Meredith, Lake Roosevelt, Lassen Volcanic, Lava Beds, Lincoln Memorial, Little River Canyon, Mammoth Cave, Manassas, MLK Memorial, Mesa Verde, Minute Man, Mississippi, Mojave, Mount Rainier, Mount Rushmore, Muir Woods, Natchez Trace, National Capital East, National Mall, New River Gorge, North Cascades, Olympic, Organ Pipe Cactus, Ozark, Pearl Harbor, Petrified Forest, Pictured Rocks, Point Reyes, President's Park, Prince William, Redwood, Rock Creek, Rocky Mountain, Ross Lake, Saguaro, Saint Croix, San Antonio Missions, San Francisco Maritime, San Juan Island, San Juan, Santa Monica Mountains, Sequoia, Shenandoah, Shiloh, Sleeping Bear Dunes, Statue of Liberty, Stonewall, Theodore Roosevelt, Thomas Jefferson Memorial, Timucuan, Valley Forge, Vicksburg, Vietnam Veterans, Virgin Islands, Whiskeytown-Shasta-Trinity, White Sands, Wind Cave, World War I, World War II, Wupatki, Yellowstone, Yosemite, Zion

# %%
data_columns = ['2022','Road Length in Park (Mi)']  
data = voi[data_columns]

# %%
agg_clustering = AgglomerativeClustering(n_clusters=10)  
labels = agg_clustering.fit_predict(data)

# %%
voi['Cluster_Labels_US'] = labels

# %%
voi.head()

# %%
# Get and sort unique cluster labels
unique_clusters = sorted(voi['Cluster_Labels_US'].unique())

# Loop through each cluster and print the count
for cluster_label in unique_clusters:
    cluster_length = len(voi.loc[voi['Cluster_Labels_US'] == cluster_label])
    print(f"{cluster_length} in cluster {cluster_label}")

# %%
Z = linkage(data, method = 'ward')

# %%
dendro = dendrogram(Z)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.show()
