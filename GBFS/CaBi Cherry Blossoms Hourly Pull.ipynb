# %% [markdown]
# ## Hourly Capital Bikeshare Pulls of Cherry Blossom-Relevant CaBi Stations
# #### Author: Eric Englin
# #### Date: 3/22/24

# %%
import requests
import json 
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import time

# %%
def get_new_data():
    res = requests.get('https://maps2.dcgis.dc.gov/dcgis/rest/services/DCGIS_DATA/Transportation_Bikes_Trails_WebMercator/MapServer/5/query?where=1%3D1&outFields=*&outSR=4326&f=json')
    data = res.text
    df = json.loads(data) # json.dumps take a dictionary as input and returns a string as output.
#    df=json.loads(df) # json.loads take a string as input and returns a dictionary as output.

    tidal_basin_stations = [
        'Jefferson Memorial',
        'Hains Point/Buckeye & Ohio Dr SW',
        'Ohio Dr & West Basin Dr SW / MLK & FDR Memorials',
        '17th St & Independence Ave SW',
        'Lincoln Memorial',
        'Maine Ave & 9th St SW',
        'Jefferson Dr & 14th St SW',
        'USDA / 12th & C St SW',
        "10th St & L'Enfant Plaza SW",
        "Maine Ave & 7th St SW",
        'Henry Bacon Dr & Lincoln Memorial Circle NW'
    ]
    
    station_id_list = []
    station_name_list = []
    capacity_list = []
    num_docks_available_list = []
    num_bikes_available_list = []
    num_ebikes_available_list = []
    lat_list = []
    lon_list = []


    for x in df['features']:
       # print(x)
        if x['attributes']['NAME'] in tidal_basin_stations:
            station_id_list.append(x['attributes']['STATION_ID'])
            station_name_list.append(x['attributes']['NAME'])
            capacity_list.append(x['attributes']['CAPACITY'])
            num_docks_available_list.append(x['attributes']['NUM_DOCKS_AVAILABLE'])
            num_bikes_available_list.append(x['attributes']['NUM_BIKES_AVAILABLE'])
            num_ebikes_available_list.append(x['attributes']['NUM_EBIKES_AVAILABLE'])
            lat_list.append(x['attributes']['LATITUDE'])
            lon_list.append(x['attributes']['LONGITUDE'])

          #  print(y['attributes']['NAME'])
    #    break
    df_update = pd.DataFrame({
        "station name":station_name_list,
        "station id":station_id_list,
        "capacity": capacity_list,
        "docks available": num_docks_available_list,
        "bikes available": num_bikes_available_list,
        "ebikes available": num_ebikes_available_list,
        "latitude": lat_list,
        "longitude": lon_list,
    #    "event end date": end_date_list
    })
    now = datetime.datetime.now()
    year = '{:02d}'.format(now.year)
    month = '{:02d}'.format(now.month)
    day = '{:02d}'.format(now.day)
    hour = '{:02d}'.format(now.hour)
    minute = '{:02d}'.format(now.minute)
    day_month_year = '{}-{}-{}'.format(year, month, day)

    df_update['date'] = day_month_year
    df_update['hour'] = int(hour)
    return df_update, day, month

# %%
while True:
    df_old = pd.read_excel("CaBi-Cherry Blossoms Data.xlsx")
    df_update, day, month = get_new_data()
    df_update = pd.concat([df_update, df_old])
    df_update.to_excel("CaBi-Cherry Blossoms Data.xlsx",index=False)
    print(day, month)
    if (int(month) > 4)&(int(day)>15):
        break
    time.sleep(60*60)
# Out:
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 22 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 23 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 24 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 25 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 26 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 27 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 28 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 29 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 30 03
# 31 03
# 31 03
# 31 03
# 31 03
# 31 03
# 31 03
# 31 03
# 31 03
# 31 03
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_8144\1895333573.py in <module>
#       3     df_update, day, month = get_new_data()
#       4     df_update = pd.concat([df_update, df_old])
# ----> 5     df_update.to_excel("CaBi-Cherry Blossoms Data.xlsx",index=False)
#       6     print(day, month)
#       7     if (int(month) > 4)&(int(day)>15):
#
# ~\.conda\envs\new_env\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2289             freeze_panes=freeze_panes,
#    2290             engine=engine,
# -> 2291             storage_options=storage_options,
#    2292         )
#    2293
#
# ~\.conda\envs\new_env\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     833             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
#     834             writer = ExcelWriter(  # type: ignore[abstract]
# --> 835                 writer, engine=engine, storage_options=storage_options
#     836             )
#     837             need_save = True
#
# ~\.conda\envs\new_env\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     197             storage_options=storage_options,
#     198             if_sheet_exists=if_sheet_exists,
# --> 199             engine_kwargs=engine_kwargs,
#     200         )
#     201
#
# ~\.conda\envs\new_env\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     924         if not isinstance(path, ExcelWriter):
#     925             self.handles = get_handle(
# --> 926                 path, mode, storage_options=storage_options, is_text=False
#     927             )
#     928         self.sheets: dict[str, Any] = {}
#
# ~\.conda\envs\new_env\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# PermissionError: [Errno 13] Permission denied: 'CaBi-Cherry Blossoms Data.xlsx'
