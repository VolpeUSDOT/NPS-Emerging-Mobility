# %% [markdown]
# ## Volpe Center
# ### Code for National Park Service sponsor project
# ### Code by Eric Englin
# ### Date: 10/23/23
# <br><br>
# #### Objective: scrape all websites for NPS to see if they meet the 10 essential travelers information for transportation
# #### These 10 are:
# <li>driving directions</li>
# <li>Public transportation information</li>
# <li>Bike and pedestrian information</li>
# <li>Parking lot locations and accommodations</li>
# <li>Parking lot peak use and availability</li>
# <li>congestion information</li>
# <li>travel distances and travel time to sites within the park</li>
# <li>Accessibility</li>
# <li>Description of transportation experience</li>
# <li>Alternative fueling stations</li>
#
# <br><br>
# #### Together, these 10 measures can allow NPS to understand how their parks are providing transportation to visitors. This information can be used to evaluate each park and plan for an improved park experience in the future.

# %%
# import libraries
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns 
import html
from bs4 import BeautifulSoup
import requests
import os
from selenium import webdriver
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import warnings; warnings.simplefilter('ignore')
from VE_scraper_functions import *
from chromedriver_py import binary_path # this will get you the path variable
from selenium.webdriver.common.by import By
import time

# %%
#https://stackoverflow.com/questions/76727774/selenium-webdriver-chrome-115-stopped-working
from selenium.webdriver.chrome.service import Service

service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.close()

# %%
#change to the location where you saved chromedriver
chromedriver_location=r'C:\Users\eric.englin\Downloads/chromedriver.exe'

# %%
driver = webdriver.Chrome(service=service, options=options)
driver.get('https://www.nps.gov/AGFO/planyourvisit/directions.htm')
driver.close() #close driver link

# %%
path = "Park Unit Scraping Information.csv"
parks = pd.read_csv(path, encoding='latin-1')

# %%
parks.head()
# Out:
#                     Park Name              Type of Unit State  Reg Alpha  Unit
# 0  Abraham Lincoln Birthplace  National Historical Park    KY  SER  ABLI   1.0
# 1                      Acadia             National Park    ME  NER  ACAD   1.0
# 2                       Adams  National Historical Park    MA  NER  ADAM   1.0
# 3       African Burial Ground         National Monument    NY  NER  AFBG   1.0
# 4           Agate Fossil Beds         National Monument    NE  MWR  AGFO   1.0

# %%
len(parks)
# Out:
# 421

# %%
index = []
for x in parks['Alpha']:
    y = "https://www.nps.gov/"+x+"/index.htm"
    index.append(y)

parks['index site']=index

# %%
## For context, here is the main site for each national park
for x in parks['index site']:
    print(x)
# Out:
# https://www.nps.gov/ABLI/index.htm
# https://www.nps.gov/ACAD/index.htm
# https://www.nps.gov/ADAM/index.htm
# https://www.nps.gov/AFBG/index.htm
# https://www.nps.gov/AGFO/index.htm
# https://www.nps.gov/ALAG/index.htm
# https://www.nps.gov/ALFL/index.htm
# https://www.nps.gov/ALKA/index.htm
# https://www.nps.gov/ALPO/index.htm
# https://www.nps.gov/AMIS/index.htm
# https://www.nps.gov/AMME/index.htm
# https://www.nps.gov/ANDE/index.htm
# https://www.nps.gov/ANIA/index.htm
# https://www.nps.gov/ANJO/index.htm
# https://www.nps.gov/ANTI/index.htm
# https://www.nps.gov/APCO/index.htm
# https://www.nps.gov/APIS/index.htm
# https://www.nps.gov/APPA/index.htm
# https://www.nps.gov/ARCH/index.htm
# https://www.nps.gov/ARHO/index.htm
# https://www.nps.gov/ARPO/index.htm
# https://www.nps.gov/ASIS/index.htm
# https://www.nps.gov/AZRU/index.htm
# https://www.nps.gov/WABA/index.htm
# https://www.nps.gov/WACA/index.htm
# https://www.nps.gov/WACO/index.htm
# https://www.nps.gov/WAMO/index.htm
# https://www.nps.gov/WAPA/index.htm
# https://www.nps.gov/WASH/index.htm
# https://www.nps.gov/WEFA/index.htm
# https://www.nps.gov/WHHO/index.htm
# https://www.nps.gov/WHIS/index.htm
# https://www.nps.gov/WHMI/index.htm
# https://www.nps.gov/WHSA/index.htm
# https://www.nps.gov/WICA/index.htm
# https://www.nps.gov/WICL/index.htm
# https://www.nps.gov/WICR/index.htm
# https://www.nps.gov/WIHO/index.htm
# https://www.nps.gov/WORI/index.htm
# https://www.nps.gov/WOTR/index.htm
# https://www.nps.gov/WRBR/index.htm
# https://www.nps.gov/WRST/index.htm
# https://www.nps.gov/WUPA/index.htm
# https://www.nps.gov/WWII/index.htm
# https://www.nps.gov/WWIM/index.htm
# https://www.nps.gov/YELL/index.htm
# https://www.nps.gov/YOSE/index.htm
# https://www.nps.gov/YUCH/index.htm
# https://www.nps.gov/YUHO/index.htm
# https://www.nps.gov/ZION/index.htm

# %%
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.get(link)
page_location = driver.find_element(By.ID, "breadcrumbs")
print(page_location.text)
elems = driver.find_elements(By.TAG_NAME, "a")

for elem in elems:
    try:
        if "planyourvisit" in str(elem.get_attribute('href')): #only want plan your visit sites
            print(elem.get_attribute('href'))
    except:
        pass
# Out:
# https://home.nps.gov/yose/planyourvisit/directions.htm#GlobalNav-toggle
# https://home.nps.gov/yose/planyourvisit/directions.htm#LocalNav-desktop-nav
# https://home.nps.gov/yose/planyourvisit/directions.htm#main
# https://home.nps.gov/yose/planyourvisit/directions.htm#ParkFooter
# https://home.nps.gov/yose/planyourvisit/directions.htm#GlobalFooter
# https://home.nps.gov/yose/planyourvisit/directions.htm#GlobalFooterSearch
# https://home.nps.gov/planyourvisit/index.htm
# https://home.nps.gov/planyourvisit/event-search.htm
# https://home.nps.gov/planyourvisit/passes.htm
# https://home.nps.gov/planyourvisit/trip-ideas.htm
# https://home.nps.gov/yose/planyourvisit/basicinfo.htm
# https://home.nps.gov/yose/planyourvisit/conditions.htm
# https://home.nps.gov/yose/planyourvisit/maps.htm
# https://home.nps.gov/yose/planyourvisit/calendar.htm
# https://home.nps.gov/yose/planyourvisit/fees.htm
# https://home.nps.gov/yose/planyourvisit/reservations.htm
# https://home.nps.gov/yose/planyourvisit/wroads.htm
# https://home.nps.gov/yose/planyourvisit/conditions.htm
# https://home.nps.gov/yose/planyourvisit/conditions.htm
# https://home.nps.gov/yose/planyourvisit/reservations.htm
# https://home.nps.gov/yose/planyourvisit/faq.htm
# https://home.nps.gov/yose/planyourvisit/eatingsleeping.htm
# https://home.nps.gov/yose/planyourvisit/driving.htm
# https://home.nps.gov/yose/planyourvisit/maps.htm
# https://home.nps.gov/yose/planyourvisit/roadwork.htm
# https://home.nps.gov/yose/planyourvisit/wroads.htm
# https://home.nps.gov/yose/planyourvisit/tiogaclosed.htm
# https://home.nps.gov/yose/planyourvisit/tirechains.htm
# https://home.nps.gov/yose/planyourvisit/traffic.htm
# https://home.nps.gov/yose/planyourvisit/publictransportation.htm
# https://home.nps.gov/yose/planyourvisit/rv.htm
# https://home.nps.gov/yose/planyourvisit/restrictions.htm
# https://home.nps.gov/yose/planyourvisit/airports.htm

# %%
for elem in elems:
    print(elem.get_attribute('href'))
# Out:
# https://home.nps.gov/yose/planyourvisit/directions.htm#GlobalNav-toggle
# https://home.nps.gov/yose/planyourvisit/directions.htm#LocalNav-desktop-nav
# https://home.nps.gov/yose/planyourvisit/directions.htm#main
# https://home.nps.gov/yose/planyourvisit/directions.htm#ParkFooter
# https://home.nps.gov/yose/planyourvisit/directions.htm#GlobalFooter
# https://home.nps.gov/
# https://home.nps.gov/yose/planyourvisit/directions.htm#GlobalFooterSearch
# https://home.nps.gov/planyourvisit/index.htm
# https://home.nps.gov/findapark/index.htm
# https://home.nps.gov/planyourvisit/event-search.htm
# https://home.nps.gov/planyourvisit/passes.htm
# https://home.nps.gov/planyourvisit/trip-ideas.htm
# https://home.nps.gov/learnandexplore/index.htm
# https://home.nps.gov/aboutus/index.htm
# https://home.nps.gov/history/index.htm
# https://home.nps.gov/nature/index.htm
# https://home.nps.gov/kids/index.htm
# https://home.nps.gov/teachers/index.htm
# https://home.nps.gov/aboutus/news/index.htm
# https://home.nps.gov/aboutus/news/photosmultimedia.htm
# https://home.nps.gov/learnandexplore/explore-by-topic.htm
# https://home.nps.gov/getinvolved/index.htm
# https://home.nps.gov/getinvolved/donate.htm
# https://home.nps.gov/getinvolved/partner.htm
# https://home.nps.gov/getinvolved/volunteer.htm
# https://home.nps.gov/aboutus/workwithus.htm
# https://home.nps.gov/getinvolved/communities.htm
# https://home.nps.gov/findapark/advanced-search.htm
# https://home.nps.gov/yose/
# https://home.nps.gov/yose/planyourvisit/basicinfo.htm
# https://home.nps.gov/yose/planyourvisit/conditions.htm
# https://home.nps.gov/yose/planyourvisit/maps.htm
# https://home.nps.gov/yose/planyourvisit/calendar.htm
# https://home.nps.gov/yose/planyourvisit/fees.htm
# None
# https://home.nps.gov/yose/planyourvisit/reservations.htm
# None
# https://home.nps.gov/yose/planyourvisit/wroads.htm
# None
# https://home.nps.gov/yose/planyourvisit/conditions.htm
# https://home.nps.gov/yose/planyourvisit/conditions.htm
# https://home.nps.gov/yose/planyourvisit/reservations.htm
# https://home.nps.gov/yose/planyourvisit/faq.htm
# https://home.nps.gov/yose/planyourvisit/eatingsleeping.htm
# https://home.nps.gov/yose/planyourvisit/driving.htm
# https://home.nps.gov/yose/planyourvisit/maps.htm
# https://home.nps.gov/yose/planyourvisit/roadwork.htm
# https://home.nps.gov/yose/planyourvisit/wroads.htm
# https://home.nps.gov/yose/planyourvisit/tiogaclosed.htm
# https://home.nps.gov/yose/planyourvisit/tirechains.htm
# https://home.nps.gov/yose/planyourvisit/traffic.htm
# https://home.nps.gov/yose/planyourvisit/publictransportation.htm
# https://home.nps.gov/yose/planyourvisit/rv.htm
# https://home.nps.gov/yose/planyourvisit/restrictions.htm
# https://home.nps.gov/yose/planyourvisit/airports.htm
# https://home.nps.gov/yose/contacts.htm
# https://home.nps.gov/yose/faqs.htm
# https://home.nps.gov/yose/siteindex.htm
# https://home.nps.gov/yose/espanol/index.htm
# https://www.facebook.com/YosemiteNPS
# http://www.twitter.com/YosemiteNPS
# http://www.instagram.com/YosemiteNPS
# http://www.youtube.com/user/yosemitenationalpark
# https://apps.apple.com/us/app/national-park-service/id1549226484
# https://play.google.com/store/apps/details?id=gov.nps.mobileapp
# https://www.nps.gov/
# https://www.doi.gov/
# https://www.nps.gov/
# https://www.nps.gov/aboutus/accessibility.htm
# https://www.nps.gov/aboutus/privacy.htm
# https://www.nps.gov/aboutus/foia/index.htm
# https://www.nps.gov/aboutus/notices.htm
# https://www.nps.gov/aboutus/contactus.htm
# https://www.nps.gov/aboutus/faqs.htm
# https://www.doi.gov/pmb/eeo/no-fear-act
# https://www.nps.gov/aboutus/disclaimer.htm
# https://www.nps.gov/aboutus/vulnerability-disclosure-policy.htm
# https://www.usa.gov/
# https://www.facebook.com/nationalparkservice
# https://www.youtube.com/nationalparkservice
# https://www.twitter.com/natlparkservice
# https://www.instagram.com/nationalparkservice
# https://www.flickr.com/nationalparkservice

# %%
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

park = "YOSE"
link = "https://www.nps.gov/"+park+"/index.htm"
driver.get(link)
#driver.find_element_by_xpath('//*[@id="anch_15"]').click()
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'lxml')
elems = driver.find_elements(By.TAG_NAME, "a")
website_list=[]
raw_list=[]
website_content=[]
raw_soup_list = []
website_location = []
for elem in elems:
    try:
        if "planyourvisit" in str(elem.get_attribute('href')) and str(elem.get_attribute('href')) not in raw_list: #only want plan your visit sites
            z= str(elem.get_attribute('href'))
            raw_list.append(z)
            website_list.append(z)
    except:
        pass

for x in website_list:
    try:
        driver.get(x)
        
        page_location = driver.find_element(By.ID, "breadcrumbs")
        website_location.append(page_location.text)
        page_source = driver.page_source
        elems = driver.find_elements(By.TAG_NAME, "a")
        soup = BeautifulSoup(page_source, 'lxml')
        raw_content = soup.get_text(strip=True) #all text fields are scraped
        website_content.append(raw_content) #raw content added to list of all content
        raw_soup_list.append(soup)
    except:
        #This means that the webpage doesn't exist
        website_content.append("page doesn't exist")
        raw_soup_list.append("page doesn't exist")
        website_location.append("page doesn't exist")

driver.close()

dict = {'website page': website_list, 'content': website_content, 'soup': raw_soup_list,
       "website location": website_location}  #create dataframe for park data
park_data = pd.DataFrame(dict)
park_data['park']=park

# %%
park_data
# Out:
#                                          website page                                            content                                               soup                                   website location  park
# 0        https://nps.gov/yose/planyourvisit/index.htm  Plan Your Visit - Yosemite National Park (U.S....  [[ Content Copyright National Park Service ,  ...                    NPS.govPark HomePlan Your Visit  YOSE
# 1    https://nps.gov/yose/planyourvisit/basicinfo.htm  Basic Information - Yosemite National Park (U....  [[ Content Copyright National Park Service ,  ...   NPS.govPark HomePlan Your VisitBasic Information  YOSE
# 2        https://nps.gov/yose/planyourvisit/hours.htm  Operating Hours & Seasons - Yosemite National ...  [[ Content Copyright National Park Service ,  ...  NPS.govPark HomePlan Your VisitBasic Informati...  YOSE
# 3         https://nps.gov/yose/planyourvisit/fall.htm  Visiting in Fall - Yosemite National Park (U.S...  [[ Content Copyright National Park Service ,  ...  NPS.govPark HomePlan Your VisitBasic Informati...  YOSE
# 4       https://nps.gov/yose/planyourvisit/winter.htm  Visiting in Winter - Yosemite National Park (U...  [[ Content Copyright National Park Service ,  ...  NPS.govPark HomePlan Your VisitBasic Informati...  YOSE
# ..                                                ...                                                ...                                                ...                                                ...   ...
# 142           https://nps.gov/planyourvisit/index.htm  Plan Your Visit (U.S. National Park Service)Sk...  [[ Content Copyright National Park Service ,  ...                                                     YOSE
# 143    https://nps.gov/planyourvisit/event-search.htm  Event Calendar (U.S. National Park Service)Ski...  [[ Content Copyright National Park Service ,  ...                                                     YOSE
# 144          https://nps.gov/planyourvisit/passes.htm  Entrance Passes (U.S. National Park Service)Sk...  [[ Content Copyright National Park Service ,  ...                                                     YOSE
# 145      https://nps.gov/planyourvisit/trip-ideas.htm  Trip Ideas (U.S. National Park Service)Skip to...  [[ Content Copyright National Park Service ,  ...                                                     YOSE
# 146  https://nps.gov/yose/planyourvisit/hdpermits.htm  Half Dome Permits for Day Hikers - Yosemite Na...  [[ Content Copyright National Park Service ,  ...  NPS.govPark HomePlan Your VisitThings To DoHik...  YOSE
#
# [147 rows x 5 columns]

# %%
stopwords = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", 
             "you", "your", "yours", "yourself", "yourselves", "he", "him", 
             "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", 
             "they", "them", "their", "theirs", "themselves", "what", "which", "who",
             "whom", "this", "that", "these", "those", "am", "is", "are", "was", 
             "were", "be", "been", "being", "have", "has", "had", "having", "do", 
             "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", 
             "because", "as", "until", "while", "of", "at", "by", "for", "with", "about",
             "against", "between", "into", "through", "during", "before", "after", "above", 
             "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", 
             "again", "further", "then", "once", "here", "there", "when", "where", "why", 
             "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", 
             "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", 
             "s", "t", "can", "will", "just", "don", "should", "now",
            "href","=","/",">","<","]","[","span","'\n'",'class',"jstcache",
            "onclick","null","jscontent"," <br/>","</span>",",",";","(",")","{","}",":","''",
            "&","'","var","+=",".","#","-","=","+","``","0","’","data.operatingHours","outputVarOperatingHours",
            ".exceptions","--","1","-1","?","class=","==","div","/div","$","li","e","!","k","/span","jQuery",
            "tabindex",'j','l']

# %%
z=0
v=0
for x in parks['Alpha'].unique():
    v+=1
    if z==0:
        park_scrape_dataset=scrape_site(x)
        print(x)
       # break
    else:
        this_park_scrape = scrape_site(x)
        park_scrape_dataset = park_scrape_dataset.append(this_park_scrape)
    if v % 25 == 0:
        print(x)
        print(len(park_scrape_dataset))
    z+=1
    #if z>50: #if want to test out
    #    break
# Out:
# ABLI
# BAND
# 839
# CACL
# 1901
# CHIC
# 2798
# DENA
# 3759
# FOCA
# 4593
# FRLA
# 5309
# GRTE
# 6431
# INDE
# 7292
# KLGO
# 8151
# MABE
# 9054
# MUWO
# 9858
# PAAL
# 10735
# REDW
# 11590
# SAPU
# 12355
# TICA
# 13154
# WASH
# 13884

# %%
# save your scraped website into another variable name so don't have to redo scrape
park_scrape_dataset2 = park_scrape_dataset

#data cleaning
park_scrape_dataset2['index1'] = park_scrape_dataset2.index
park_scrape_dataset2=park_scrape_dataset2.reset_index()


#save as excel
#note: saving as a csv won't work due to punctuation used in html code
park_scrape_dataset2.to_excel("full_park_scrape_dataset.xlsx")

# %%
park_scrape_dataset2.tail()
# Out:
#        index                                       website page                                            content                                               soup website location  park  index1
# 14663     17  https://home.nps.gov/zion/planyourvisit/zion-c...  Zion Canyon Shuttle System - Zion National Par...  [[ Content Copyright National Park Service ,  ...                   ZION      17
# 14664     18  https://home.nps.gov/zion/planyourvisit/kolob-...  Kolob Canyons - Zion National Park (U.S. Natio...  [[ Content Copyright National Park Service ,  ...                   ZION      18
# 14665     19  https://home.nps.gov/grca/planyourvisit/north-...  North Rim - Grand Canyon National Park (U.S. N...  [[ Content Copyright National Park Service ,  ...                   ZION      19
# 14666     20  https://home.nps.gov/zion/planyourvisit/the-zi...  The Zion-Mount Carmel Tunnel - Zion National P...  [[ Content Copyright National Park Service ,  ...                   ZION      20
# 14667     21  https://home.nps.gov/zion/planyourvisit/hours.htm  Operating Hours & Seasons - Zion National Park...  [[ Content Copyright National Park Service ,  ...                   ZION      21

# %%
park_scrape_dataset2.shape
# Out:
# (14668, 7)

# %%
park_scrape_dataset_content = park_scrape_dataset2[['index','website page', 'content', 'website location', 'park']]

# %%
park_scrape_dataset_content.to_excel("park_scrape_content_dataset.xlsx")

# %%
## Model to calculate VE fields ##

#create new sheet so with our variables for each park
park_sheet = pd.DataFrame(columns = ['park', 'Driving_Directions','Public_transportation_information',
                                     'Bike_Pedestrian_Information','Congestion_information','Accessibility',
                                           'Alternative_Fueling_Stations', 'website page count'])
z=0
tic = time.process_time() #function to let us track processing time


for x in park_scrape_dataset2['park'].unique():
    z+=1
    if z % 25 == 0: 
        #function to let us track processing time
        z5 = 424-z
        toc = time.process_time()
        time_diff = toc-tic
        print("Current Park: ", x, ": ", z, " checks done; ", z5, " remaining; Processing Time: ",time_diff)
        tic=toc
        
    this_park = park_scrape_dataset2[(park_scrape_dataset2['park']==x)] #filter our webscraping dataset for our park's website code
    park_final = Traveler_Info_Finder(this_park) #run function
    park_sheet = park_sheet.append({'park': park_final.get_value(0,'park'),
                        'website page count': park_final.get_value(0,'website page'),
                        'Directions_word_count': park_final.get_value(0,'Directions_count'),
                        'Directions_page_count': park_final.get_value(0,'Directions_page_count'),
                       'Driving_Directions': park_final.get_value(0,'MajorDirections_count'),
                       'Public_transportation_information': park_final.get_value(0,'Public_transportation_information'),
                       'Alternative_Fueling_Stations': park_final.get_value(0,'Alternative_Fueling_Stations'), 
                       'Bike_Pedestrian_Information': park_final.get_value(0,'Bike_Pedestrian_Information'),
                       'Congestion_information': park_final.get_value(0,'Congestion_information'),
                        'Travel_Distance_Information': park_final.get_value(0,'Travel_dist_information'),
                        'Travel_other_dist_information': park_final.get_value(0,'Travel_other_dist_information'),
                        'Accessibility': park_final.get_value(0,'Accessibility_information'),
                        'Parking_raw_information': park_final.get_value(0,'Parking_information'),
                        'Parking_experience_information': park_final.get_value(0,'Parking_experience_information'),
                        'Parking_max_on_one_site': park_final.get_value(0,'Parking_max_on_one_site')
                       },
                      ignore_index=True)
    park_sheet.loc[park_sheet.Driving_Directions > 0, 'Driving_Directions'] = 1
    park_sheet.loc[park_sheet.Alternative_Fueling_Stations > 0, 'Alternative_Fueling_Stations'] = 1
    park_sheet.loc[park_sheet.Public_transportation_information > 0, 'Public_transportation_information'] = 1
    park_sheet.loc[park_sheet.Bike_Pedestrian_Information > 0, 'Bike_Pedestrian_Information'] = 1
    park_sheet.loc[park_sheet.Congestion_information > 0, 'Congestion_information'] = 1
    park_sheet.loc[park_sheet.Accessibility > 0, 'Accessibility'] = 1
 #   park_sheet.loc[park_sheet.Parking_information > 0, 'Parking_information'] = 1
    park_sheet['Travel_Distance_Final']=np.where(
        np.logical_or(park_sheet['Travel_Distance_Information']>9, 
                     park_sheet['Travel_other_dist_information']>0),1,0)
    park_sheet['Parking_Experience_information']=np.where((
        park_sheet['Parking_raw_information']/park_sheet['website page count'])>0.25,1,0)
    park_sheet['Transportation_experience_information']=np.where((
        park_sheet['Directions_page_count']/park_sheet['website page count'])>0.65,1,0)
    park_sheet['Parking_information']=np.where(np.logical_or(
        park_sheet['Parking_Experience_information']==1,
        park_sheet['Parking_max_on_one_site']>2),1,0)


park_sheet= park_sheet.drop(columns=['website page count', 'Directions_word_count',
                        'Directions_page_count','Parking_raw_information','Parking_experience_information',
                        'Parking_max_on_one_site','Travel_Distance_Information','Travel_other_dist_information'])
    
#create csv
park_sheet.to_csv("final_park.csv") #save final csv
os.system("start EXCEL.EXE final_park.csv") #open csv file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 11>()
#      19     tic=toc
#      21 this_park = park_scrape_dataset2[(park_scrape_dataset2['park']==x)] #filter our webscraping dataset for our park's website code
# ---> 22 park_final = Traveler_Info_Finder(this_park) #run function
#      23 park_sheet = park_sheet.append({'park': park_final.get_value(0,'park'),
#      24                     'website page count': park_final.get_value(0,'website page'),
#      25                     'Directions_word_count': park_final.get_value(0,'Directions_count'),
#    (...)
#      38                    },
#      39                   ignore_index=True)
#      40 park_sheet.loc[park_sheet.Driving_Directions > 0, 'Driving_Directions'] = 1
#
# File ~\Documents\GitHub\NPS-Emerging-Mobility\NPS digital product content\VE_scraper_functions.py:268, in Traveler_Info_Finder(park)
#     264  park['Parking_experience_information']=Parking_plan_count
#     265  park['Parking_max_on_one_site']=park['Parking_experience_information']
# --> 268  park['Accessibility_information']=np.where(
#     269      np.logical_or(park['Accessibility_intro_information']>2,
#     270                   park['Parking_experience_information']>2),1,0)
#     272  park_final = park.groupby('park', as_index=False).agg({
#     273      "MajorDirections_count": "sum",
#     274      "Directions_count": "sum",
#    (...)
#     286      "website page":"count",
#     287  })
#     289 # park_final2 = park.groupby('park')['Directions_word_list'].apply(lambda x: ','.join(x))
#     290 # park_final = park_final.merge(park_final2, on="park")
#
# NameError: name 'np' is not defined
